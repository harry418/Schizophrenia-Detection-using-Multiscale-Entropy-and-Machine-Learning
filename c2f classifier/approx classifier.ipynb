# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install lazypredict
# Out:
# Requirement already satisfied: lazypredict in /usr/local/lib/python3.7/dist-packages (0.2.9)
# Requirement already satisfied: PyYAML==5.3.1 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (5.3.1)
# Requirement already satisfied: numpy==1.19.1 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.19.1)
# Requirement already satisfied: pytest==5.4.3 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (5.4.3)
# Requirement already satisfied: scikit-learn==0.23.1 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (0.23.1)
# Requirement already satisfied: scipy==1.5.4 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.5.4)
# Requirement already satisfied: six==1.15.0 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.15.0)
# Requirement already satisfied: tqdm==4.56.0 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (4.56.0)
# Requirement already satisfied: pandas==1.0.5 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.0.5)
# Requirement already satisfied: xgboost==1.1.1 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.1.1)
# Requirement already satisfied: joblib==1.0.0 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.0.0)
# Requirement already satisfied: lightgbm==2.3.1 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (2.3.1)
# Requirement already satisfied: click==7.1.2 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (7.1.2)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from pandas==1.0.5->lazypredict) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas==1.0.5->lazypredict) (2018.9)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (1.11.0)
# Requirement already satisfied: importlib-metadata>=0.12 in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (4.11.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (21.4.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (8.12.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (21.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (0.2.5)
# Requirement already satisfied: pluggy<1.0,>=0.12 in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (0.13.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.23.1->lazypredict) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.12->pytest==5.4.3->lazypredict) (3.7.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.12->pytest==5.4.3->lazypredict) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->pytest==5.4.3->lazypredict) (3.0.7)

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/multiscale_entropy/c2f_calculated_entropy/approx_data.csv',header=None)

# %%
import numpy as np
df=df.T.fillna(df.mean(axis=1)).T

# %%
df.tail()
# Out:
#            0         1         2         3         4         5         6    \
# 1137  0.016248  0.015369  0.009241  0.010045  0.020647  0.006052  0.027738
# 1138  0.006717  0.006052  0.005830  0.006052  0.005784  0.003389  0.005386
# 1139  0.006495  0.007337  0.005248  0.006273  0.006939  0.002946  0.011238
# 1140  0.031601  0.032932  0.025963  0.020869  0.034699  0.020203  0.053570
# 1141  0.017181  0.016784  0.012217  0.013104  0.016562  0.011773  0.024104
#
#            7         8         9    ...       181       182       183  \
# 1137  0.018069  0.018466  0.027256  ...  0.003168  0.003389  0.001836
# 1138  0.004720  0.006052  0.007383  ...  0.001171  0.001836  0.002280
# 1139  0.006579  0.005830  0.011238  ...  0.002058  0.004055  0.003611
# 1140  0.029337  0.026731  0.048650  ...  0.003833  0.004720  0.003833
# 1141  0.013816  0.016654  0.028755  ...  0.003122  0.002724  0.003168
#
#            184       185       186       187       188       189  190
# 1137  0.004055  0.077051  0.003168  0.004277  0.003343  0.001393  2.0
# 1138  0.002502  0.016795  0.002280  0.001393  0.002280  0.002280  2.0
# 1139  0.002502  0.033953  0.004277  0.002280  0.005164  0.001836  2.0
# 1140  0.004942  0.049388  0.003611  0.006893  0.003168  0.004499  2.0
# 1141  0.002946  0.023278  0.003168  0.002946  0.002280  0.002280  2.0
#
# [5 rows x 191 columns]

# %%
cols_to_scale = list(df.columns)[:-1]
from sklearn.preprocessing import StandardScaler,MinMaxScaler,RobustScaler
scaler = StandardScaler()
df[cols_to_scale] = scaler.fit_transform(df[cols_to_scale])

# %%
df.shape
# Out:
# (1142, 191)

# %%
X = df.drop([df.shape[1]-1], axis=1)
y = df[df.shape[1]-1].values

# %%
X.shape
# Out:
# (1142, 190)

# %%
y.shape
# Out:
# (1142,)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()

logreg.fit(X_train,y_train)
print(logreg.score(X_test,y_test))
from sklearn.metrics import confusion_matrix,classification_report
print(classification_report(y_test,logreg.predict(X_test)))
# Out:
# 0.7903930131004366
#               precision    recall  f1-score   support
#
#          1.0       0.80      0.74      0.77       109
#          2.0       0.78      0.83      0.81       120
#
#     accuracy                           0.79       229
#    macro avg       0.79      0.79      0.79       229
# weighted avg       0.79      0.79      0.79       229

# %% [markdown]
# svm

# %%
from sklearn.svm import SVC
svm = SVC(kernel = 'linear')
svm.fit(X_train,y_train)
svm.score(X_test,y_test)
# Out:
# 0.7903930131004366

# %%
print(classification_report(y_test,svm.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.80      0.75      0.77       109
#          2.0       0.79      0.82      0.80       120
#
#     accuracy                           0.79       229
#    macro avg       0.79      0.79      0.79       229
# weighted avg       0.79      0.79      0.79       229

# %% [markdown]
# # New Section

# %%
'''Set a seed for reproducibility'''
seed = 43

'''Initialize all the regression models object we are interested in.'''
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier,ExtraTreesClassifier,GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

'''We are interested in the following 14 regression models.
All initialized with default parameters except random_state and n_jobs.'''


et = ExtraTreesClassifier(n_jobs = -1, random_state = seed)
ab = AdaBoostClassifier(random_state = seed)
gb = GradientBoostingClassifier(random_state = seed)
xgb = XGBClassifier(random_state = seed, n_jobs = -1)
lgb = LGBMClassifier(random_state = seed, n_jobs = -1)

knn = KNeighborsClassifier(3)
lsvm = SVC(kernel="linear", C=0.025)
rsvm = SVC(kernel="rbf",gamma=2, C=1)
gps = GaussianProcessClassifier(1.0 * RBF(1.0))
dt = DecisionTreeClassifier(max_depth=5)
rf = RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1)
mlp = MLPClassifier(alpha=1, max_iter=1000)
gnb = GaussianNB()
qda = QuadraticDiscriminantAnalysis()

# %%
'''Evaluate models on the holdout set(say on 30%).'''
def train_test_split_score(model):
    from sklearn.metrics import mean_squared_error
    from sklearn.model_selection import train_test_split
    X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size = 0.2, random_state = seed)
    model.fit(X_train, Y_train)
    return model.score(X_test,Y_test)
'''Calculate train_test_split score of differnt models and plot them.'''
models = [et,ab,gb,xgb,lgb,knn,lsvm,rsvm,gps,dt,rf,mlp,gnb,qda]
train_test_split_res = []
for model in models:
    train_test_split_res.append(train_test_split_score(model))

'''Plot data frame of train test rmse'''
train_test_score = pd.DataFrame(data = train_test_split_res, columns = ['Train_Test_SCORE'])
train_test_score.index = ['ET', 'AB', 'GB', 'XGB', 'LGB', 'KNN', 'LSVM', 'RSVM', 'GPS', 'DT', 'RF', 'MLP', 'GNB', 'QDA']
train_test_score = train_test_score.round(5)
train_test_score
# Out:
#       Train_Test_SCORE
# ET             0.78603
# AB             0.74672
# GB             0.79476
# XGB            0.79476
# LGB            0.83843
# KNN            0.81223
# LSVM           0.58079
# RSVM           0.78603
# GPS            0.79039
# DT             0.68996
# RF             0.66376
# MLP            0.75546
# GNB            0.46288
# QDA            0.71179

# %%
def cross_validate(model):
    from sklearn.model_selection import cross_val_score
    score = cross_val_score(model, X, y, cv = 10, n_jobs = -1, scoring = 'accuracy')
    return score.mean()

'''Calculate cross validation score of differnt models and plot them.'''
models = [et,ab,gb,xgb,lgb,knn,lsvm,rsvm,gps,dt,rf,mlp,gnb,qda]
cross_val_scores = []
for model in models:
    cross_val_scores.append(cross_validate(model))

'''Plot data frame of cross validation scores.'''
x_val_score = pd.DataFrame(data = cross_val_scores, columns = ['Cross Validation Scores (ACC)'])
x_val_score.index = ['ET', 'AB', 'GB', 'XGB', 'LGB', 'KNN', 'LSVM', 'RSVM', 'GPS', 'DT', 'RF', 'MLP', 'GNB', 'QDA']

# %%
x_val_score
# Out:
#       Cross Validation Scores (ACC)
# ET                         0.745606
# AB                         0.706880
# GB                         0.752502
# XGB                        0.746377
# LGB                        0.765645
# KNN                        0.729725
# LSVM                       0.569176
# RSVM                       0.743715
# GPS                        0.741953
# DT                         0.689413
# RF                         0.680679
# MLP                        0.750862
# GNB                        0.485172
# QDA                        0.659550

# %%
'''Create a function to plot learning curves.'''
import matplotlib.pyplot as plt
import numpy as np

def plot_learning_curve(model):
    from sklearn.model_selection import learning_curve
    
    # df_train_final is training matrix and y_train is target matrix.
    # Create CV training and test scores for various training set sizes
    train_sizes, train_scores, test_scores = learning_curve(model, X, y, 
                                            train_sizes = np.linspace(0.01, 1.0, 20), cv = 10, scoring = 'accuracy', 
                                            n_jobs = -1, random_state = seed)
    
    
    # Create means and standard deviations of training set scores
    train_mean = np.mean(train_scores, axis = 1)
    train_std = np.std(train_scores, axis = 1)

    # Create means and standard deviations of test set scores
    test_mean = np.mean(test_scores, axis = 1)
    test_std = np.std(test_scores, axis = 1)  
    # Draw lines
    plt.plot(train_sizes, train_mean, 'o-', color = 'red',  label = 'Training score')
    plt.plot(train_sizes, test_mean, 'o-', color = 'green', label = 'Cross-validation score')
    
    # Draw bands
    plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, alpha = 0.1, color = 'r') # Alpha controls band transparency.
    plt.fill_between(train_sizes, test_mean - test_std, test_mean + test_std, alpha = 0.1, color = 'g')
    
    
    # Create plot
    font_size = 12
    plt.xlabel('Training Set Size', fontsize = font_size)
    plt.ylabel('Accuracy Score', fontsize = font_size)
    plt.xticks(fontsize = font_size)
    plt.yticks(fontsize = font_size)
    plt.legend(loc = 'best')
    plt.grid()

# %%
'''Now plot learning curves of the optimized models in subplots.
For computational reason, I am omitting XGB, GB, and LGB.'''
plt.figure(figsize = (16,24))
lc_models = [et,ab,gb,xgb,lgb,knn,lsvm,rsvm,gps,dt,rf,mlp,gnb,qda]
lc_labels = ['ET', 'AB', 'GB', 'XGB', 'LGB', 'KNN', 'LSVM', 'RSVM', 'GPS', 'DT', 'RF', 'MLP', 'GNB', 'QDA']

for ax, models, labels in zip (range(1,14), lc_models, lc_labels):
    try:
        plt.subplot(7,2,ax)
        plot_learning_curve(models)
        plt.title(labels, fontsize = 15)
    except:
        pass
plt.suptitle('Learning Curves of Optimized Models', fontsize = 20)
plt.tight_layout(rect = [0, 0.03, 1, 0.97])

# %% [markdown]
# # XGB

# %%
import xgboost as xgb
# read in data
'''
dtrain = xgb.DMatrix(X_train,y_train)
dtest = xgb.DMatrix(X_test,y_test)
evallist = [(dtest, 'eval'), (dtrain, 'train')]
# specify parameters via map
param = {'booster': 'dart',
         'max_depth': 5, 'learning_rate': 0.01,
         'objective': 'binary:logistic',
         'sample_type': 'uniform',
         'normalize_type': 'tree',
         'rate_drop': 0.1,
         'eval_metric':'auc',
         'skip_drop': 0.5}
num_round = 500
bst = xgb.train(param, dtrain, num_round,evallist)
preds = bst.predict(dtest)
'''
# Out:
# "\ndtrain = xgb.DMatrix(X_train,y_train)\ndtest = xgb.DMatrix(X_test,y_test)\nevallist = [(dtest, 'eval'), (dtrain, 'train')]\n# specify parameters via map\nparam = {'booster': 'dart',\n         'max_depth': 5, 'learning_rate': 0.01,\n         'objective': 'binary:logistic',\n         'sample_type': 'uniform',\n         'normalize_type': 'tree',\n         'rate_drop': 0.1,\n         'eval_metric':'auc',\n         'skip_drop': 0.5}\nnum_round = 500\nbst = xgb.train(param, dtrain, num_round,evallist)\npreds = bst.predict(dtest)\n"

# %%
#xgb.plot_importance(bst)

# %%
param = {'booster': 'dart',
         'max_depth': 5,
         'learning_rate': 0.001,
         'objective': 'binary:logistic',
         'sample_type': 'uniform',
         'normalize_type': 'tree',
         'rate_drop': 0.1,
         'skip_drop': 0.5,
         'n_estimators':2000}

# %%
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier
from matplotlib import pyplot
# define the model
model = XGBClassifier(**param)
# define the datasets to evaluate each iteration
evalset = [(X_train, y_train), (X_test,y_test)]
# fit the model
model.fit(X_train, y_train, eval_metric=['logloss','auc'], eval_set=evalset)
# evaluate performance
yhat = model.predict(X_test)
score = accuracy_score(y_test, yhat)
print('Accuracy: %.3f' % score)
# retrieve performance metrics
results = model.evals_result()
# plot learning curves
pyplot.plot(results['validation_0']['logloss'], label='train')
pyplot.plot(results['validation_1']['logloss'], label='test')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# [0]	validation_0-logloss:0.69262	validation_0-auc:0.90591	validation_1-logloss:0.69277	validation_1-auc:0.82691
# [1]	validation_0-logloss:0.69210	validation_0-auc:0.90911	validation_1-logloss:0.69241	validation_1-auc:0.82653
# [2]	validation_0-logloss:0.69158	validation_0-auc:0.90987	validation_1-logloss:0.69203	validation_1-auc:0.82649
# [3]	validation_0-logloss:0.69106	validation_0-auc:0.90896	validation_1-logloss:0.69169	validation_1-auc:0.82179
# [4]	validation_0-logloss:0.69054	validation_0-auc:0.90874	validation_1-logloss:0.69135	validation_1-auc:0.82179
# [5]	validation_0-logloss:0.69002	validation_0-auc:0.91056	validation_1-logloss:0.69099	validation_1-auc:0.82439
# [6]	validation_0-logloss:0.68950	validation_0-auc:0.91047	validation_1-logloss:0.69061	validation_1-auc:0.82336
# [7]	validation_0-logloss:0.68899	validation_0-auc:0.91241	validation_1-logloss:0.69025	validation_1-auc:0.82534
# [8]	validation_0-logloss:0.68847	validation_0-auc:0.91388	validation_1-logloss:0.68991	validation_1-auc:0.82336
# [9]	validation_0-logloss:0.68795	validation_0-auc:0.91540	validation_1-logloss:0.68954	validation_1-auc:0.82053
# [10]	validation_0-logloss:0.68747	validation_0-auc:0.93199	validation_1-logloss:0.68919	validation_1-auc:0.83169
# [11]	validation_0-logloss:0.68694	validation_0-auc:0.94460	validation_1-logloss:0.68887	validation_1-auc:0.83995
# [12]	validation_0-logloss:0.68643	validation_0-auc:0.94401	validation_1-logloss:0.68852	validation_1-auc:0.84002
# [13]	validation_0-logloss:0.68616	validation_0-auc:0.94622	validation_1-logloss:0.68836	validation_1-auc:0.84010
# [14]	validation_0-logloss:0.68591	validation_0-auc:0.94559	validation_1-logloss:0.68819	validation_1-auc:0.84002
# [15]	validation_0-logloss:0.68538	validation_0-auc:0.94893	validation_1-logloss:0.68787	validation_1-auc:0.84193
# [16]	validation_0-logloss:0.68487	validation_0-auc:0.94814	validation_1-logloss:0.68753	validation_1-auc:0.83934
# [17]	validation_0-logloss:0.68436	validation_0-auc:0.94793	validation_1-logloss:0.68719	validation_1-auc:0.83803
# [18]	validation_0-logloss:0.68384	validation_0-auc:0.95017	validation_1-logloss:0.68688	validation_1-auc:0.83895
# [19]	validation_0-logloss:0.68331	validation_0-auc:0.95173	validation_1-logloss:0.68655	validation_1-auc:0.83995
# [20]	validation_0-logloss:0.68278	validation_0-auc:0.95281	validation_1-logloss:0.68624	validation_1-auc:0.84010
# [21]	validation_0-logloss:0.68266	validation_0-auc:0.95266	validation_1-logloss:0.68616	validation_1-auc:0.83972
# [22]	validation_0-logloss:0.68240	validation_0-auc:0.95324	validation_1-logloss:0.68600	validation_1-auc:0.84025
# [23]	validation_0-logloss:0.68189	validation_0-auc:0.95274	validation_1-logloss:0.68566	validation_1-auc:0.83987
# [24]	validation_0-logloss:0.68137	validation_0-auc:0.95363	validation_1-logloss:0.68535	validation_1-auc:0.84086
# [25]	validation_0-logloss:0.68112	validation_0-auc:0.95353	validation_1-logloss:0.68517	validation_1-auc:0.84018
# [26]	validation_0-logloss:0.68059	validation_0-auc:0.95381	validation_1-logloss:0.68486	validation_1-auc:0.84125
# [27]	validation_0-logloss:0.68010	validation_0-auc:0.95364	validation_1-logloss:0.68454	validation_1-auc:0.83941
# [28]	validation_0-logloss:0.67957	validation_0-auc:0.95405	validation_1-logloss:0.68423	validation_1-auc:0.84132
# [29]	validation_0-logloss:0.67933	validation_0-auc:0.95391	validation_1-logloss:0.68406	validation_1-auc:0.84048
# [30]	validation_0-logloss:0.67881	validation_0-auc:0.95423	validation_1-logloss:0.68375	validation_1-auc:0.84094
# [31]	validation_0-logloss:0.67830	validation_0-auc:0.95394	validation_1-logloss:0.68339	validation_1-auc:0.84182
# [32]	validation_0-logloss:0.67778	validation_0-auc:0.95436	validation_1-logloss:0.68309	validation_1-auc:0.84167
# [33]	validation_0-logloss:0.67770	validation_0-auc:0.95433	validation_1-logloss:0.68303	validation_1-auc:0.84167
# [34]	validation_0-logloss:0.67758	validation_0-auc:0.95424	validation_1-logloss:0.68295	validation_1-auc:0.84167
# [35]	validation_0-logloss:0.67746	validation_0-auc:0.95410	validation_1-logloss:0.68287	validation_1-auc:0.84128
# [36]	validation_0-logloss:0.67695	validation_0-auc:0.95719	validation_1-logloss:0.68252	validation_1-auc:0.84457
# [37]	validation_0-logloss:0.67643	validation_0-auc:0.95759	validation_1-logloss:0.68221	validation_1-auc:0.84373
# [38]	validation_0-logloss:0.67592	validation_0-auc:0.95942	validation_1-logloss:0.68186	validation_1-auc:0.84671
# [39]	validation_0-logloss:0.67541	validation_0-auc:0.95961	validation_1-logloss:0.68156	validation_1-auc:0.84625
# [40]	validation_0-logloss:0.67525	validation_0-auc:0.95948	validation_1-logloss:0.68145	validation_1-auc:0.84572
# [41]	validation_0-logloss:0.67475	validation_0-auc:0.95925	validation_1-logloss:0.68112	validation_1-auc:0.84557
# [42]	validation_0-logloss:0.67424	validation_0-auc:0.95938	validation_1-logloss:0.68081	validation_1-auc:0.84526
# [43]	validation_0-logloss:0.67374	validation_0-auc:0.96080	validation_1-logloss:0.68047	validation_1-auc:0.84732
# [44]	validation_0-logloss:0.67323	validation_0-auc:0.96083	validation_1-logloss:0.68016	validation_1-auc:0.84686
# [45]	validation_0-logloss:0.67274	validation_0-auc:0.96048	validation_1-logloss:0.67984	validation_1-auc:0.84625
# [46]	validation_0-logloss:0.67224	validation_0-auc:0.96215	validation_1-logloss:0.67950	validation_1-auc:0.84847
# [47]	validation_0-logloss:0.67218	validation_0-auc:0.96208	validation_1-logloss:0.67945	validation_1-auc:0.84824
# [48]	validation_0-logloss:0.67201	validation_0-auc:0.96252	validation_1-logloss:0.67934	validation_1-auc:0.84885
# [49]	validation_0-logloss:0.67185	validation_0-auc:0.96236	validation_1-logloss:0.67923	validation_1-auc:0.84885
# [50]	validation_0-logloss:0.67179	validation_0-auc:0.96230	validation_1-logloss:0.67918	validation_1-auc:0.84893
# [51]	validation_0-logloss:0.67128	validation_0-auc:0.96258	validation_1-logloss:0.67888	validation_1-auc:0.84916
# [52]	validation_0-logloss:0.67120	validation_0-auc:0.96237	validation_1-logloss:0.67882	validation_1-auc:0.84916
# [53]	validation_0-logloss:0.67073	validation_0-auc:0.96280	validation_1-logloss:0.67855	validation_1-auc:0.84790
# [54]	validation_0-logloss:0.67067	validation_0-auc:0.96281	validation_1-logloss:0.67851	validation_1-auc:0.84759
# [55]	validation_0-logloss:0.67054	validation_0-auc:0.96283	validation_1-logloss:0.67844	validation_1-auc:0.84759
# [56]	validation_0-logloss:0.67004	validation_0-auc:0.96272	validation_1-logloss:0.67814	validation_1-auc:0.84690
# [57]	validation_0-logloss:0.66954	validation_0-auc:0.96393	validation_1-logloss:0.67780	validation_1-auc:0.84859
# [58]	validation_0-logloss:0.66903	validation_0-auc:0.96400	validation_1-logloss:0.67749	validation_1-auc:0.84759
# [59]	validation_0-logloss:0.66895	validation_0-auc:0.96384	validation_1-logloss:0.67744	validation_1-auc:0.84774
# [60]	validation_0-logloss:0.66887	validation_0-auc:0.96398	validation_1-logloss:0.67739	validation_1-auc:0.84774
# [61]	validation_0-logloss:0.66841	validation_0-auc:0.96422	validation_1-logloss:0.67712	validation_1-auc:0.84744
# [62]	validation_0-logloss:0.66834	validation_0-auc:0.96426	validation_1-logloss:0.67707	validation_1-auc:0.84744
# [63]	validation_0-logloss:0.66783	validation_0-auc:0.96426	validation_1-logloss:0.67677	validation_1-auc:0.84675
# [64]	validation_0-logloss:0.66774	validation_0-auc:0.96424	validation_1-logloss:0.67671	validation_1-auc:0.84690
# [65]	validation_0-logloss:0.66724	validation_0-auc:0.96498	validation_1-logloss:0.67637	validation_1-auc:0.84767
# [66]	validation_0-logloss:0.66716	validation_0-auc:0.96497	validation_1-logloss:0.67632	validation_1-auc:0.84752
# [67]	validation_0-logloss:0.66708	validation_0-auc:0.96495	validation_1-logloss:0.67626	validation_1-auc:0.84759
# [68]	validation_0-logloss:0.66699	validation_0-auc:0.96506	validation_1-logloss:0.67621	validation_1-auc:0.84752
# [69]	validation_0-logloss:0.66649	validation_0-auc:0.96509	validation_1-logloss:0.67591	validation_1-auc:0.84774
# [70]	validation_0-logloss:0.66600	validation_0-auc:0.96562	validation_1-logloss:0.67557	validation_1-auc:0.84881
# [71]	validation_0-logloss:0.66591	validation_0-auc:0.96565	validation_1-logloss:0.67552	validation_1-auc:0.84889
# [72]	validation_0-logloss:0.66586	validation_0-auc:0.96564	validation_1-logloss:0.67549	validation_1-auc:0.84874
# [73]	validation_0-logloss:0.66540	validation_0-auc:0.96591	validation_1-logloss:0.67519	validation_1-auc:0.84816
# [74]	validation_0-logloss:0.66532	validation_0-auc:0.96594	validation_1-logloss:0.67514	validation_1-auc:0.84866
# [75]	validation_0-logloss:0.66482	validation_0-auc:0.96588	validation_1-logloss:0.67485	validation_1-auc:0.84836
# [76]	validation_0-logloss:0.66478	validation_0-auc:0.96588	validation_1-logloss:0.67482	validation_1-auc:0.84859
# [77]	validation_0-logloss:0.66471	validation_0-auc:0.96589	validation_1-logloss:0.67478	validation_1-auc:0.84836
# [78]	validation_0-logloss:0.66422	validation_0-auc:0.96651	validation_1-logloss:0.67444	validation_1-auc:0.84889
# [79]	validation_0-logloss:0.66372	validation_0-auc:0.96639	validation_1-logloss:0.67414	validation_1-auc:0.84859
# [80]	validation_0-logloss:0.66323	validation_0-auc:0.96682	validation_1-logloss:0.67381	validation_1-auc:0.84958
# [81]	validation_0-logloss:0.66274	validation_0-auc:0.96661	validation_1-logloss:0.67352	validation_1-auc:0.84927
# [82]	validation_0-logloss:0.66229	validation_0-auc:0.96681	validation_1-logloss:0.67323	validation_1-auc:0.84859
# [83]	validation_0-logloss:0.66179	validation_0-auc:0.96674	validation_1-logloss:0.67295	validation_1-auc:0.84828
# [84]	validation_0-logloss:0.66131	validation_0-auc:0.96721	validation_1-logloss:0.67262	validation_1-auc:0.84912
# [85]	validation_0-logloss:0.66082	validation_0-auc:0.96714	validation_1-logloss:0.67233	validation_1-auc:0.84843
# [86]	validation_0-logloss:0.66076	validation_0-auc:0.96711	validation_1-logloss:0.67229	validation_1-auc:0.84859
# [87]	validation_0-logloss:0.66067	validation_0-auc:0.96710	validation_1-logloss:0.67223	validation_1-auc:0.84843
# [88]	validation_0-logloss:0.66057	validation_0-auc:0.96706	validation_1-logloss:0.67218	validation_1-auc:0.84790
# [89]	validation_0-logloss:0.66009	validation_0-auc:0.96741	validation_1-logloss:0.67184	validation_1-auc:0.84881
# [90]	validation_0-logloss:0.65961	validation_0-auc:0.96728	validation_1-logloss:0.67151	validation_1-auc:0.84889
# [91]	validation_0-logloss:0.65957	validation_0-auc:0.96726	validation_1-logloss:0.67148	validation_1-auc:0.84889
# [92]	validation_0-logloss:0.65949	validation_0-auc:0.96726	validation_1-logloss:0.67143	validation_1-auc:0.84904
# [93]	validation_0-logloss:0.65943	validation_0-auc:0.96727	validation_1-logloss:0.67139	validation_1-auc:0.84889
# [94]	validation_0-logloss:0.65936	validation_0-auc:0.96727	validation_1-logloss:0.67135	validation_1-auc:0.84904
# [95]	validation_0-logloss:0.65891	validation_0-auc:0.96726	validation_1-logloss:0.67109	validation_1-auc:0.84851
# [96]	validation_0-logloss:0.65886	validation_0-auc:0.96725	validation_1-logloss:0.67105	validation_1-auc:0.84843
# [97]	validation_0-logloss:0.65879	validation_0-auc:0.96724	validation_1-logloss:0.67101	validation_1-auc:0.84836
# [98]	validation_0-logloss:0.65830	validation_0-auc:0.96733	validation_1-logloss:0.67073	validation_1-auc:0.84866
# [99]	validation_0-logloss:0.65825	validation_0-auc:0.96733	validation_1-logloss:0.67070	validation_1-auc:0.84851
# [100]	validation_0-logloss:0.65818	validation_0-auc:0.96733	validation_1-logloss:0.67065	validation_1-auc:0.84851
# [101]	validation_0-logloss:0.65770	validation_0-auc:0.96775	validation_1-logloss:0.67032	validation_1-auc:0.84912
# [102]	validation_0-logloss:0.65766	validation_0-auc:0.96773	validation_1-logloss:0.67029	validation_1-auc:0.84912
# [103]	validation_0-logloss:0.65762	validation_0-auc:0.96770	validation_1-logloss:0.67027	validation_1-auc:0.84881
# [104]	validation_0-logloss:0.65759	validation_0-auc:0.96772	validation_1-logloss:0.67025	validation_1-auc:0.84897
# [105]	validation_0-logloss:0.65754	validation_0-auc:0.96772	validation_1-logloss:0.67022	validation_1-auc:0.84889
# [106]	validation_0-logloss:0.65705	validation_0-auc:0.96760	validation_1-logloss:0.66993	validation_1-auc:0.84874
# [107]	validation_0-logloss:0.65658	validation_0-auc:0.96791	validation_1-logloss:0.66961	validation_1-auc:0.84881
# [108]	validation_0-logloss:0.65609	validation_0-auc:0.96783	validation_1-logloss:0.66933	validation_1-auc:0.84881
# [109]	validation_0-logloss:0.65606	validation_0-auc:0.96779	validation_1-logloss:0.66931	validation_1-auc:0.84874
# [110]	validation_0-logloss:0.65603	validation_0-auc:0.96783	validation_1-logloss:0.66929	validation_1-auc:0.84889
# [111]	validation_0-logloss:0.65558	validation_0-auc:0.96789	validation_1-logloss:0.66901	validation_1-auc:0.84843
# [112]	validation_0-logloss:0.65510	validation_0-auc:0.96801	validation_1-logloss:0.66873	validation_1-auc:0.84805
# [113]	validation_0-logloss:0.65505	validation_0-auc:0.96802	validation_1-logloss:0.66869	validation_1-auc:0.84805
# [114]	validation_0-logloss:0.65457	validation_0-auc:0.96841	validation_1-logloss:0.66836	validation_1-auc:0.84901
# [115]	validation_0-logloss:0.65409	validation_0-auc:0.96845	validation_1-logloss:0.66809	validation_1-auc:0.84801
# [116]	validation_0-logloss:0.65405	validation_0-auc:0.96841	validation_1-logloss:0.66807	validation_1-auc:0.84801
# [117]	validation_0-logloss:0.65358	validation_0-auc:0.96875	validation_1-logloss:0.66773	validation_1-auc:0.84931
# [118]	validation_0-logloss:0.65310	validation_0-auc:0.96872	validation_1-logloss:0.66745	validation_1-auc:0.84816
# [119]	validation_0-logloss:0.65307	validation_0-auc:0.96871	validation_1-logloss:0.66742	validation_1-auc:0.84809
# [120]	validation_0-logloss:0.65302	validation_0-auc:0.96866	validation_1-logloss:0.66739	validation_1-auc:0.84801
# [121]	validation_0-logloss:0.65299	validation_0-auc:0.96867	validation_1-logloss:0.66737	validation_1-auc:0.84809
# [122]	validation_0-logloss:0.65253	validation_0-auc:0.96863	validation_1-logloss:0.66704	validation_1-auc:0.84962
# [123]	validation_0-logloss:0.65250	validation_0-auc:0.96865	validation_1-logloss:0.66702	validation_1-auc:0.84969
# [124]	validation_0-logloss:0.65246	validation_0-auc:0.96861	validation_1-logloss:0.66699	validation_1-auc:0.84962
# [125]	validation_0-logloss:0.65199	validation_0-auc:0.96898	validation_1-logloss:0.66666	validation_1-auc:0.85031
# [126]	validation_0-logloss:0.65151	validation_0-auc:0.96883	validation_1-logloss:0.66639	validation_1-auc:0.84962
# [127]	validation_0-logloss:0.65107	validation_0-auc:0.96888	validation_1-logloss:0.66612	validation_1-auc:0.84977
# [128]	validation_0-logloss:0.65103	validation_0-auc:0.96887	validation_1-logloss:0.66609	validation_1-auc:0.84977
# [129]	validation_0-logloss:0.65056	validation_0-auc:0.96881	validation_1-logloss:0.66582	validation_1-auc:0.84923
# [130]	validation_0-logloss:0.65052	validation_0-auc:0.96880	validation_1-logloss:0.66579	validation_1-auc:0.84939
# [131]	validation_0-logloss:0.65005	validation_0-auc:0.96913	validation_1-logloss:0.66546	validation_1-auc:0.84969
# [132]	validation_0-logloss:0.65002	validation_0-auc:0.96911	validation_1-logloss:0.66545	validation_1-auc:0.84962
# [133]	validation_0-logloss:0.64954	validation_0-auc:0.96908	validation_1-logloss:0.66517	validation_1-auc:0.84885
# [134]	validation_0-logloss:0.64950	validation_0-auc:0.96910	validation_1-logloss:0.66514	validation_1-auc:0.84885
# [135]	validation_0-logloss:0.64904	validation_0-auc:0.96934	validation_1-logloss:0.66482	validation_1-auc:0.84962
# [136]	validation_0-logloss:0.64856	validation_0-auc:0.96931	validation_1-logloss:0.66454	validation_1-auc:0.84855
# [137]	validation_0-logloss:0.64813	validation_0-auc:0.96929	validation_1-logloss:0.66427	validation_1-auc:0.84885
# [138]	validation_0-logloss:0.64810	validation_0-auc:0.96928	validation_1-logloss:0.66425	validation_1-auc:0.84878
# [139]	validation_0-logloss:0.64763	validation_0-auc:0.96922	validation_1-logloss:0.66398	validation_1-auc:0.84832
# [140]	validation_0-logloss:0.64717	validation_0-auc:0.96954	validation_1-logloss:0.66365	validation_1-auc:0.84870
# [141]	validation_0-logloss:0.64711	validation_0-auc:0.96955	validation_1-logloss:0.66362	validation_1-auc:0.84885
# [142]	validation_0-logloss:0.64707	validation_0-auc:0.96952	validation_1-logloss:0.66359	validation_1-auc:0.84878
# [143]	validation_0-logloss:0.64702	validation_0-auc:0.96954	validation_1-logloss:0.66356	validation_1-auc:0.84870
# [144]	validation_0-logloss:0.64655	validation_0-auc:0.96947	validation_1-logloss:0.66329	validation_1-auc:0.84908
# [145]	validation_0-logloss:0.64611	validation_0-auc:0.96978	validation_1-logloss:0.66299	validation_1-auc:0.84931
# [146]	validation_0-logloss:0.64608	validation_0-auc:0.96977	validation_1-logloss:0.66297	validation_1-auc:0.84947
# [147]	validation_0-logloss:0.64605	validation_0-auc:0.96976	validation_1-logloss:0.66296	validation_1-auc:0.84939
# [148]	validation_0-logloss:0.64558	validation_0-auc:0.96969	validation_1-logloss:0.66269	validation_1-auc:0.84916
# [149]	validation_0-logloss:0.64514	validation_0-auc:0.96964	validation_1-logloss:0.66240	validation_1-auc:0.84916
# [150]	validation_0-logloss:0.64470	validation_0-auc:0.96992	validation_1-logloss:0.66210	validation_1-auc:0.84954
# [151]	validation_0-logloss:0.64423	validation_0-auc:0.96988	validation_1-logloss:0.66183	validation_1-auc:0.84931
# [152]	validation_0-logloss:0.64420	validation_0-auc:0.96988	validation_1-logloss:0.66181	validation_1-auc:0.84931
# [153]	validation_0-logloss:0.64418	validation_0-auc:0.96988	validation_1-logloss:0.66180	validation_1-auc:0.84931
# [154]	validation_0-logloss:0.64414	validation_0-auc:0.96988	validation_1-logloss:0.66177	validation_1-auc:0.84939
# [155]	validation_0-logloss:0.64409	validation_0-auc:0.96988	validation_1-logloss:0.66174	validation_1-auc:0.84931
# [156]	validation_0-logloss:0.64406	validation_0-auc:0.96988	validation_1-logloss:0.66172	validation_1-auc:0.84947
# [157]	validation_0-logloss:0.64360	validation_0-auc:0.96977	validation_1-logloss:0.66146	validation_1-auc:0.84916
# [158]	validation_0-logloss:0.64356	validation_0-auc:0.96978	validation_1-logloss:0.66143	validation_1-auc:0.84908
# [159]	validation_0-logloss:0.64313	validation_0-auc:0.96974	validation_1-logloss:0.66117	validation_1-auc:0.84893
# [160]	validation_0-logloss:0.64268	validation_0-auc:0.97005	validation_1-logloss:0.66085	validation_1-auc:0.84916
# [161]	validation_0-logloss:0.64265	validation_0-auc:0.97006	validation_1-logloss:0.66083	validation_1-auc:0.84908
# [162]	validation_0-logloss:0.64219	validation_0-auc:0.97004	validation_1-logloss:0.66057	validation_1-auc:0.84916
# [163]	validation_0-logloss:0.64173	validation_0-auc:0.96999	validation_1-logloss:0.66030	validation_1-auc:0.84923
# [164]	validation_0-logloss:0.64170	validation_0-auc:0.96998	validation_1-logloss:0.66028	validation_1-auc:0.84923
# [165]	validation_0-logloss:0.64168	validation_0-auc:0.97000	validation_1-logloss:0.66026	validation_1-auc:0.84916
# [166]	validation_0-logloss:0.64164	validation_0-auc:0.97001	validation_1-logloss:0.66024	validation_1-auc:0.84931
# [167]	validation_0-logloss:0.64121	validation_0-auc:0.97023	validation_1-logloss:0.65995	validation_1-auc:0.84954
# [168]	validation_0-logloss:0.64075	validation_0-auc:0.97015	validation_1-logloss:0.65968	validation_1-auc:0.84870
# [169]	validation_0-logloss:0.64071	validation_0-auc:0.97012	validation_1-logloss:0.65966	validation_1-auc:0.84870
# [170]	validation_0-logloss:0.64026	validation_0-auc:0.97015	validation_1-logloss:0.65935	validation_1-auc:0.84893
# [171]	validation_0-logloss:0.63984	validation_0-auc:0.97024	validation_1-logloss:0.65908	validation_1-auc:0.84870
# [172]	validation_0-logloss:0.63982	validation_0-auc:0.97021	validation_1-logloss:0.65907	validation_1-auc:0.84862
# [173]	validation_0-logloss:0.63936	validation_0-auc:0.97015	validation_1-logloss:0.65881	validation_1-auc:0.84847
# [174]	validation_0-logloss:0.63891	validation_0-auc:0.97039	validation_1-logloss:0.65849	validation_1-auc:0.84847
# [175]	validation_0-logloss:0.63845	validation_0-auc:0.97098	validation_1-logloss:0.65822	validation_1-auc:0.84923
# [176]	validation_0-logloss:0.63803	validation_0-auc:0.97129	validation_1-logloss:0.65787	validation_1-auc:0.85130
# [177]	validation_0-logloss:0.63760	validation_0-auc:0.97148	validation_1-logloss:0.65759	validation_1-auc:0.85122
# [178]	validation_0-logloss:0.63714	validation_0-auc:0.97181	validation_1-logloss:0.65732	validation_1-auc:0.85115
# [179]	validation_0-logloss:0.63712	validation_0-auc:0.97181	validation_1-logloss:0.65731	validation_1-auc:0.85122
# [180]	validation_0-logloss:0.63710	validation_0-auc:0.97180	validation_1-logloss:0.65729	validation_1-auc:0.85122
# [181]	validation_0-logloss:0.63707	validation_0-auc:0.97180	validation_1-logloss:0.65728	validation_1-auc:0.85122
# [182]	validation_0-logloss:0.63665	validation_0-auc:0.97203	validation_1-logloss:0.65693	validation_1-auc:0.85191
# [183]	validation_0-logloss:0.63619	validation_0-auc:0.97202	validation_1-logloss:0.65666	validation_1-auc:0.85184
# [184]	validation_0-logloss:0.63617	validation_0-auc:0.97200	validation_1-logloss:0.65665	validation_1-auc:0.85184
# [185]	validation_0-logloss:0.63612	validation_0-auc:0.97204	validation_1-logloss:0.65662	validation_1-auc:0.85176
# [186]	validation_0-logloss:0.63570	validation_0-auc:0.97216	validation_1-logloss:0.65633	validation_1-auc:0.85160
# [187]	validation_0-logloss:0.63524	validation_0-auc:0.97237	validation_1-logloss:0.65606	validation_1-auc:0.85138
# [188]	validation_0-logloss:0.63481	validation_0-auc:0.97235	validation_1-logloss:0.65578	validation_1-auc:0.85130
# [189]	validation_0-logloss:0.63479	validation_0-auc:0.97235	validation_1-logloss:0.65577	validation_1-auc:0.85138
# [190]	validation_0-logloss:0.63477	validation_0-auc:0.97236	validation_1-logloss:0.65576	validation_1-auc:0.85145
# [191]	validation_0-logloss:0.63435	validation_0-auc:0.97257	validation_1-logloss:0.65541	validation_1-auc:0.85245
# [192]	validation_0-logloss:0.63433	validation_0-auc:0.97255	validation_1-logloss:0.65540	validation_1-auc:0.85252
# [193]	validation_0-logloss:0.63388	validation_0-auc:0.97281	validation_1-logloss:0.65514	validation_1-auc:0.85229
# [194]	validation_0-logloss:0.63344	validation_0-auc:0.97278	validation_1-logloss:0.65484	validation_1-auc:0.85222
# [195]	validation_0-logloss:0.63302	validation_0-auc:0.97288	validation_1-logloss:0.65456	validation_1-auc:0.85252
# [196]	validation_0-logloss:0.63260	validation_0-auc:0.97315	validation_1-logloss:0.65422	validation_1-auc:0.85367
# [197]	validation_0-logloss:0.63215	validation_0-auc:0.97333	validation_1-logloss:0.65396	validation_1-auc:0.85375
# [198]	validation_0-logloss:0.63213	validation_0-auc:0.97332	validation_1-logloss:0.65395	validation_1-auc:0.85375
# [199]	validation_0-logloss:0.63169	validation_0-auc:0.97341	validation_1-logloss:0.65367	validation_1-auc:0.85428
# [200]	validation_0-logloss:0.63127	validation_0-auc:0.97367	validation_1-logloss:0.65332	validation_1-auc:0.85528
# [201]	validation_0-logloss:0.63125	validation_0-auc:0.97366	validation_1-logloss:0.65331	validation_1-auc:0.85535
# [202]	validation_0-logloss:0.63123	validation_0-auc:0.97367	validation_1-logloss:0.65329	validation_1-auc:0.85535
# [203]	validation_0-logloss:0.63081	validation_0-auc:0.97378	validation_1-logloss:0.65302	validation_1-auc:0.85535
# [204]	validation_0-logloss:0.63036	validation_0-auc:0.97399	validation_1-logloss:0.65276	validation_1-auc:0.85558
# [205]	validation_0-logloss:0.62993	validation_0-auc:0.97386	validation_1-logloss:0.65248	validation_1-auc:0.85550
# [206]	validation_0-logloss:0.62952	validation_0-auc:0.97417	validation_1-logloss:0.65214	validation_1-auc:0.85680
# [207]	validation_0-logloss:0.62908	validation_0-auc:0.97434	validation_1-logloss:0.65188	validation_1-auc:0.85673
# [208]	validation_0-logloss:0.62905	validation_0-auc:0.97434	validation_1-logloss:0.65187	validation_1-auc:0.85680
# [209]	validation_0-logloss:0.62862	validation_0-auc:0.97428	validation_1-logloss:0.65158	validation_1-auc:0.85719
# [210]	validation_0-logloss:0.62861	validation_0-auc:0.97428	validation_1-logloss:0.65157	validation_1-auc:0.85719
# [211]	validation_0-logloss:0.62819	validation_0-auc:0.97441	validation_1-logloss:0.65129	validation_1-auc:0.85788
# [212]	validation_0-logloss:0.62817	validation_0-auc:0.97440	validation_1-logloss:0.65128	validation_1-auc:0.85780
# [213]	validation_0-logloss:0.62815	validation_0-auc:0.97439	validation_1-logloss:0.65126	validation_1-auc:0.85780
# [214]	validation_0-logloss:0.62813	validation_0-auc:0.97439	validation_1-logloss:0.65125	validation_1-auc:0.85772
# [215]	validation_0-logloss:0.62769	validation_0-auc:0.97462	validation_1-logloss:0.65099	validation_1-auc:0.85803
# [216]	validation_0-logloss:0.62728	validation_0-auc:0.97484	validation_1-logloss:0.65065	validation_1-auc:0.85879
# [217]	validation_0-logloss:0.62725	validation_0-auc:0.97485	validation_1-logloss:0.65063	validation_1-auc:0.85879
# [218]	validation_0-logloss:0.62681	validation_0-auc:0.97473	validation_1-logloss:0.65038	validation_1-auc:0.85833
# [219]	validation_0-logloss:0.62679	validation_0-auc:0.97472	validation_1-logloss:0.65037	validation_1-auc:0.85833
# [220]	validation_0-logloss:0.62676	validation_0-auc:0.97473	validation_1-logloss:0.65035	validation_1-auc:0.85833
# [221]	validation_0-logloss:0.62674	validation_0-auc:0.97472	validation_1-logloss:0.65033	validation_1-auc:0.85833
# [222]	validation_0-logloss:0.62671	validation_0-auc:0.97471	validation_1-logloss:0.65032	validation_1-auc:0.85833
# [223]	validation_0-logloss:0.62670	validation_0-auc:0.97472	validation_1-logloss:0.65031	validation_1-auc:0.85833
# [224]	validation_0-logloss:0.62628	validation_0-auc:0.97480	validation_1-logloss:0.65004	validation_1-auc:0.85841
# [225]	validation_0-logloss:0.62587	validation_0-auc:0.97500	validation_1-logloss:0.64970	validation_1-auc:0.85948
# [226]	validation_0-logloss:0.62585	validation_0-auc:0.97500	validation_1-logloss:0.64969	validation_1-auc:0.85948
# [227]	validation_0-logloss:0.62541	validation_0-auc:0.97510	validation_1-logloss:0.64943	validation_1-auc:0.85894
# [228]	validation_0-logloss:0.62497	validation_0-auc:0.97513	validation_1-logloss:0.64915	validation_1-auc:0.85986
# [229]	validation_0-logloss:0.62456	validation_0-auc:0.97525	validation_1-logloss:0.64889	validation_1-auc:0.85986
# [230]	validation_0-logloss:0.62454	validation_0-auc:0.97525	validation_1-logloss:0.64887	validation_1-auc:0.85986
# [231]	validation_0-logloss:0.62411	validation_0-auc:0.97535	validation_1-logloss:0.64862	validation_1-auc:0.85948
# [232]	validation_0-logloss:0.62409	validation_0-auc:0.97535	validation_1-logloss:0.64861	validation_1-auc:0.85940
# [233]	validation_0-logloss:0.62407	validation_0-auc:0.97536	validation_1-logloss:0.64860	validation_1-auc:0.85948
# [234]	validation_0-logloss:0.62406	validation_0-auc:0.97535	validation_1-logloss:0.64859	validation_1-auc:0.85948
# [235]	validation_0-logloss:0.62362	validation_0-auc:0.97545	validation_1-logloss:0.64831	validation_1-auc:0.86032
# [236]	validation_0-logloss:0.62360	validation_0-auc:0.97544	validation_1-logloss:0.64830	validation_1-auc:0.86032
# [237]	validation_0-logloss:0.62359	validation_0-auc:0.97545	validation_1-logloss:0.64829	validation_1-auc:0.86032
# [238]	validation_0-logloss:0.62357	validation_0-auc:0.97545	validation_1-logloss:0.64828	validation_1-auc:0.86025
# [239]	validation_0-logloss:0.62355	validation_0-auc:0.97545	validation_1-logloss:0.64826	validation_1-auc:0.86025
# [240]	validation_0-logloss:0.62353	validation_0-auc:0.97544	validation_1-logloss:0.64825	validation_1-auc:0.86032
# [241]	validation_0-logloss:0.62313	validation_0-auc:0.97565	validation_1-logloss:0.64792	validation_1-auc:0.86105
# [242]	validation_0-logloss:0.62310	validation_0-auc:0.97564	validation_1-logloss:0.64790	validation_1-auc:0.86089
# [243]	validation_0-logloss:0.62267	validation_0-auc:0.97574	validation_1-logloss:0.64764	validation_1-auc:0.85990
# [244]	validation_0-logloss:0.62223	validation_0-auc:0.97583	validation_1-logloss:0.64736	validation_1-auc:0.86074
# [245]	validation_0-logloss:0.62222	validation_0-auc:0.97584	validation_1-logloss:0.64735	validation_1-auc:0.86067
# [246]	validation_0-logloss:0.62181	validation_0-auc:0.97598	validation_1-logloss:0.64702	validation_1-auc:0.86067
# [247]	validation_0-logloss:0.62140	validation_0-auc:0.97603	validation_1-logloss:0.64676	validation_1-auc:0.86067
# [248]	validation_0-logloss:0.62097	validation_0-auc:0.97618	validation_1-logloss:0.64651	validation_1-auc:0.86051
# [249]	validation_0-logloss:0.62054	validation_0-auc:0.97620	validation_1-logloss:0.64624	validation_1-auc:0.86059
# [250]	validation_0-logloss:0.62013	validation_0-auc:0.97637	validation_1-logloss:0.64592	validation_1-auc:0.86059
# [251]	validation_0-logloss:0.61973	validation_0-auc:0.97646	validation_1-logloss:0.64566	validation_1-auc:0.86097
# [252]	validation_0-logloss:0.61929	validation_0-auc:0.97648	validation_1-logloss:0.64539	validation_1-auc:0.86112
# [253]	validation_0-logloss:0.61927	validation_0-auc:0.97648	validation_1-logloss:0.64537	validation_1-auc:0.86112
# [254]	validation_0-logloss:0.61887	validation_0-auc:0.97671	validation_1-logloss:0.64505	validation_1-auc:0.86097
# [255]	validation_0-logloss:0.61844	validation_0-auc:0.97659	validation_1-logloss:0.64480	validation_1-auc:0.86112
# [256]	validation_0-logloss:0.61802	validation_0-auc:0.97663	validation_1-logloss:0.64453	validation_1-auc:0.86105
# [257]	validation_0-logloss:0.61801	validation_0-auc:0.97663	validation_1-logloss:0.64453	validation_1-auc:0.86105
# [258]	validation_0-logloss:0.61799	validation_0-auc:0.97663	validation_1-logloss:0.64452	validation_1-auc:0.86105
# [259]	validation_0-logloss:0.61759	validation_0-auc:0.97671	validation_1-logloss:0.64425	validation_1-auc:0.86097
# [260]	validation_0-logloss:0.61758	validation_0-auc:0.97672	validation_1-logloss:0.64424	validation_1-auc:0.86097
# [261]	validation_0-logloss:0.61715	validation_0-auc:0.97677	validation_1-logloss:0.64399	validation_1-auc:0.86105
# [262]	validation_0-logloss:0.61675	validation_0-auc:0.97696	validation_1-logloss:0.64367	validation_1-auc:0.86097
# [263]	validation_0-logloss:0.61674	validation_0-auc:0.97696	validation_1-logloss:0.64367	validation_1-auc:0.86097
# [264]	validation_0-logloss:0.61631	validation_0-auc:0.97707	validation_1-logloss:0.64342	validation_1-auc:0.86059
# [265]	validation_0-logloss:0.61630	validation_0-auc:0.97706	validation_1-logloss:0.64341	validation_1-auc:0.86059
# [266]	validation_0-logloss:0.61588	validation_0-auc:0.97710	validation_1-logloss:0.64315	validation_1-auc:0.86074
# [267]	validation_0-logloss:0.61587	validation_0-auc:0.97710	validation_1-logloss:0.64314	validation_1-auc:0.86074
# [268]	validation_0-logloss:0.61585	validation_0-auc:0.97710	validation_1-logloss:0.64313	validation_1-auc:0.86074
# [269]	validation_0-logloss:0.61546	validation_0-auc:0.97719	validation_1-logloss:0.64280	validation_1-auc:0.86067
# [270]	validation_0-logloss:0.61503	validation_0-auc:0.97730	validation_1-logloss:0.64255	validation_1-auc:0.86097
# [271]	validation_0-logloss:0.61501	validation_0-auc:0.97731	validation_1-logloss:0.64253	validation_1-auc:0.86097
# [272]	validation_0-logloss:0.61461	validation_0-auc:0.97732	validation_1-logloss:0.64227	validation_1-auc:0.86082
# [273]	validation_0-logloss:0.61419	validation_0-auc:0.97739	validation_1-logloss:0.64203	validation_1-auc:0.86036
# [274]	validation_0-logloss:0.61418	validation_0-auc:0.97739	validation_1-logloss:0.64202	validation_1-auc:0.86044
# [275]	validation_0-logloss:0.61378	validation_0-auc:0.97748	validation_1-logloss:0.64170	validation_1-auc:0.86074
# [276]	validation_0-logloss:0.61377	validation_0-auc:0.97748	validation_1-logloss:0.64169	validation_1-auc:0.86067
# [277]	validation_0-logloss:0.61375	validation_0-auc:0.97748	validation_1-logloss:0.64168	validation_1-auc:0.86059
# [278]	validation_0-logloss:0.61374	validation_0-auc:0.97748	validation_1-logloss:0.64167	validation_1-auc:0.86059
# [279]	validation_0-logloss:0.61373	validation_0-auc:0.97749	validation_1-logloss:0.64167	validation_1-auc:0.86059
# [280]	validation_0-logloss:0.61371	validation_0-auc:0.97749	validation_1-logloss:0.64166	validation_1-auc:0.86067
# [281]	validation_0-logloss:0.61370	validation_0-auc:0.97748	validation_1-logloss:0.64165	validation_1-auc:0.86067
# [282]	validation_0-logloss:0.61329	validation_0-auc:0.97754	validation_1-logloss:0.64138	validation_1-auc:0.86059
# [283]	validation_0-logloss:0.61327	validation_0-auc:0.97754	validation_1-logloss:0.64138	validation_1-auc:0.86059
# [284]	validation_0-logloss:0.61285	validation_0-auc:0.97759	validation_1-logloss:0.64113	validation_1-auc:0.86067
# [285]	validation_0-logloss:0.61284	validation_0-auc:0.97760	validation_1-logloss:0.64112	validation_1-auc:0.86059
# [286]	validation_0-logloss:0.61283	validation_0-auc:0.97760	validation_1-logloss:0.64111	validation_1-auc:0.86055
# [287]	validation_0-logloss:0.61281	validation_0-auc:0.97760	validation_1-logloss:0.64110	validation_1-auc:0.86051
# [288]	validation_0-logloss:0.61242	validation_0-auc:0.97775	validation_1-logloss:0.64079	validation_1-auc:0.86067
# [289]	validation_0-logloss:0.61202	validation_0-auc:0.97779	validation_1-logloss:0.64053	validation_1-auc:0.86074
# [290]	validation_0-logloss:0.61201	validation_0-auc:0.97779	validation_1-logloss:0.64052	validation_1-auc:0.86067
# [291]	validation_0-logloss:0.61199	validation_0-auc:0.97779	validation_1-logloss:0.64051	validation_1-auc:0.86067
# [292]	validation_0-logloss:0.61197	validation_0-auc:0.97779	validation_1-logloss:0.64050	validation_1-auc:0.86067
# [293]	validation_0-logloss:0.61155	validation_0-auc:0.97785	validation_1-logloss:0.64025	validation_1-auc:0.86059
# [294]	validation_0-logloss:0.61114	validation_0-auc:0.97785	validation_1-logloss:0.64000	validation_1-auc:0.86036
# [295]	validation_0-logloss:0.61072	validation_0-auc:0.97792	validation_1-logloss:0.63975	validation_1-auc:0.86028
# [296]	validation_0-logloss:0.61033	validation_0-auc:0.97805	validation_1-logloss:0.63943	validation_1-auc:0.86128
# [297]	validation_0-logloss:0.60994	validation_0-auc:0.97811	validation_1-logloss:0.63917	validation_1-auc:0.86128
# [298]	validation_0-logloss:0.60993	validation_0-auc:0.97811	validation_1-logloss:0.63916	validation_1-auc:0.86128
# [299]	validation_0-logloss:0.60991	validation_0-auc:0.97811	validation_1-logloss:0.63916	validation_1-auc:0.86128
# [300]	validation_0-logloss:0.60990	validation_0-auc:0.97811	validation_1-logloss:0.63915	validation_1-auc:0.86128
# [301]	validation_0-logloss:0.60988	validation_0-auc:0.97810	validation_1-logloss:0.63914	validation_1-auc:0.86120
# [302]	validation_0-logloss:0.60987	validation_0-auc:0.97810	validation_1-logloss:0.63913	validation_1-auc:0.86120
# [303]	validation_0-logloss:0.60985	validation_0-auc:0.97810	validation_1-logloss:0.63912	validation_1-auc:0.86128
# [304]	validation_0-logloss:0.60984	validation_0-auc:0.97810	validation_1-logloss:0.63911	validation_1-auc:0.86128
# [305]	validation_0-logloss:0.60942	validation_0-auc:0.97811	validation_1-logloss:0.63887	validation_1-auc:0.86112
# [306]	validation_0-logloss:0.60941	validation_0-auc:0.97811	validation_1-logloss:0.63886	validation_1-auc:0.86112
# [307]	validation_0-logloss:0.60899	validation_0-auc:0.97821	validation_1-logloss:0.63862	validation_1-auc:0.86105
# [308]	validation_0-logloss:0.60858	validation_0-auc:0.97822	validation_1-logloss:0.63836	validation_1-auc:0.86082
# [309]	validation_0-logloss:0.60857	validation_0-auc:0.97821	validation_1-logloss:0.63835	validation_1-auc:0.86089
# [310]	validation_0-logloss:0.60856	validation_0-auc:0.97820	validation_1-logloss:0.63834	validation_1-auc:0.86082
# [311]	validation_0-logloss:0.60817	validation_0-auc:0.97832	validation_1-logloss:0.63803	validation_1-auc:0.86143
# [312]	validation_0-logloss:0.60816	validation_0-auc:0.97831	validation_1-logloss:0.63802	validation_1-auc:0.86143
# [313]	validation_0-logloss:0.60814	validation_0-auc:0.97831	validation_1-logloss:0.63801	validation_1-auc:0.86143
# [314]	validation_0-logloss:0.60813	validation_0-auc:0.97832	validation_1-logloss:0.63800	validation_1-auc:0.86151
# [315]	validation_0-logloss:0.60812	validation_0-auc:0.97831	validation_1-logloss:0.63800	validation_1-auc:0.86151
# [316]	validation_0-logloss:0.60811	validation_0-auc:0.97831	validation_1-logloss:0.63799	validation_1-auc:0.86143
# [317]	validation_0-logloss:0.60771	validation_0-auc:0.97832	validation_1-logloss:0.63773	validation_1-auc:0.86120
# [318]	validation_0-logloss:0.60770	validation_0-auc:0.97832	validation_1-logloss:0.63773	validation_1-auc:0.86120
# [319]	validation_0-logloss:0.60769	validation_0-auc:0.97831	validation_1-logloss:0.63772	validation_1-auc:0.86120
# [320]	validation_0-logloss:0.60728	validation_0-auc:0.97842	validation_1-logloss:0.63748	validation_1-auc:0.86158
# [321]	validation_0-logloss:0.60688	validation_0-auc:0.97851	validation_1-logloss:0.63719	validation_1-auc:0.86216
# [322]	validation_0-logloss:0.60646	validation_0-auc:0.97856	validation_1-logloss:0.63694	validation_1-auc:0.86246
# [323]	validation_0-logloss:0.60645	validation_0-auc:0.97856	validation_1-logloss:0.63694	validation_1-auc:0.86246
# [324]	validation_0-logloss:0.60605	validation_0-auc:0.97860	validation_1-logloss:0.63668	validation_1-auc:0.86154
# [325]	validation_0-logloss:0.60603	validation_0-auc:0.97860	validation_1-logloss:0.63668	validation_1-auc:0.86154
# [326]	validation_0-logloss:0.60602	validation_0-auc:0.97860	validation_1-logloss:0.63667	validation_1-auc:0.86162
# [327]	validation_0-logloss:0.60601	validation_0-auc:0.97860	validation_1-logloss:0.63666	validation_1-auc:0.86162
# [328]	validation_0-logloss:0.60600	validation_0-auc:0.97860	validation_1-logloss:0.63665	validation_1-auc:0.86154
# [329]	validation_0-logloss:0.60598	validation_0-auc:0.97861	validation_1-logloss:0.63665	validation_1-auc:0.86154
# [330]	validation_0-logloss:0.60560	validation_0-auc:0.97869	validation_1-logloss:0.63633	validation_1-auc:0.86177
# [331]	validation_0-logloss:0.60519	validation_0-auc:0.97876	validation_1-logloss:0.63609	validation_1-auc:0.86277
# [332]	validation_0-logloss:0.60517	validation_0-auc:0.97876	validation_1-logloss:0.63608	validation_1-auc:0.86269
# [333]	validation_0-logloss:0.60479	validation_0-auc:0.97878	validation_1-logloss:0.63583	validation_1-auc:0.86246
# [334]	validation_0-logloss:0.60477	validation_0-auc:0.97879	validation_1-logloss:0.63582	validation_1-auc:0.86238
# [335]	validation_0-logloss:0.60476	validation_0-auc:0.97879	validation_1-logloss:0.63582	validation_1-auc:0.86238
# [336]	validation_0-logloss:0.60475	validation_0-auc:0.97878	validation_1-logloss:0.63581	validation_1-auc:0.86231
# [337]	validation_0-logloss:0.60434	validation_0-auc:0.97881	validation_1-logloss:0.63557	validation_1-auc:0.86262
# [338]	validation_0-logloss:0.60433	validation_0-auc:0.97881	validation_1-logloss:0.63557	validation_1-auc:0.86262
# [339]	validation_0-logloss:0.60432	validation_0-auc:0.97881	validation_1-logloss:0.63556	validation_1-auc:0.86262
# [340]	validation_0-logloss:0.60391	validation_0-auc:0.97881	validation_1-logloss:0.63531	validation_1-auc:0.86238
# [341]	validation_0-logloss:0.60351	validation_0-auc:0.97893	validation_1-logloss:0.63503	validation_1-auc:0.86269
# [342]	validation_0-logloss:0.60310	validation_0-auc:0.97898	validation_1-logloss:0.63479	validation_1-auc:0.86277
# [343]	validation_0-logloss:0.60309	validation_0-auc:0.97898	validation_1-logloss:0.63478	validation_1-auc:0.86277
# [344]	validation_0-logloss:0.60307	validation_0-auc:0.97897	validation_1-logloss:0.63477	validation_1-auc:0.86269
# [345]	validation_0-logloss:0.60268	validation_0-auc:0.97899	validation_1-logloss:0.63452	validation_1-auc:0.86277
# [346]	validation_0-logloss:0.60267	validation_0-auc:0.97900	validation_1-logloss:0.63451	validation_1-auc:0.86262
# [347]	validation_0-logloss:0.60266	validation_0-auc:0.97900	validation_1-logloss:0.63450	validation_1-auc:0.86269
# [348]	validation_0-logloss:0.60225	validation_0-auc:0.97905	validation_1-logloss:0.63427	validation_1-auc:0.86300
# [349]	validation_0-logloss:0.60224	validation_0-auc:0.97905	validation_1-logloss:0.63426	validation_1-auc:0.86300
# [350]	validation_0-logloss:0.60223	validation_0-auc:0.97905	validation_1-logloss:0.63425	validation_1-auc:0.86292
# [351]	validation_0-logloss:0.60184	validation_0-auc:0.97908	validation_1-logloss:0.63397	validation_1-auc:0.86323
# [352]	validation_0-logloss:0.60143	validation_0-auc:0.97906	validation_1-logloss:0.63373	validation_1-auc:0.86307
# [353]	validation_0-logloss:0.60102	validation_0-auc:0.97903	validation_1-logloss:0.63348	validation_1-auc:0.86315
# [354]	validation_0-logloss:0.60064	validation_0-auc:0.97910	validation_1-logloss:0.63323	validation_1-auc:0.86307
# [355]	validation_0-logloss:0.60063	validation_0-auc:0.97910	validation_1-logloss:0.63323	validation_1-auc:0.86307
# [356]	validation_0-logloss:0.60062	validation_0-auc:0.97909	validation_1-logloss:0.63322	validation_1-auc:0.86307
# [366]	validation_0-logloss:0.59820	validation_0-auc:0.97926	validation_1-logloss:0.63172	validation_1-auc:0.86223
# [367]	validation_0-logloss:0.59780	validation_0-auc:0.97929	validation_1-logloss:0.63149	validation_1-auc:0.86300
# [368]	validation_0-logloss:0.59741	validation_0-auc:0.97935	validation_1-logloss:0.63121	validation_1-auc:0.86323
# [369]	validation_0-logloss:0.59740	validation_0-auc:0.97935	validation_1-logloss:0.63121	validation_1-auc:0.86323
# [370]	validation_0-logloss:0.59738	validation_0-auc:0.97935	validation_1-logloss:0.63120	validation_1-auc:0.86323
# [371]	validation_0-logloss:0.59698	validation_0-auc:0.97938	validation_1-logloss:0.63095	validation_1-auc:0.86330
# [372]	validation_0-logloss:0.59697	validation_0-auc:0.97938	validation_1-logloss:0.63095	validation_1-auc:0.86330
# [373]	validation_0-logloss:0.59659	validation_0-auc:0.97944	validation_1-logloss:0.63067	validation_1-auc:0.86376
# [374]	validation_0-logloss:0.59621	validation_0-auc:0.97949	validation_1-logloss:0.63044	validation_1-auc:0.86376
# [375]	validation_0-logloss:0.59581	validation_0-auc:0.97952	validation_1-logloss:0.63019	validation_1-auc:0.86384
# [376]	validation_0-logloss:0.59580	validation_0-auc:0.97951	validation_1-logloss:0.63019	validation_1-auc:0.86376
# [377]	validation_0-logloss:0.59578	validation_0-auc:0.97951	validation_1-logloss:0.63018	validation_1-auc:0.86384
# [378]	validation_0-logloss:0.59577	validation_0-auc:0.97951	validation_1-logloss:0.63018	validation_1-auc:0.86384
# [379]	validation_0-logloss:0.59577	validation_0-auc:0.97951	validation_1-logloss:0.63017	validation_1-auc:0.86376
# [380]	validation_0-logloss:0.59538	validation_0-auc:0.97955	validation_1-logloss:0.62990	validation_1-auc:0.86414
# [381]	validation_0-logloss:0.59537	validation_0-auc:0.97956	validation_1-logloss:0.62989	validation_1-auc:0.86414
# [382]	validation_0-logloss:0.59497	validation_0-auc:0.97960	validation_1-logloss:0.62966	validation_1-auc:0.86376
# [383]	validation_0-logloss:0.59496	validation_0-auc:0.97961	validation_1-logloss:0.62965	validation_1-auc:0.86384
# [384]	validation_0-logloss:0.59456	validation_0-auc:0.97960	validation_1-logloss:0.62942	validation_1-auc:0.86384
# [385]	validation_0-logloss:0.59416	validation_0-auc:0.97967	validation_1-logloss:0.62918	validation_1-auc:0.86376
# [386]	validation_0-logloss:0.59377	validation_0-auc:0.97963	validation_1-logloss:0.62894	validation_1-auc:0.86338
# [387]	validation_0-logloss:0.59340	validation_0-auc:0.97968	validation_1-logloss:0.62871	validation_1-auc:0.86346
# [388]	validation_0-logloss:0.59300	validation_0-auc:0.97974	validation_1-logloss:0.62848	validation_1-auc:0.86353
# [389]	validation_0-logloss:0.59262	validation_0-auc:0.97976	validation_1-logloss:0.62821	validation_1-auc:0.86369
# [390]	validation_0-logloss:0.59223	validation_0-auc:0.97973	validation_1-logloss:0.62797	validation_1-auc:0.86338
# [391]	validation_0-logloss:0.59183	validation_0-auc:0.97970	validation_1-logloss:0.62774	validation_1-auc:0.86315
# [392]	validation_0-logloss:0.59182	validation_0-auc:0.97970	validation_1-logloss:0.62773	validation_1-auc:0.86315
# [393]	validation_0-logloss:0.59145	validation_0-auc:0.97972	validation_1-logloss:0.62750	validation_1-auc:0.86330
# [394]	validation_0-logloss:0.59144	validation_0-auc:0.97972	validation_1-logloss:0.62749	validation_1-auc:0.86323
# [395]	validation_0-logloss:0.59143	validation_0-auc:0.97972	validation_1-logloss:0.62748	validation_1-auc:0.86330
# [396]	validation_0-logloss:0.59142	validation_0-auc:0.97972	validation_1-logloss:0.62748	validation_1-auc:0.86330
# [397]	validation_0-logloss:0.59103	validation_0-auc:0.97981	validation_1-logloss:0.62726	validation_1-auc:0.86315
# [398]	validation_0-logloss:0.59064	validation_0-auc:0.97977	validation_1-logloss:0.62702	validation_1-auc:0.86284
# [399]	validation_0-logloss:0.59062	validation_0-auc:0.97977	validation_1-logloss:0.62701	validation_1-auc:0.86277
# [400]	validation_0-logloss:0.59061	validation_0-auc:0.97977	validation_1-logloss:0.62701	validation_1-auc:0.86277
# [401]	validation_0-logloss:0.59060	validation_0-auc:0.97977	validation_1-logloss:0.62700	validation_1-auc:0.86277
# [402]	validation_0-logloss:0.59059	validation_0-auc:0.97977	validation_1-logloss:0.62699	validation_1-auc:0.86277
# [403]	validation_0-logloss:0.59059	validation_0-auc:0.97976	validation_1-logloss:0.62699	validation_1-auc:0.86277
# [404]	validation_0-logloss:0.59021	validation_0-auc:0.97980	validation_1-logloss:0.62672	validation_1-auc:0.86300
# [405]	validation_0-logloss:0.59020	validation_0-auc:0.97981	validation_1-logloss:0.62672	validation_1-auc:0.86300
# [406]	validation_0-logloss:0.59019	validation_0-auc:0.97981	validation_1-logloss:0.62672	validation_1-auc:0.86300
# [407]	validation_0-logloss:0.59018	validation_0-auc:0.97980	validation_1-logloss:0.62671	validation_1-auc:0.86300
# [408]	validation_0-logloss:0.59017	validation_0-auc:0.97980	validation_1-logloss:0.62670	validation_1-auc:0.86300
# [409]	validation_0-logloss:0.59017	validation_0-auc:0.97980	validation_1-logloss:0.62670	validation_1-auc:0.86300
# [410]	validation_0-logloss:0.58977	validation_0-auc:0.97981	validation_1-logloss:0.62646	validation_1-auc:0.86353
# [411]	validation_0-logloss:0.58976	validation_0-auc:0.97981	validation_1-logloss:0.62645	validation_1-auc:0.86353
# [412]	validation_0-logloss:0.58939	validation_0-auc:0.97986	validation_1-logloss:0.62623	validation_1-auc:0.86323
# [413]	validation_0-logloss:0.58939	validation_0-auc:0.97985	validation_1-logloss:0.62622	validation_1-auc:0.86323
# [414]	validation_0-logloss:0.58938	validation_0-auc:0.97985	validation_1-logloss:0.62621	validation_1-auc:0.86323
# [415]	validation_0-logloss:0.58937	validation_0-auc:0.97985	validation_1-logloss:0.62621	validation_1-auc:0.86323
# [416]	validation_0-logloss:0.58899	validation_0-auc:0.97991	validation_1-logloss:0.62594	validation_1-auc:0.86376
# [417]	validation_0-logloss:0.58860	validation_0-auc:0.97998	validation_1-logloss:0.62572	validation_1-auc:0.86391
# [418]	validation_0-logloss:0.58859	validation_0-auc:0.97998	validation_1-logloss:0.62571	validation_1-auc:0.86391
# [419]	validation_0-logloss:0.58820	validation_0-auc:0.98003	validation_1-logloss:0.62547	validation_1-auc:0.86399
# [420]	validation_0-logloss:0.58819	validation_0-auc:0.98002	validation_1-logloss:0.62546	validation_1-auc:0.86399
# [421]	validation_0-logloss:0.58818	validation_0-auc:0.98002	validation_1-logloss:0.62546	validation_1-auc:0.86399
# [422]	validation_0-logloss:0.58779	validation_0-auc:0.98010	validation_1-logloss:0.62520	validation_1-auc:0.86414
# [423]	validation_0-logloss:0.58740	validation_0-auc:0.98015	validation_1-logloss:0.62497	validation_1-auc:0.86445
# [424]	validation_0-logloss:0.58739	validation_0-auc:0.98014	validation_1-logloss:0.62497	validation_1-auc:0.86445
# [425]	validation_0-logloss:0.58738	validation_0-auc:0.98014	validation_1-logloss:0.62496	validation_1-auc:0.86445
# [426]	validation_0-logloss:0.58702	validation_0-auc:0.98019	validation_1-logloss:0.62473	validation_1-auc:0.86430
# [427]	validation_0-logloss:0.58663	validation_0-auc:0.98029	validation_1-logloss:0.62449	validation_1-auc:0.86468
# [428]	validation_0-logloss:0.58662	validation_0-auc:0.98028	validation_1-logloss:0.62448	validation_1-auc:0.86468
# [429]	validation_0-logloss:0.58624	validation_0-auc:0.98032	validation_1-logloss:0.62427	validation_1-auc:0.86499
# [430]	validation_0-logloss:0.58623	validation_0-auc:0.98032	validation_1-logloss:0.62426	validation_1-auc:0.86499
# ...
# [1862]	validation_0-logloss:0.38550	validation_0-auc:0.99515	validation_1-logloss:0.49831	validation_1-auc:0.89197
# [1863]	validation_0-logloss:0.38550	validation_0-auc:0.99515	validation_1-logloss:0.49831	validation_1-auc:0.89197
# [1864]	validation_0-logloss:0.38550	validation_0-auc:0.99515	validation_1-logloss:0.49831	validation_1-auc:0.89197
# [1865]	validation_0-logloss:0.38550	validation_0-auc:0.99515	validation_1-logloss:0.49831	validation_1-auc:0.89197
# [1866]	validation_0-logloss:0.38549	validation_0-auc:0.99515	validation_1-logloss:0.49831	validation_1-auc:0.89197
# [1867]	validation_0-logloss:0.38549	validation_0-auc:0.99515	validation_1-logloss:0.49831	validation_1-auc:0.89197
# [1868]	validation_0-logloss:0.38528	validation_0-auc:0.99517	validation_1-logloss:0.49818	validation_1-auc:0.89182
# [1869]	validation_0-logloss:0.38528	validation_0-auc:0.99517	validation_1-logloss:0.49818	validation_1-auc:0.89182
# [1870]	validation_0-logloss:0.38510	validation_0-auc:0.99518	validation_1-logloss:0.49808	validation_1-auc:0.89197
# [1871]	validation_0-logloss:0.38492	validation_0-auc:0.99518	validation_1-logloss:0.49798	validation_1-auc:0.89197
# [1872]	validation_0-logloss:0.38492	validation_0-auc:0.99518	validation_1-logloss:0.49798	validation_1-auc:0.89197
# [1873]	validation_0-logloss:0.38474	validation_0-auc:0.99521	validation_1-logloss:0.49784	validation_1-auc:0.89220
# [1874]	validation_0-logloss:0.38452	validation_0-auc:0.99523	validation_1-logloss:0.49772	validation_1-auc:0.89212
# [1875]	validation_0-logloss:0.38434	validation_0-auc:0.99525	validation_1-logloss:0.49763	validation_1-auc:0.89205
# [1876]	validation_0-logloss:0.38434	validation_0-auc:0.99525	validation_1-logloss:0.49763	validation_1-auc:0.89205
# [1877]	validation_0-logloss:0.38434	validation_0-auc:0.99525	validation_1-logloss:0.49763	validation_1-auc:0.89205
# [1878]	validation_0-logloss:0.38411	validation_0-auc:0.99527	validation_1-logloss:0.49749	validation_1-auc:0.89197
# [1879]	validation_0-logloss:0.38393	validation_0-auc:0.99527	validation_1-logloss:0.49738	validation_1-auc:0.89212
# [1880]	validation_0-logloss:0.38375	validation_0-auc:0.99528	validation_1-logloss:0.49727	validation_1-auc:0.89220
# [1881]	validation_0-logloss:0.38375	validation_0-auc:0.99528	validation_1-logloss:0.49727	validation_1-auc:0.89220
# [1882]	validation_0-logloss:0.38375	validation_0-auc:0.99528	validation_1-logloss:0.49727	validation_1-auc:0.89220
# [1883]	validation_0-logloss:0.38354	validation_0-auc:0.99531	validation_1-logloss:0.49715	validation_1-auc:0.89228
# [1884]	validation_0-logloss:0.38336	validation_0-auc:0.99533	validation_1-logloss:0.49704	validation_1-auc:0.89251
# [1885]	validation_0-logloss:0.38336	validation_0-auc:0.99533	validation_1-logloss:0.49704	validation_1-auc:0.89251
# [1886]	validation_0-logloss:0.38336	validation_0-auc:0.99533	validation_1-logloss:0.49704	validation_1-auc:0.89251
# [1887]	validation_0-logloss:0.38336	validation_0-auc:0.99533	validation_1-logloss:0.49704	validation_1-auc:0.89251
# [1888]	validation_0-logloss:0.38318	validation_0-auc:0.99535	validation_1-logloss:0.49695	validation_1-auc:0.89251
# [1889]	validation_0-logloss:0.38296	validation_0-auc:0.99536	validation_1-logloss:0.49683	validation_1-auc:0.89243
# [1890]	validation_0-logloss:0.38296	validation_0-auc:0.99536	validation_1-logloss:0.49683	validation_1-auc:0.89243
# [1891]	validation_0-logloss:0.38278	validation_0-auc:0.99537	validation_1-logloss:0.49673	validation_1-auc:0.89251
# [1892]	validation_0-logloss:0.38260	validation_0-auc:0.99537	validation_1-logloss:0.49665	validation_1-auc:0.89236
# [1893]	validation_0-logloss:0.38260	validation_0-auc:0.99537	validation_1-logloss:0.49665	validation_1-auc:0.89236
# [1894]	validation_0-logloss:0.38260	validation_0-auc:0.99537	validation_1-logloss:0.49665	validation_1-auc:0.89236
# [1895]	validation_0-logloss:0.38238	validation_0-auc:0.99540	validation_1-logloss:0.49653	validation_1-auc:0.89243
# [1896]	validation_0-logloss:0.38220	validation_0-auc:0.99542	validation_1-logloss:0.49642	validation_1-auc:0.89266
# [1897]	validation_0-logloss:0.38220	validation_0-auc:0.99542	validation_1-logloss:0.49642	validation_1-auc:0.89258
# [1898]	validation_0-logloss:0.38202	validation_0-auc:0.99543	validation_1-logloss:0.49633	validation_1-auc:0.89281
# [1899]	validation_0-logloss:0.38180	validation_0-auc:0.99545	validation_1-logloss:0.49620	validation_1-auc:0.89266
# [1900]	validation_0-logloss:0.38180	validation_0-auc:0.99545	validation_1-logloss:0.49620	validation_1-auc:0.89266
# [1901]	validation_0-logloss:0.38163	validation_0-auc:0.99546	validation_1-logloss:0.49610	validation_1-auc:0.89281
# [1902]	validation_0-logloss:0.38145	validation_0-auc:0.99546	validation_1-logloss:0.49601	validation_1-auc:0.89289
# [1903]	validation_0-logloss:0.38145	validation_0-auc:0.99546	validation_1-logloss:0.49601	validation_1-auc:0.89289
# [1904]	validation_0-logloss:0.38124	validation_0-auc:0.99547	validation_1-logloss:0.49591	validation_1-auc:0.89297
# [1905]	validation_0-logloss:0.38124	validation_0-auc:0.99547	validation_1-logloss:0.49591	validation_1-auc:0.89297
# [1906]	validation_0-logloss:0.38107	validation_0-auc:0.99547	validation_1-logloss:0.49577	validation_1-auc:0.89304
# [1907]	validation_0-logloss:0.38089	validation_0-auc:0.99549	validation_1-logloss:0.49567	validation_1-auc:0.89304
# [1908]	validation_0-logloss:0.38067	validation_0-auc:0.99552	validation_1-logloss:0.49556	validation_1-auc:0.89320
# [1909]	validation_0-logloss:0.38067	validation_0-auc:0.99552	validation_1-logloss:0.49555	validation_1-auc:0.89320
# [1910]	validation_0-logloss:0.38067	validation_0-auc:0.99552	validation_1-logloss:0.49555	validation_1-auc:0.89320
# [1911]	validation_0-logloss:0.38067	validation_0-auc:0.99552	validation_1-logloss:0.49555	validation_1-auc:0.89320
# [1912]	validation_0-logloss:0.38067	validation_0-auc:0.99552	validation_1-logloss:0.49555	validation_1-auc:0.89320
# [1913]	validation_0-logloss:0.38067	validation_0-auc:0.99552	validation_1-logloss:0.49555	validation_1-auc:0.89320
# [1914]	validation_0-logloss:0.38067	validation_0-auc:0.99552	validation_1-logloss:0.49555	validation_1-auc:0.89320
# [1915]	validation_0-logloss:0.38049	validation_0-auc:0.99552	validation_1-logloss:0.49546	validation_1-auc:0.89304
# [1916]	validation_0-logloss:0.38049	validation_0-auc:0.99552	validation_1-logloss:0.49546	validation_1-auc:0.89304
# [1917]	validation_0-logloss:0.38049	validation_0-auc:0.99552	validation_1-logloss:0.49546	validation_1-auc:0.89304
# [1918]	validation_0-logloss:0.38049	validation_0-auc:0.99552	validation_1-logloss:0.49546	validation_1-auc:0.89304
# [1919]	validation_0-logloss:0.38049	validation_0-auc:0.99552	validation_1-logloss:0.49546	validation_1-auc:0.89304
# [1920]	validation_0-logloss:0.38031	validation_0-auc:0.99551	validation_1-logloss:0.49535	validation_1-auc:0.89343
# [1921]	validation_0-logloss:0.38010	validation_0-auc:0.99553	validation_1-logloss:0.49524	validation_1-auc:0.89358
# [1922]	validation_0-logloss:0.37992	validation_0-auc:0.99553	validation_1-logloss:0.49514	validation_1-auc:0.89358
# [1923]	validation_0-logloss:0.37992	validation_0-auc:0.99553	validation_1-logloss:0.49514	validation_1-auc:0.89358
# [1924]	validation_0-logloss:0.37992	validation_0-auc:0.99553	validation_1-logloss:0.49514	validation_1-auc:0.89358
# [1925]	validation_0-logloss:0.37975	validation_0-auc:0.99555	validation_1-logloss:0.49501	validation_1-auc:0.89365
# [1926]	validation_0-logloss:0.37975	validation_0-auc:0.99555	validation_1-logloss:0.49500	validation_1-auc:0.89365
# [1927]	validation_0-logloss:0.37975	validation_0-auc:0.99555	validation_1-logloss:0.49500	validation_1-auc:0.89365
# [1928]	validation_0-logloss:0.37975	validation_0-auc:0.99555	validation_1-logloss:0.49500	validation_1-auc:0.89365
# [1929]	validation_0-logloss:0.37953	validation_0-auc:0.99557	validation_1-logloss:0.49489	validation_1-auc:0.89381
# [1930]	validation_0-logloss:0.37953	validation_0-auc:0.99557	validation_1-logloss:0.49489	validation_1-auc:0.89381
# [1931]	validation_0-logloss:0.37936	validation_0-auc:0.99557	validation_1-logloss:0.49478	validation_1-auc:0.89388
# [1932]	validation_0-logloss:0.37914	validation_0-auc:0.99559	validation_1-logloss:0.49467	validation_1-auc:0.89388
# [1933]	validation_0-logloss:0.37914	validation_0-auc:0.99559	validation_1-logloss:0.49467	validation_1-auc:0.89388
# [1934]	validation_0-logloss:0.37914	validation_0-auc:0.99559	validation_1-logloss:0.49467	validation_1-auc:0.89388
# [1935]	validation_0-logloss:0.37896	validation_0-auc:0.99561	validation_1-logloss:0.49457	validation_1-auc:0.89381
# [1936]	validation_0-logloss:0.37879	validation_0-auc:0.99562	validation_1-logloss:0.49447	validation_1-auc:0.89388
# [1937]	validation_0-logloss:0.37857	validation_0-auc:0.99564	validation_1-logloss:0.49436	validation_1-auc:0.89388
# [1938]	validation_0-logloss:0.37857	validation_0-auc:0.99564	validation_1-logloss:0.49436	validation_1-auc:0.89388
# [1939]	validation_0-logloss:0.37839	validation_0-auc:0.99565	validation_1-logloss:0.49428	validation_1-auc:0.89396
# [1940]	validation_0-logloss:0.37839	validation_0-auc:0.99565	validation_1-logloss:0.49428	validation_1-auc:0.89396
# [1941]	validation_0-logloss:0.37817	validation_0-auc:0.99567	validation_1-logloss:0.49417	validation_1-auc:0.89388
# [1942]	validation_0-logloss:0.37817	validation_0-auc:0.99567	validation_1-logloss:0.49417	validation_1-auc:0.89388
# [1943]	validation_0-logloss:0.37800	validation_0-auc:0.99569	validation_1-logloss:0.49407	validation_1-auc:0.89411
# [1944]	validation_0-logloss:0.37782	validation_0-auc:0.99571	validation_1-logloss:0.49397	validation_1-auc:0.89411
# [1945]	validation_0-logloss:0.37782	validation_0-auc:0.99571	validation_1-logloss:0.49397	validation_1-auc:0.89411
# [1946]	validation_0-logloss:0.37765	validation_0-auc:0.99572	validation_1-logloss:0.49386	validation_1-auc:0.89411
# [1947]	validation_0-logloss:0.37765	validation_0-auc:0.99572	validation_1-logloss:0.49386	validation_1-auc:0.89411
# [1948]	validation_0-logloss:0.37743	validation_0-auc:0.99575	validation_1-logloss:0.49375	validation_1-auc:0.89411
# [1949]	validation_0-logloss:0.37743	validation_0-auc:0.99575	validation_1-logloss:0.49375	validation_1-auc:0.89411
# [1950]	validation_0-logloss:0.37743	validation_0-auc:0.99575	validation_1-logloss:0.49375	validation_1-auc:0.89411
# [1951]	validation_0-logloss:0.37726	validation_0-auc:0.99577	validation_1-logloss:0.49362	validation_1-auc:0.89427
# [1952]	validation_0-logloss:0.37705	validation_0-auc:0.99579	validation_1-logloss:0.49351	validation_1-auc:0.89427
# [1953]	validation_0-logloss:0.37687	validation_0-auc:0.99579	validation_1-logloss:0.49343	validation_1-auc:0.89419
# [1954]	validation_0-logloss:0.37670	validation_0-auc:0.99580	validation_1-logloss:0.49332	validation_1-auc:0.89419
# [1955]	validation_0-logloss:0.37670	validation_0-auc:0.99580	validation_1-logloss:0.49332	validation_1-auc:0.89419
# [1956]	validation_0-logloss:0.37670	validation_0-auc:0.99580	validation_1-logloss:0.49332	validation_1-auc:0.89419
# [1957]	validation_0-logloss:0.37648	validation_0-auc:0.99583	validation_1-logloss:0.49322	validation_1-auc:0.89419
# [1958]	validation_0-logloss:0.37630	validation_0-auc:0.99583	validation_1-logloss:0.49314	validation_1-auc:0.89411
# [1959]	validation_0-logloss:0.37630	validation_0-auc:0.99583	validation_1-logloss:0.49314	validation_1-auc:0.89411
# [1960]	validation_0-logloss:0.37613	validation_0-auc:0.99584	validation_1-logloss:0.49304	validation_1-auc:0.89411
# [1961]	validation_0-logloss:0.37592	validation_0-auc:0.99585	validation_1-logloss:0.49293	validation_1-auc:0.89411
# [1962]	validation_0-logloss:0.37575	validation_0-auc:0.99585	validation_1-logloss:0.49283	validation_1-auc:0.89419
# [1963]	validation_0-logloss:0.37575	validation_0-auc:0.99585	validation_1-logloss:0.49283	validation_1-auc:0.89419
# [1964]	validation_0-logloss:0.37554	validation_0-auc:0.99586	validation_1-logloss:0.49273	validation_1-auc:0.89396
# [1965]	validation_0-logloss:0.37537	validation_0-auc:0.99588	validation_1-logloss:0.49259	validation_1-auc:0.89434
# [1966]	validation_0-logloss:0.37537	validation_0-auc:0.99588	validation_1-logloss:0.49259	validation_1-auc:0.89434
# [1967]	validation_0-logloss:0.37520	validation_0-auc:0.99589	validation_1-logloss:0.49249	validation_1-auc:0.89427
# [1968]	validation_0-logloss:0.37520	validation_0-auc:0.99589	validation_1-logloss:0.49249	validation_1-auc:0.89427
# [1969]	validation_0-logloss:0.37503	validation_0-auc:0.99590	validation_1-logloss:0.49240	validation_1-auc:0.89442
# [1970]	validation_0-logloss:0.37483	validation_0-auc:0.99590	validation_1-logloss:0.49230	validation_1-auc:0.89442
# [1971]	validation_0-logloss:0.37466	validation_0-auc:0.99589	validation_1-logloss:0.49219	validation_1-auc:0.89442
# [1972]	validation_0-logloss:0.37466	validation_0-auc:0.99589	validation_1-logloss:0.49219	validation_1-auc:0.89442
# [1973]	validation_0-logloss:0.37449	validation_0-auc:0.99590	validation_1-logloss:0.49206	validation_1-auc:0.89457
# [1974]	validation_0-logloss:0.37428	validation_0-auc:0.99593	validation_1-logloss:0.49195	validation_1-auc:0.89480
# [1975]	validation_0-logloss:0.37411	validation_0-auc:0.99594	validation_1-logloss:0.49187	validation_1-auc:0.89480
# [1976]	validation_0-logloss:0.37395	validation_0-auc:0.99593	validation_1-logloss:0.49178	validation_1-auc:0.89465
# [1977]	validation_0-logloss:0.37373	validation_0-auc:0.99595	validation_1-logloss:0.49167	validation_1-auc:0.89465
# [1978]	validation_0-logloss:0.37356	validation_0-auc:0.99596	validation_1-logloss:0.49158	validation_1-auc:0.89488
# [1979]	validation_0-logloss:0.37356	validation_0-auc:0.99596	validation_1-logloss:0.49158	validation_1-auc:0.89488
# [1980]	validation_0-logloss:0.37356	validation_0-auc:0.99596	validation_1-logloss:0.49158	validation_1-auc:0.89488
# [1981]	validation_0-logloss:0.37356	validation_0-auc:0.99596	validation_1-logloss:0.49158	validation_1-auc:0.89488
# [1982]	validation_0-logloss:0.37335	validation_0-auc:0.99599	validation_1-logloss:0.49147	validation_1-auc:0.89472
# [1983]	validation_0-logloss:0.37335	validation_0-auc:0.99599	validation_1-logloss:0.49147	validation_1-auc:0.89472
# [1984]	validation_0-logloss:0.37318	validation_0-auc:0.99598	validation_1-logloss:0.49136	validation_1-auc:0.89480
# [1985]	validation_0-logloss:0.37301	validation_0-auc:0.99598	validation_1-logloss:0.49123	validation_1-auc:0.89503
# [1986]	validation_0-logloss:0.37279	validation_0-auc:0.99599	validation_1-logloss:0.49111	validation_1-auc:0.89511
# [1987]	validation_0-logloss:0.37279	validation_0-auc:0.99599	validation_1-logloss:0.49111	validation_1-auc:0.89511
# [1988]	validation_0-logloss:0.37261	validation_0-auc:0.99601	validation_1-logloss:0.49103	validation_1-auc:0.89518
# [1989]	validation_0-logloss:0.37261	validation_0-auc:0.99601	validation_1-logloss:0.49103	validation_1-auc:0.89518
# [1990]	validation_0-logloss:0.37261	validation_0-auc:0.99601	validation_1-logloss:0.49103	validation_1-auc:0.89518
# [1991]	validation_0-logloss:0.37261	validation_0-auc:0.99601	validation_1-logloss:0.49102	validation_1-auc:0.89518
# [1992]	validation_0-logloss:0.37261	validation_0-auc:0.99601	validation_1-logloss:0.49102	validation_1-auc:0.89518
# [1993]	validation_0-logloss:0.37245	validation_0-auc:0.99600	validation_1-logloss:0.49093	validation_1-auc:0.89503
# [1994]	validation_0-logloss:0.37245	validation_0-auc:0.99600	validation_1-logloss:0.49093	validation_1-auc:0.89503
# [1995]	validation_0-logloss:0.37224	validation_0-auc:0.99601	validation_1-logloss:0.49082	validation_1-auc:0.89511
# [1996]	validation_0-logloss:0.37224	validation_0-auc:0.99601	validation_1-logloss:0.49082	validation_1-auc:0.89511
# [1997]	validation_0-logloss:0.37207	validation_0-auc:0.99603	validation_1-logloss:0.49073	validation_1-auc:0.89526
# [1998]	validation_0-logloss:0.37207	validation_0-auc:0.99603	validation_1-logloss:0.49073	validation_1-auc:0.89526
# [1999]	validation_0-logloss:0.37207	validation_0-auc:0.99603	validation_1-logloss:0.49073	validation_1-auc:0.89526
# Accuracy: 0.830

# %%
# plot learning curves
pyplot.plot(results['validation_0']['auc'], label='train')
pyplot.plot(results['validation_1']['auc'], label='test')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()

# %%
print(classification_report(y_test,model.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.78      0.90      0.83       109
#          2.0       0.89      0.77      0.83       120
#
#     accuracy                           0.83       229
#    macro avg       0.84      0.83      0.83       229
# weighted avg       0.84      0.83      0.83       229

# %%
print(confusion_matrix(y_test,model.predict(X_test)))
# Out:
# [[98 11]
#  [28 92]]

# %% [markdown]
# # lazy

# %%
import lazypredict
### importing LazyClassifier for classification problem
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric =None)
### fitting data in LazyClassifier
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
### lets check which model did better on Breast Cancer Dataset
# Out:
# 100%|██████████| 29/29 [00:07<00:00,  3.90it/s]

# %%
predictions
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# XGBClassifier                      0.86               0.86     0.86      0.86
# RandomForestClassifier             0.85               0.85     0.85      0.85
# ExtraTreesClassifier               0.84               0.85     0.85      0.84
# LGBMClassifier                     0.85               0.85     0.85      0.85
# KNeighborsClassifier               0.83               0.83     0.83      0.83
# SGDClassifier                      0.81               0.81     0.81      0.81
# LabelSpreading                     0.79               0.80     0.80      0.79
# LabelPropagation                   0.79               0.80     0.80      0.79
# NuSVC                              0.80               0.80     0.80      0.80
# BaggingClassifier                  0.79               0.79     0.79      0.79
# RidgeClassifier                    0.79               0.79     0.79      0.79
# LinearSVC                          0.79               0.78     0.78      0.79
# AdaBoostClassifier                 0.78               0.78     0.78      0.78
# LogisticRegression                 0.78               0.78     0.78      0.78
# LinearDiscriminantAnalysis         0.74               0.74     0.74      0.74
# CalibratedClassifierCV             0.75               0.74     0.74      0.74
# RidgeClassifierCV                  0.71               0.70     0.70      0.70
# Perceptron                         0.70               0.70     0.70      0.69
# DecisionTreeClassifier             0.69               0.68     0.68      0.68
# QuadraticDiscriminantAnalysis      0.67               0.67     0.67      0.67
# PassiveAggressiveClassifier        0.68               0.66     0.66      0.64
# ExtraTreeClassifier                0.66               0.66     0.66      0.66
# BernoulliNB                        0.59               0.61     0.61      0.53
# NearestCentroid                    0.55               0.57     0.57      0.46
# GaussianNB                         0.49               0.51     0.51      0.34
# SVC                                0.53               0.51     0.51      0.38
# DummyClassifier                    0.51               0.50     0.50      0.50
#
#                                Time Taken
# Model
# XGBClassifier                        0.88
# RandomForestClassifier               0.66
# ExtraTreesClassifier                 0.31
# LGBMClassifier                       0.81
# KNeighborsClassifier                 0.12
# SGDClassifier                        0.11
# LabelSpreading                       0.12
# LabelPropagation                     0.11
# NuSVC                                0.31
# BaggingClassifier                    0.60
# RidgeClassifier                      0.04
# LinearSVC                            0.35
# AdaBoostClassifier                   0.66
# LogisticRegression                   0.12
# LinearDiscriminantAnalysis           0.15
# CalibratedClassifierCV               1.04
# RidgeClassifierCV                    0.08
# Perceptron                           0.05
# DecisionTreeClassifier               0.12
# QuadraticDiscriminantAnalysis        0.10
# PassiveAggressiveClassifier          0.05
# ExtraTreeClassifier                  0.03
# BernoulliNB                          0.04
# NearestCentroid                      0.04
# GaussianNB                           0.03
# SVC                                  0.35
# DummyClassifier                      0.03
