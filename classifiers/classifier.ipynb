# %% [markdown]
# **Load Drive data into VM machine**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Install & Import required Libraries**

# %%
#!pip install lazypredict

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler,MinMaxScaler,RobustScaler
from sklearn.model_selection import train_test_split
import lazypredict
### importing LazyClassifier for classification problem
from lazypredict.Supervised import LazyClassifier
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Preprocessing Class**

# %%
class PreProcessing:
    def __init__(self,filename):
        self.df = pd.read_csv('/content/drive/MyDrive/multiscale_entropy/auto_encoder/{}'.format(filename),header=None)
        self.y = self.df[self.df.shape[1]-1].values
        self.X = None
    def clean_data(self):
        self.df = self.df.replace([np.inf, -np.inf], np.nan).dropna(axis=1)
        self.df = self.df.dropna(axis = 0, how = 'all')
        self.df = self.df.T.fillna(self.df.mean(axis=1)).T
        print('------------------------ Data Cleaned Sucessfully --------------------')
    def scale_data(self):
        cols_to_scale = list(self.df.columns)[:-1]
        scaler = StandardScaler()
        self.df[cols_to_scale] = scaler.fit_transform(self.df[cols_to_scale])
        print('------------------------ Data Scaled Sucessfully --------------------')

    def convert_dataset(self):
        self.clean_data()
        self.scale_data()
        self.X = self.df.drop([self.df.shape[1]-1], axis=1)
        return self.X,self.y

# %% [markdown]
# **Training With Lazy Classifier**

# %%
class Training:
    def __init__(self,X,y):
        self.X = X
        self.y = y
    def split_data(self):
        self.X_train, self.X_test, self.y_train, self.y_test = train_test_split(self.X, self.y, test_size=0.2, random_state=123)
    def train(self):
        self.split_data()
        clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric =None)
        ### fitting data in LazyClassifier
        #print('------------------------ Training Starts --------------------')

        self.models,self.predictions = clf.fit(self.X_train, self.X_test, self.y_train, self.y_test)
    def results(self):
        self.train()
        return self.predictions

# %% [markdown]
# # Sample Entropy with 100 channel

# %%
X,y = PreProcessing('sample_data_ch_100.csv').convert_dataset()
# Out:
# ------------------------ Data Cleaned Sucessfully --------------------
# ------------------------ Data Scaled Sucessfully --------------------

# %%
Training(X,y).results()
# Out:
# 100%|██████████| 29/29 [00:06<00:00,  4.70it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     0.93               0.92     0.92      0.93
# RandomForestClassifier             0.91               0.91     0.91      0.91
# ExtraTreesClassifier               0.90               0.90     0.90      0.90
# XGBClassifier                      0.89               0.89     0.89      0.89
# LabelSpreading                     0.88               0.88     0.88      0.88
# LabelPropagation                   0.88               0.88     0.88      0.88
# BaggingClassifier                  0.87               0.87     0.87      0.87
# CalibratedClassifierCV             0.86               0.86     0.86      0.86
# KNeighborsClassifier               0.86               0.86     0.86      0.86
# LinearSVC                          0.86               0.86     0.86      0.86
# NuSVC                              0.84               0.84     0.84      0.84
# LinearDiscriminantAnalysis         0.84               0.84     0.84      0.84
# AdaBoostClassifier                 0.83               0.83     0.83      0.83
# QuadraticDiscriminantAnalysis      0.82               0.83     0.83      0.82
# SVC                                0.83               0.83     0.83      0.83
# RidgeClassifierCV                  0.82               0.82     0.82      0.82
# Perceptron                         0.82               0.81     0.81      0.82
# DecisionTreeClassifier             0.81               0.81     0.81      0.81
# RidgeClassifier                    0.80               0.80     0.80      0.80
# LogisticRegression                 0.80               0.80     0.80      0.80
# ExtraTreeClassifier                0.80               0.80     0.80      0.80
# PassiveAggressiveClassifier        0.81               0.80     0.80      0.80
# SGDClassifier                      0.78               0.78     0.78      0.78
# NearestCentroid                    0.72               0.74     0.74      0.71
# GaussianNB                         0.71               0.73     0.73      0.70
# BernoulliNB                        0.69               0.71     0.71      0.69
# DummyClassifier                    0.47               0.46     0.46      0.47
#
#                                Time Taken
# Model
# LGBMClassifier                       1.14
# RandomForestClassifier               0.66
# ExtraTreesClassifier                 0.25
# XGBClassifier                        0.76
# LabelSpreading                       0.10
# LabelPropagation                     0.08
# BaggingClassifier                    0.42
# CalibratedClassifierCV               0.83
# KNeighborsClassifier                 0.05
# LinearSVC                            0.21
# NuSVC                                0.16
# LinearDiscriminantAnalysis           0.08
# AdaBoostClassifier                   0.62
# QuadraticDiscriminantAnalysis        0.05
# SVC                                  0.14
# RidgeClassifierCV                    0.05
# Perceptron                           0.04
# DecisionTreeClassifier               0.11
# RidgeClassifier                      0.03
# LogisticRegression                   0.10
# ExtraTreeClassifier                  0.02
# PassiveAggressiveClassifier          0.03
# SGDClassifier                        0.05
# NearestCentroid                      0.03
# GaussianNB                           0.03
# BernoulliNB                          0.03
# DummyClassifier                      0.02

# %% [markdown]
# # Sample Entropy with 50 channel

# %%
X,y = PreProcessing('sample_data_ch_50.csv').convert_dataset()
# Out:
# ------------------------ Data Cleaned Sucessfully --------------------
# ------------------------ Data Scaled Sucessfully --------------------

# %%
Training(X,y).results()
# Out:
# 100%|██████████| 29/29 [00:03<00:00,  7.31it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     0.95               0.95     0.95      0.95
# RandomForestClassifier             0.93               0.93     0.93      0.93
# XGBClassifier                      0.93               0.93     0.93      0.93
# ExtraTreesClassifier               0.92               0.92     0.92      0.92
# KNeighborsClassifier               0.90               0.90     0.90      0.90
# LabelSpreading                     0.90               0.90     0.90      0.90
# LabelPropagation                   0.90               0.90     0.90      0.90
# BaggingClassifier                  0.89               0.89     0.89      0.89
# AdaBoostClassifier                 0.89               0.89     0.89      0.89
# SVC                                0.87               0.87     0.87      0.87
# NuSVC                              0.87               0.87     0.87      0.87
# SGDClassifier                      0.86               0.87     0.87      0.86
# PassiveAggressiveClassifier        0.85               0.85     0.85      0.85
# LinearSVC                          0.84               0.84     0.84      0.84
# CalibratedClassifierCV             0.83               0.83     0.83      0.83
# LogisticRegression                 0.83               0.83     0.83      0.83
# DecisionTreeClassifier             0.83               0.83     0.83      0.83
# ExtraTreeClassifier                0.83               0.82     0.82      0.83
# RidgeClassifierCV                  0.80               0.81     0.81      0.80
# Perceptron                         0.81               0.80     0.80      0.81
# QuadraticDiscriminantAnalysis      0.78               0.79     0.79      0.77
# LinearDiscriminantAnalysis         0.78               0.79     0.79      0.78
# RidgeClassifier                    0.78               0.78     0.78      0.78
# GaussianNB                         0.74               0.76     0.76      0.73
# NearestCentroid                    0.71               0.72     0.72      0.71
# BernoulliNB                        0.71               0.72     0.72      0.71
# DummyClassifier                    0.47               0.46     0.46      0.47
#
#                                Time Taken
# Model
# LGBMClassifier                       0.59
# RandomForestClassifier               0.51
# XGBClassifier                        0.41
# ExtraTreesClassifier                 0.24
# KNeighborsClassifier                 0.05
# LabelSpreading                       0.09
# LabelPropagation                     0.07
# BaggingClassifier                    0.24
# AdaBoostClassifier                   0.37
# SVC                                  0.11
# NuSVC                                0.11
# SGDClassifier                        0.03
# PassiveAggressiveClassifier          0.03
# LinearSVC                            0.15
# CalibratedClassifierCV               0.43
# LogisticRegression                   0.11
# DecisionTreeClassifier               0.07
# ExtraTreeClassifier                  0.03
# RidgeClassifierCV                    0.04
# Perceptron                           0.03
# QuadraticDiscriminantAnalysis        0.03
# LinearDiscriminantAnalysis           0.04
# RidgeClassifier                      0.03
# GaussianNB                           0.02
# NearestCentroid                      0.03
# BernoulliNB                          0.02
# DummyClassifier                      0.03

# %% [markdown]
# # Sample Entropy with 10 channel

# %%
X,y = PreProcessing('sample_data_ch_10.csv').convert_dataset()
# Out:
# ------------------------ Data Cleaned Sucessfully --------------------
# ------------------------ Data Scaled Sucessfully --------------------

# %%
Training(X,y).results()
# Out:
# 100%|██████████| 29/29 [00:02<00:00, 13.61it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# XGBClassifier                      0.86               0.86     0.86      0.86
# RandomForestClassifier             0.85               0.85     0.85      0.85
# ExtraTreesClassifier               0.84               0.84     0.84      0.84
# LGBMClassifier                     0.84               0.84     0.84      0.84
# BaggingClassifier                  0.82               0.82     0.82      0.82
# NuSVC                              0.79               0.80     0.80      0.79
# KNeighborsClassifier               0.79               0.80     0.80      0.80
# SVC                                0.77               0.79     0.79      0.77
# AdaBoostClassifier                 0.77               0.77     0.77      0.77
# DecisionTreeClassifier             0.78               0.77     0.77      0.78
# ExtraTreeClassifier                0.76               0.75     0.75      0.76
# LinearSVC                          0.74               0.75     0.75      0.73
# LogisticRegression                 0.73               0.75     0.75      0.73
# LabelPropagation                   0.74               0.74     0.74      0.74
# LabelSpreading                     0.74               0.74     0.74      0.74
# CalibratedClassifierCV             0.73               0.74     0.74      0.73
# QuadraticDiscriminantAnalysis      0.71               0.73     0.73      0.69
# LinearDiscriminantAnalysis         0.71               0.73     0.73      0.71
# RidgeClassifierCV                  0.71               0.73     0.73      0.71
# RidgeClassifier                    0.71               0.73     0.73      0.71
# GaussianNB                         0.69               0.72     0.72      0.68
# SGDClassifier                      0.72               0.71     0.71      0.72
# CategoricalNB                      0.69               0.71     0.71      0.68
# NearestCentroid                    0.69               0.71     0.71      0.67
# BernoulliNB                        0.67               0.69     0.69      0.66
# PassiveAggressiveClassifier        0.68               0.67     0.67      0.68
# Perceptron                         0.64               0.62     0.62      0.61
# DummyClassifier                    0.47               0.46     0.46      0.47
#
#                                Time Taken
# Model
# XGBClassifier                        0.14
# RandomForestClassifier               0.34
# ExtraTreesClassifier                 0.23
# LGBMClassifier                       0.17
# BaggingClassifier                    0.08
# NuSVC                                0.06
# KNeighborsClassifier                 0.03
# SVC                                  0.07
# AdaBoostClassifier                   0.17
# DecisionTreeClassifier               0.02
# ExtraTreeClassifier                  0.01
# LinearSVC                            0.12
# LogisticRegression                   0.03
# LabelPropagation                     0.08
# LabelSpreading                       0.10
# CalibratedClassifierCV               0.18
# QuadraticDiscriminantAnalysis        0.02
# LinearDiscriminantAnalysis           0.03
# RidgeClassifierCV                    0.04
# RidgeClassifier                      0.02
# GaussianNB                           0.02
# SGDClassifier                        0.06
# CategoricalNB                        0.02
# NearestCentroid                      0.02
# BernoulliNB                          0.02
# PassiveAggressiveClassifier          0.02
# Perceptron                           0.02
# DummyClassifier                      0.01

# %% [markdown]
# # Approx Entropy with 100 channel

# %%
X,y = PreProcessing('approx_data_ch_100.csv').convert_dataset()

# %%
Training(X,y).results()

# %% [markdown]
# # Approx Entropy with 50 channel

# %%
X,y = PreProcessing('approx_data_ch_50.csv').convert_dataset()
# Out:
# ------------------------ Data Cleaned Sucessfully --------------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-cbdb218a5fed> in <module>()
# ----> 1 X,y = PreProcessing('approx_data_ch_50.csv').convert_dataset()
#
# <ipython-input-26-03edc950fb6c> in convert_dataset(self)
#      17     def convert_dataset(self):
#      18         self.clean_data()
# ---> 19         self.scale_data()
#      20         self.X = self.df.drop([self.df.shape[1]-1], axis=1)
#      21         return self.X,self.y
#
# <ipython-input-26-03edc950fb6c> in scale_data(self)
#      12         cols_to_scale = list(self.df.columns)[:-1]
#      13         scaler = StandardScaler()
# ---> 14         self.df[cols_to_scale] = scaler.fit_transform(self.df[cols_to_scale])
#      15         print('------------------------ Data Scaled Sucessfully --------------------')
#      16
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     688         if y is None:
#     689             # fit method of arity 1 (unsupervised transformation)
# --> 690             return self.fit(X, **fit_params).transform(X)
#     691         else:
#     692             # fit method of arity 2 (supervised transformation)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py in fit(self, X, y)
#     665         # Reset internal state before fitting
#     666         self._reset()
# --> 667         return self.partial_fit(X, y)
#     668
#     669     def partial_fit(self, X, y=None):
#
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py in partial_fit(self, X, y)
#     696         X = self._validate_data(X, accept_sparse=('csr', 'csc'),
#     697                                 estimator=self, dtype=FLOAT_DTYPES,
# --> 698                                 force_all_finite='allow-nan')
#     699
#     700         # Even in the case of `with_mean=False`, we update the mean anyway
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     418                     f"requires y to be passed, but the target y is None."
#     419                 )
# --> 420             X = check_array(X, **check_params)
#     421             out = X
#     422         else:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     532
#     533         if all(isinstance(dtype, np.dtype) for dtype in dtypes_orig):
# --> 534             dtype_orig = np.result_type(*dtypes_orig)
#     535
#     536     if dtype_numeric:
#
# <__array_function__ internals> in result_type(*args, **kwargs)
#
# ValueError: at least one array or dtype is required

# %%
Training(X,y).results()

# %% [markdown]
# # Approx Entropy with 10 channel

# %%
X,y = PreProcessing('approx_data_ch_10.csv').convert_dataset()

# %%
Training(X,y).results()

# %% [markdown]
# # Permute Entropy with 100 channel

# %%
X,y = PreProcessing('permute_data_ch_100.csv').convert_dataset()
# Out:
# ------------------------ Data Cleaned Sucessfully --------------------
# ------------------------ Data Scaled Sucessfully --------------------

# %%
Training(X,y).results()
# Out:
# 100%|██████████| 29/29 [00:06<00:00,  4.18it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# QuadraticDiscriminantAnalysis      0.66               0.68     0.68      0.64
# LinearDiscriminantAnalysis         0.63               0.63     0.63      0.63
# CalibratedClassifierCV             0.61               0.61     0.61      0.61
# NuSVC                              0.59               0.60     0.60      0.58
# LogisticRegression                 0.59               0.60     0.60      0.59
# AdaBoostClassifier                 0.59               0.59     0.59      0.59
# LabelSpreading                     0.59               0.59     0.59      0.59
# LinearSVC                          0.58               0.59     0.59      0.58
# LabelPropagation                   0.59               0.59     0.59      0.59
# KNeighborsClassifier               0.59               0.59     0.59      0.59
# GaussianNB                         0.55               0.58     0.58      0.47
# RandomForestClassifier             0.57               0.58     0.58      0.57
# BernoulliNB                        0.54               0.57     0.57      0.46
# BaggingClassifier                  0.57               0.57     0.57      0.57
# LGBMClassifier                     0.57               0.56     0.56      0.57
# ExtraTreesClassifier               0.56               0.56     0.56      0.56
# NearestCentroid                    0.52               0.56     0.56      0.43
# SVC                                0.55               0.56     0.56      0.54
# XGBClassifier                      0.54               0.54     0.54      0.54
# ExtraTreeClassifier                0.54               0.53     0.53      0.54
# DecisionTreeClassifier             0.52               0.52     0.52      0.52
# Perceptron                         0.55               0.50     0.50      0.39
# RidgeClassifierCV                  0.55               0.50     0.50      0.39
# SGDClassifier                      0.55               0.50     0.50      0.39
# RidgeClassifier                    0.53               0.49     0.49      0.39
# PassiveAggressiveClassifier        0.53               0.48     0.48      0.38
# DummyClassifier                    0.47               0.46     0.46      0.47
#
#                                Time Taken
# Model
# QuadraticDiscriminantAnalysis        0.05
# LinearDiscriminantAnalysis           0.06
# CalibratedClassifierCV               1.12
# NuSVC                                0.14
# LogisticRegression                   0.04
# AdaBoostClassifier                   0.53
# LabelSpreading                       0.10
# LinearSVC                            0.29
# LabelPropagation                     0.08
# KNeighborsClassifier                 0.05
# GaussianNB                           0.02
# RandomForestClassifier               0.69
# BernoulliNB                          0.04
# BaggingClassifier                    0.47
# LGBMClassifier                       1.33
# ExtraTreesClassifier                 0.30
# NearestCentroid                      0.03
# SVC                                  0.23
# XGBClassifier                        0.92
# ExtraTreeClassifier                  0.02
# DecisionTreeClassifier               0.12
# Perceptron                           0.03
# RidgeClassifierCV                    0.05
# SGDClassifier                        0.04
# RidgeClassifier                      0.03
# PassiveAggressiveClassifier          0.03
# DummyClassifier                      0.02

# %% [markdown]
# # Permute Entropy with 50 channel

# %%
X,y = PreProcessing('permute_data_ch_50.csv').convert_dataset()
# Out:
# ------------------------ Data Cleaned Sucessfully --------------------
# ------------------------ Data Scaled Sucessfully --------------------

# %%
Training(X,y).results()
# Out:
# 100%|██████████| 29/29 [00:02<00:00, 12.97it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# PassiveAggressiveClassifier        0.55               0.58     0.58      0.47
# SGDClassifier                      0.54               0.58     0.58      0.45
# GaussianNB                         0.54               0.58     0.58      0.45
# BaggingClassifier                  0.56               0.57     0.57      0.56
# QuadraticDiscriminantAnalysis      0.52               0.56     0.56      0.43
# ExtraTreesClassifier               0.55               0.56     0.56      0.54
# RandomForestClassifier             0.55               0.56     0.56      0.55
# AdaBoostClassifier                 0.55               0.55     0.55      0.55
# DecisionTreeClassifier             0.54               0.55     0.55      0.53
# LGBMClassifier                     0.54               0.54     0.54      0.54
# NearestCentroid                    0.49               0.54     0.54      0.36
# BernoulliNB                        0.49               0.54     0.54      0.36
# XGBClassifier                      0.53               0.53     0.53      0.53
# ExtraTreeClassifier                0.52               0.53     0.53      0.51
# KNeighborsClassifier               0.53               0.53     0.53      0.53
# LinearDiscriminantAnalysis         0.52               0.51     0.51      0.51
# Perceptron                         0.55               0.50     0.50      0.39
# RidgeClassifier                    0.55               0.50     0.50      0.39
# SVC                                0.55               0.50     0.50      0.39
# RidgeClassifierCV                  0.55               0.50     0.50      0.39
# LabelPropagation                   0.55               0.50     0.50      0.39
# CalibratedClassifierCV             0.55               0.50     0.50      0.39
# LabelSpreading                     0.55               0.50     0.50      0.39
# LogisticRegression                 0.55               0.50     0.50      0.39
# LinearSVC                          0.55               0.50     0.50      0.39
# DummyClassifier                    0.47               0.46     0.46      0.47
# NuSVC                              0.41               0.43     0.43      0.39
#
#                                Time Taken
# Model
# PassiveAggressiveClassifier          0.03
# SGDClassifier                        0.04
# GaussianNB                           0.02
# BaggingClassifier                    0.07
# QuadraticDiscriminantAnalysis        0.03
# ExtraTreesClassifier                 0.24
# RandomForestClassifier               0.32
# AdaBoostClassifier                   0.17
# DecisionTreeClassifier               0.03
# LGBMClassifier                       0.14
# NearestCentroid                      0.03
# BernoulliNB                          0.02
# XGBClassifier                        0.24
# ExtraTreeClassifier                  0.03
# KNeighborsClassifier                 0.05
# LinearDiscriminantAnalysis           0.04
# Perceptron                           0.03
# RidgeClassifier                      0.03
# SVC                                  0.14
# RidgeClassifierCV                    0.04
# LabelPropagation                     0.08
# CalibratedClassifierCV               0.10
# LabelSpreading                       0.11
# LogisticRegression                   0.04
# LinearSVC                            0.04
# DummyClassifier                      0.03
# NuSVC                                0.10

# %% [markdown]
# # Permute Entropy with 10 channel

# %%
X,y = PreProcessing('permute_data_ch_10.csv').convert_dataset()
# Out:
# ------------------------ Data Cleaned Sucessfully --------------------
# ------------------------ Data Scaled Sucessfully --------------------

# %%
Training(X,y).results()
# Out:
# 100%|██████████| 29/29 [00:01<00:00, 19.08it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# NuSVC                              0.58               0.61     0.61      0.52
# QuadraticDiscriminantAnalysis      0.55               0.59     0.59      0.47
# KNeighborsClassifier               0.59               0.58     0.58      0.59
# AdaBoostClassifier                 0.58               0.58     0.58      0.58
# GaussianNB                         0.54               0.58     0.58      0.44
# XGBClassifier                      0.55               0.56     0.56      0.56
# Perceptron                         0.50               0.54     0.54      0.38
# ExtraTreesClassifier               0.54               0.54     0.54      0.54
# SGDClassifier                      0.50               0.54     0.54      0.37
# DecisionTreeClassifier             0.53               0.54     0.54      0.53
# RandomForestClassifier             0.54               0.54     0.54      0.54
# ExtraTreeClassifier                0.53               0.54     0.54      0.53
# NearestCentroid                    0.49               0.54     0.54      0.36
# BernoulliNB                        0.49               0.54     0.54      0.36
# PassiveAggressiveClassifier        0.49               0.54     0.54      0.36
# LGBMClassifier                     0.53               0.53     0.53      0.53
# BaggingClassifier                  0.52               0.53     0.53      0.52
# LogisticRegression                 0.55               0.50     0.50      0.39
# LabelSpreading                     0.55               0.50     0.50      0.39
# LabelPropagation                   0.55               0.50     0.50      0.39
# RidgeClassifier                    0.55               0.50     0.50      0.39
# RidgeClassifierCV                  0.55               0.50     0.50      0.39
# SVC                                0.55               0.50     0.50      0.39
# CalibratedClassifierCV             0.55               0.50     0.50      0.39
# LinearSVC                          0.55               0.50     0.50      0.39
# LinearDiscriminantAnalysis         0.52               0.49     0.49      0.46
# DummyClassifier                    0.47               0.46     0.46      0.47
#
#                                Time Taken
# Model
# NuSVC                                0.04
# QuadraticDiscriminantAnalysis        0.01
# KNeighborsClassifier                 0.03
# AdaBoostClassifier                   0.13
# GaussianNB                           0.02
# XGBClassifier                        0.08
# Perceptron                           0.02
# ExtraTreesClassifier                 0.19
# SGDClassifier                        0.03
# DecisionTreeClassifier               0.02
# RandomForestClassifier               0.24
# ExtraTreeClassifier                  0.02
# NearestCentroid                      0.02
# BernoulliNB                          0.02
# PassiveAggressiveClassifier          0.02
# LGBMClassifier                       0.08
# BaggingClassifier                    0.05
# LogisticRegression                   0.06
# LabelSpreading                       0.09
# LabelPropagation                     0.07
# RidgeClassifier                      0.02
# RidgeClassifierCV                    0.02
# SVC                                  0.08
# CalibratedClassifierCV               0.06
# LinearSVC                            0.04
# LinearDiscriminantAnalysis           0.03
# DummyClassifier                      0.01

# %% [markdown]
# # Renyi Entropy with 100 channel

# %%
X,y = PreProcessing('renyi_data_ch_100.csv').convert_dataset()

# %%
Training(X,y).results()

# %% [markdown]
# # Renyi Entropy with 50 channel

# %%
X,y = PreProcessing('renyi_data_ch_50.csv').convert_dataset()

# %%
Training(X,y).results()

# %% [markdown]
# # Renyi Entropy with 10 channel

# %%
X,y = PreProcessing('renyi_data_ch_10.csv').convert_dataset()
# Out:
# ------------------------ Data Cleaned Sucessfully --------------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-8562999b1e81> in <module>()
# ----> 1 X,y = PreProcessing('renyi_data_ch_10.csv').convert_dataset()
#
# <ipython-input-26-03edc950fb6c> in convert_dataset(self)
#      17     def convert_dataset(self):
#      18         self.clean_data()
# ---> 19         self.scale_data()
#      20         self.X = self.df.drop([self.df.shape[1]-1], axis=1)
#      21         return self.X,self.y
#
# <ipython-input-26-03edc950fb6c> in scale_data(self)
#      12         cols_to_scale = list(self.df.columns)[:-1]
#      13         scaler = StandardScaler()
# ---> 14         self.df[cols_to_scale] = scaler.fit_transform(self.df[cols_to_scale])
#      15         print('------------------------ Data Scaled Sucessfully --------------------')
#      16
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     688         if y is None:
#     689             # fit method of arity 1 (unsupervised transformation)
# --> 690             return self.fit(X, **fit_params).transform(X)
#     691         else:
#     692             # fit method of arity 2 (supervised transformation)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py in fit(self, X, y)
#     665         # Reset internal state before fitting
#     666         self._reset()
# --> 667         return self.partial_fit(X, y)
#     668
#     669     def partial_fit(self, X, y=None):
#
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py in partial_fit(self, X, y)
#     696         X = self._validate_data(X, accept_sparse=('csr', 'csc'),
#     697                                 estimator=self, dtype=FLOAT_DTYPES,
# --> 698                                 force_all_finite='allow-nan')
#     699
#     700         # Even in the case of `with_mean=False`, we update the mean anyway
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     418                     f"requires y to be passed, but the target y is None."
#     419                 )
# --> 420             X = check_array(X, **check_params)
#     421             out = X
#     422         else:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     532
#     533         if all(isinstance(dtype, np.dtype) for dtype in dtypes_orig):
# --> 534             dtype_orig = np.result_type(*dtypes_orig)
#     535
#     536     if dtype_numeric:
#
# <__array_function__ internals> in result_type(*args, **kwargs)
#
# ValueError: at least one array or dtype is required

# %%
Training(X,y).results()
