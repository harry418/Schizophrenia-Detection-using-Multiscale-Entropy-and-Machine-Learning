# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install lazypredict
# Out:
# Requirement already satisfied: lazypredict in /usr/local/lib/python3.7/dist-packages (0.2.9)
# Requirement already satisfied: scikit-learn==0.23.1 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (0.23.1)
# Requirement already satisfied: joblib==1.0.0 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.0.0)
# Requirement already satisfied: click==7.1.2 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (7.1.2)
# Requirement already satisfied: pytest==5.4.3 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (5.4.3)
# Requirement already satisfied: numpy==1.19.1 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.19.1)
# Requirement already satisfied: tqdm==4.56.0 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (4.56.0)
# Requirement already satisfied: six==1.15.0 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.15.0)
# Requirement already satisfied: scipy==1.5.4 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.5.4)
# Requirement already satisfied: lightgbm==2.3.1 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (2.3.1)
# Requirement already satisfied: xgboost==1.1.1 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.1.1)
# Requirement already satisfied: PyYAML==5.3.1 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (5.3.1)
# Requirement already satisfied: pandas==1.0.5 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.0.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas==1.0.5->lazypredict) (2018.9)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from pandas==1.0.5->lazypredict) (2.8.2)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (1.11.0)
# Requirement already satisfied: pluggy<1.0,>=0.12 in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (0.13.1)
# Requirement already satisfied: importlib-metadata>=0.12 in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (4.11.3)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (8.12.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (21.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (21.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (0.2.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.23.1->lazypredict) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.12->pytest==5.4.3->lazypredict) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.12->pytest==5.4.3->lazypredict) (3.7.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->pytest==5.4.3->lazypredict) (3.0.7)

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/multiscale_entropy/calculated_entropy/permute_data.csv',header=None)

# %%
import numpy as np
y = df[df.shape[1]-1].values
df=df.replace([np.inf, -np.inf], np.nan).dropna(axis=1)

df=df.T.fillna(df.mean(axis=1)).T

# %%
df.tail()
# Out:
#           0        1        2        3        4        5        6        7    \
# 1137  0.69310  0.69262  0.69254  0.69314  0.69310  0.69315  0.69315  0.69223
# 1138  0.69285  0.69299  0.69268  0.69308  0.69273  0.69315  0.69298  0.69234
# 1139  0.69186  0.69136  0.69016  0.69311  0.69306  0.69315  0.69304  0.69200
# 1140  0.69223  0.69300  0.69315  0.69314  0.69306  0.69315  0.69313  0.69308
# 1141  0.69314  0.69292  0.69311  0.69315  0.69312  0.69257  0.69290  0.69302
#
#           8        9    ...      181      182      183      184      185  \
# 1137  0.69314  0.69311  ...  0.69291  0.69295  0.69291  0.69315  0.62224
# 1138  0.69305  0.69229  ...  0.69312  0.69311  0.69308  0.69297 -0.00000
# 1139  0.69131  0.69311  ...  0.69215  0.69212  0.69211  0.69225  0.69113
# 1140  0.69302  0.69305  ...  0.67632  0.67456  0.67475  0.67549 -0.00000
# 1141  0.69121  0.69315  ...  0.69227  0.69169  0.69171  0.69196 -0.00000
#
#           186      187      188      189  190
# 1137  0.69295  0.69310  0.69293  0.69290  2.0
# 1138  0.69313  0.69306  0.69314  0.69314  2.0
# 1139  0.69188  0.69194  0.69186  0.69214  2.0
# 1140  0.67444  0.67463  0.67450  0.67438  2.0
# 1141  0.69144  0.69167  0.69166  0.69162  2.0
#
# [5 rows x 191 columns]

# %%
cols_to_scale = list(df.columns)[:-1]
from sklearn.preprocessing import StandardScaler,MinMaxScaler,RobustScaler
scaler = StandardScaler()
df[cols_to_scale] = scaler.fit_transform(df[cols_to_scale])

# %%
df.shape
# Out:
# (1142, 191)

# %%
X = df.drop([df.shape[1]-1], axis=1)

# %%
X.shape
# Out:
# (1142, 190)

# %%
from collections import Counter
print(Counter(y))
# Out:
# Counter({2: 626, 1: 516})

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()

logreg.fit(X_train,y_train)
print(logreg.score(X_test,y_test))
from sklearn.metrics import confusion_matrix,classification_report
print(classification_report(y_test,logreg.predict(X_test)))
# Out:
# 0.7816593886462883
#               precision    recall  f1-score   support
#
#            1       0.76      0.76      0.76       104
#            2       0.80      0.80      0.80       125
#
#     accuracy                           0.78       229
#    macro avg       0.78      0.78      0.78       229
# weighted avg       0.78      0.78      0.78       229

# %% [markdown]
# svm

# %%
from sklearn.svm import SVC
svm = SVC(kernel = 'linear')
svm.fit(X_train,y_train)
svm.score(X_test,y_test)
# Out:
# 0.7685589519650655

# %%
print(classification_report(y_test,svm.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.75      0.73      0.74       104
#            2       0.78      0.80      0.79       125
#
#     accuracy                           0.77       229
#    macro avg       0.77      0.77      0.77       229
# weighted avg       0.77      0.77      0.77       229

# %% [markdown]
# # New Section

# %%
'''Set a seed for reproducibility'''
seed = 43

'''Initialize all the regression models object we are interested in.'''
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier,ExtraTreesClassifier,GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

'''We are interested in the following 14 regression models.
All initialized with default parameters except random_state and n_jobs.'''


et = ExtraTreesClassifier(n_jobs = -1, random_state = seed)
ab = AdaBoostClassifier(random_state = seed)
gb = GradientBoostingClassifier(random_state = seed)
xgb = XGBClassifier(random_state = seed, n_jobs = -1)
lgb = LGBMClassifier(random_state = seed, n_jobs = -1)

knn = KNeighborsClassifier(3)
lsvm = SVC(kernel="linear", C=0.025)
rsvm = SVC(kernel="rbf",gamma=2, C=1)
gps = GaussianProcessClassifier(1.0 * RBF(1.0))
dt = DecisionTreeClassifier(max_depth=5)
rf = RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1)
mlp = MLPClassifier(alpha=1, max_iter=1000)
gnb = GaussianNB()
qda = QuadraticDiscriminantAnalysis()

# %%
'''Evaluate models on the holdout set(say on 30%).'''
def train_test_split_score(model):
    from sklearn.metrics import mean_squared_error
    from sklearn.model_selection import train_test_split
    X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size = 0.2, random_state = seed)
    model.fit(X_train, Y_train)
    return model.score(X_test,Y_test)
'''Calculate train_test_split score of differnt models and plot them.'''
models = [et,ab,gb,xgb,lgb,knn,lsvm,rsvm,gps,dt,rf,mlp,gnb,qda]
train_test_split_res = []
for model in models:
    train_test_split_res.append(train_test_split_score(model))

'''Plot data frame of train test rmse'''
train_test_score = pd.DataFrame(data = train_test_split_res, columns = ['Train_Test_SCORE'])
train_test_score.index = ['ET', 'AB', 'GB', 'XGB', 'LGB', 'KNN', 'LSVM', 'RSVM', 'GPS', 'DT', 'RF', 'MLP', 'GNB', 'QDA']
train_test_score = train_test_score.round(5)
train_test_score
# Out:
#       Train_Test_SCORE
# ET             0.81659
# AB             0.74672
# GB             0.80786
# XGB            0.78603
# LGB            0.82096
# KNN            0.64192
# LSVM           0.73799
# RSVM           0.55459
# GPS            0.75983
# DT             0.70306
# RF             0.62445
# MLP            0.79913
# GNB            0.59389
# QDA            0.71616

# %%
def cross_validate(model):
    from sklearn.model_selection import cross_val_score
    score = cross_val_score(model, X, y, cv = 10, n_jobs = -1, scoring = 'accuracy')
    return score.mean()

'''Calculate cross validation score of differnt models and plot them.'''
models = [et,ab,gb,xgb,lgb,knn,lsvm,rsvm,gps,dt,rf,mlp,gnb,qda]
cross_val_scores = []
for model in models:
    cross_val_scores.append(cross_validate(model))

'''Plot data frame of cross validation scores.'''
x_val_score = pd.DataFrame(data = cross_val_scores, columns = ['Cross Validation Scores (ACC)'])
x_val_score.index = ['ET', 'AB', 'GB', 'XGB', 'LGB', 'KNN', 'LSVM', 'RSVM', 'GPS', 'DT', 'RF', 'MLP', 'GNB', 'QDA']

# %%
x_val_score
# Out:
#       Cross Validation Scores (ACC)
# ET                         0.682273
# AB                         0.627941
# GB                         0.666415
# XGB                        0.668177
# LGB                        0.673509
# KNN                        0.595538
# LSVM                       0.617567
# RSVM                       0.548162
# GPS                        0.582326
# DT                         0.550831
# RF                         0.563158
# MLP                        0.634157
# GNB                        0.586125
# QDA                        0.640481

# %%
'''Create a function to plot learning curves.'''
import matplotlib.pyplot as plt
import numpy as np

def plot_learning_curve(model):
    from sklearn.model_selection import learning_curve
    
    # df_train_final is training matrix and y_train is target matrix.
    # Create CV training and test scores for various training set sizes
    train_sizes, train_scores, test_scores = learning_curve(model, X, y, 
                                            train_sizes = np.linspace(0.01, 1.0, 20), cv = 10, scoring = 'accuracy', 
                                            n_jobs = -1, random_state = seed)
    
    
    # Create means and standard deviations of training set scores
    train_mean = np.mean(train_scores, axis = 1)
    train_std = np.std(train_scores, axis = 1)

    # Create means and standard deviations of test set scores
    test_mean = np.mean(test_scores, axis = 1)
    test_std = np.std(test_scores, axis = 1)  
    # Draw lines
    plt.plot(train_sizes, train_mean, 'o-', color = 'red',  label = 'Training score')
    plt.plot(train_sizes, test_mean, 'o-', color = 'green', label = 'Cross-validation score')
    
    # Draw bands
    plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, alpha = 0.1, color = 'r') # Alpha controls band transparency.
    plt.fill_between(train_sizes, test_mean - test_std, test_mean + test_std, alpha = 0.1, color = 'g')
    
    
    # Create plot
    font_size = 12
    plt.xlabel('Training Set Size', fontsize = font_size)
    plt.ylabel('Accuracy Score', fontsize = font_size)
    plt.xticks(fontsize = font_size)
    plt.yticks(fontsize = font_size)
    plt.legend(loc = 'best')
    plt.grid()

# %%
'''Now plot learning curves of the optimized models in subplots.
For computational reason, I am omitting XGB, GB, and LGB.'''
plt.figure(figsize = (16,24))
lc_models = [et,ab,gb,xgb,lgb,knn,lsvm,rsvm,gps,dt,rf,mlp,gnb,qda]
lc_labels = ['ET', 'AB', 'GB', 'XGB', 'LGB', 'KNN', 'LSVM', 'RSVM', 'GPS', 'DT', 'RF', 'MLP', 'GNB', 'QDA']

for ax, models, labels in zip (range(1,14), lc_models, lc_labels):
    try:
        plt.subplot(7,2,ax)
        plot_learning_curve(models)
        plt.title(labels, fontsize = 15)
    except:
        pass
plt.suptitle('Learning Curves of Optimized Models', fontsize = 20)
plt.tight_layout(rect = [0, 0.03, 1, 0.97])

# %% [markdown]
# # XGB

# %%
import xgboost as xgb
# read in data
'''
dtrain = xgb.DMatrix(X_train,y_train)
dtest = xgb.DMatrix(X_test,y_test)
evallist = [(dtest, 'eval'), (dtrain, 'train')]
# specify parameters via map
param = {'booster': 'dart',
         'max_depth': 5, 'learning_rate': 0.01,
         'objective': 'binary:logistic',
         'sample_type': 'uniform',
         'normalize_type': 'tree',
         'rate_drop': 0.1,
         'eval_metric':'auc',
         'skip_drop': 0.5}
num_round = 500
bst = xgb.train(param, dtrain, num_round,evallist)
preds = bst.predict(dtest)
'''
# Out:
# "\ndtrain = xgb.DMatrix(X_train,y_train)\ndtest = xgb.DMatrix(X_test,y_test)\nevallist = [(dtest, 'eval'), (dtrain, 'train')]\n# specify parameters via map\nparam = {'booster': 'dart',\n         'max_depth': 5, 'learning_rate': 0.01,\n         'objective': 'binary:logistic',\n         'sample_type': 'uniform',\n         'normalize_type': 'tree',\n         'rate_drop': 0.1,\n         'eval_metric':'auc',\n         'skip_drop': 0.5}\nnum_round = 500\nbst = xgb.train(param, dtrain, num_round,evallist)\npreds = bst.predict(dtest)\n"

# %%
#xgb.plot_importance(bst)

# %%
param = {'booster': 'dart',
         'max_depth': 5,
         'learning_rate': 0.001,
         'objective': 'binary:logistic',
         'sample_type': 'uniform',
         'normalize_type': 'tree',
         'rate_drop': 0.1,
         'skip_drop': 0.5,
         'n_estimators':2000}

# %%
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier
from matplotlib import pyplot
# define the model
model = XGBClassifier(**param)
# define the datasets to evaluate each iteration
evalset = [(X_train, y_train), (X_test,y_test)]
# fit the model
model.fit(X_train, y_train, eval_metric=['logloss','auc'], eval_set=evalset)
# evaluate performance
yhat = model.predict(X_test)
score = accuracy_score(y_test, yhat)
print('Accuracy: %.3f' % score)
# retrieve performance metrics
results = model.evals_result()
# plot learning curves
pyplot.plot(results['validation_0']['logloss'], label='train')
pyplot.plot(results['validation_1']['logloss'], label='test')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# [0]	validation_0-logloss:0.69281	validation_0-auc:0.82765	validation_1-logloss:0.69294	validation_1-auc:0.70223
# [1]	validation_0-logloss:0.69248	validation_0-auc:0.82785	validation_1-logloss:0.69273	validation_1-auc:0.70123
# [2]	validation_0-logloss:0.69214	validation_0-auc:0.82724	validation_1-logloss:0.69252	validation_1-auc:0.70627
# [3]	validation_0-logloss:0.69181	validation_0-auc:0.82635	validation_1-logloss:0.69232	validation_1-auc:0.70742
# [4]	validation_0-logloss:0.69147	validation_0-auc:0.82785	validation_1-logloss:0.69212	validation_1-auc:0.70342
# [5]	validation_0-logloss:0.69114	validation_0-auc:0.82785	validation_1-logloss:0.69191	validation_1-auc:0.70365
# [6]	validation_0-logloss:0.69081	validation_0-auc:0.82754	validation_1-logloss:0.69170	validation_1-auc:0.70373
# [7]	validation_0-logloss:0.69048	validation_0-auc:0.82695	validation_1-logloss:0.69150	validation_1-auc:0.70365
# [8]	validation_0-logloss:0.69015	validation_0-auc:0.82635	validation_1-logloss:0.69130	validation_1-auc:0.70365
# [9]	validation_0-logloss:0.68982	validation_0-auc:0.82785	validation_1-logloss:0.69109	validation_1-auc:0.70381
# [10]	validation_0-logloss:0.68949	validation_0-auc:0.82786	validation_1-logloss:0.69090	validation_1-auc:0.70088
# [11]	validation_0-logloss:0.68919	validation_0-auc:0.83892	validation_1-logloss:0.69072	validation_1-auc:0.70265
# [12]	validation_0-logloss:0.68886	validation_0-auc:0.83844	validation_1-logloss:0.69051	validation_1-auc:0.70342
# [13]	validation_0-logloss:0.68871	validation_0-auc:0.84010	validation_1-logloss:0.69043	validation_1-auc:0.70242
# [14]	validation_0-logloss:0.68854	validation_0-auc:0.84037	validation_1-logloss:0.69033	validation_1-auc:0.70242
# [15]	validation_0-logloss:0.68824	validation_0-auc:0.84089	validation_1-logloss:0.69014	validation_1-auc:0.70550
# [16]	validation_0-logloss:0.68794	validation_0-auc:0.84131	validation_1-logloss:0.68996	validation_1-auc:0.70735
# [17]	validation_0-logloss:0.68764	validation_0-auc:0.84304	validation_1-logloss:0.68978	validation_1-auc:0.70519
# [18]	validation_0-logloss:0.68734	validation_0-auc:0.84312	validation_1-logloss:0.68960	validation_1-auc:0.70496
# [19]	validation_0-logloss:0.68704	validation_0-auc:0.84199	validation_1-logloss:0.68942	validation_1-auc:0.70558
# [20]	validation_0-logloss:0.68674	validation_0-auc:0.84231	validation_1-logloss:0.68925	validation_1-auc:0.70450
# [21]	validation_0-logloss:0.68666	validation_0-auc:0.84231	validation_1-logloss:0.68920	validation_1-auc:0.70450
# [22]	validation_0-logloss:0.68651	validation_0-auc:0.84239	validation_1-logloss:0.68911	validation_1-auc:0.70450
# [23]	validation_0-logloss:0.68621	validation_0-auc:0.84291	validation_1-logloss:0.68893	validation_1-auc:0.70535
# [24]	validation_0-logloss:0.68592	validation_0-auc:0.84296	validation_1-logloss:0.68875	validation_1-auc:0.70788
# [25]	validation_0-logloss:0.68577	validation_0-auc:0.84259	validation_1-logloss:0.68866	validation_1-auc:0.70450
# [26]	validation_0-logloss:0.68547	validation_0-auc:0.84247	validation_1-logloss:0.68849	validation_1-auc:0.70450
# [27]	validation_0-logloss:0.68517	validation_0-auc:0.84224	validation_1-logloss:0.68832	validation_1-auc:0.70350
# [28]	validation_0-logloss:0.68488	validation_0-auc:0.84239	validation_1-logloss:0.68814	validation_1-auc:0.70273
# [29]	validation_0-logloss:0.68473	validation_0-auc:0.84239	validation_1-logloss:0.68805	validation_1-auc:0.70265
# [30]	validation_0-logloss:0.68443	validation_0-auc:0.84183	validation_1-logloss:0.68788	validation_1-auc:0.70304
# [31]	validation_0-logloss:0.68414	validation_0-auc:0.84022	validation_1-logloss:0.68770	validation_1-auc:0.70165
# [32]	validation_0-logloss:0.68385	validation_0-auc:0.84041	validation_1-logloss:0.68752	validation_1-auc:0.69873
# [33]	validation_0-logloss:0.68379	validation_0-auc:0.84049	validation_1-logloss:0.68749	validation_1-auc:0.69904
# [34]	validation_0-logloss:0.68372	validation_0-auc:0.84049	validation_1-logloss:0.68744	validation_1-auc:0.69904
# [35]	validation_0-logloss:0.68364	validation_0-auc:0.84049	validation_1-logloss:0.68740	validation_1-auc:0.69904
# [36]	validation_0-logloss:0.68331	validation_0-auc:0.86505	validation_1-logloss:0.68720	validation_1-auc:0.71192
# [37]	validation_0-logloss:0.68298	validation_0-auc:0.86553	validation_1-logloss:0.68699	validation_1-auc:0.71208
# [38]	validation_0-logloss:0.68268	validation_0-auc:0.86551	validation_1-logloss:0.68682	validation_1-auc:0.71254
# [39]	validation_0-logloss:0.68235	validation_0-auc:0.86556	validation_1-logloss:0.68661	validation_1-auc:0.71185
# [40]	validation_0-logloss:0.68225	validation_0-auc:0.86582	validation_1-logloss:0.68655	validation_1-auc:0.71200
# [41]	validation_0-logloss:0.68196	validation_0-auc:0.86546	validation_1-logloss:0.68637	validation_1-auc:0.71239
# [42]	validation_0-logloss:0.68163	validation_0-auc:0.86650	validation_1-logloss:0.68617	validation_1-auc:0.71000
# [43]	validation_0-logloss:0.68129	validation_0-auc:0.86915	validation_1-logloss:0.68596	validation_1-auc:0.70785
# [44]	validation_0-logloss:0.68101	validation_0-auc:0.86865	validation_1-logloss:0.68579	validation_1-auc:0.70739
# [45]	validation_0-logloss:0.68068	validation_0-auc:0.86950	validation_1-logloss:0.68559	validation_1-auc:0.70877
# [46]	validation_0-logloss:0.68039	validation_0-auc:0.86910	validation_1-logloss:0.68542	validation_1-auc:0.70761
# [47]	validation_0-logloss:0.68035	validation_0-auc:0.86902	validation_1-logloss:0.68540	validation_1-auc:0.70715
# [48]	validation_0-logloss:0.68024	validation_0-auc:0.86972	validation_1-logloss:0.68533	validation_1-auc:0.70761
# [49]	validation_0-logloss:0.68015	validation_0-auc:0.86977	validation_1-logloss:0.68527	validation_1-auc:0.70761
# [50]	validation_0-logloss:0.68011	validation_0-auc:0.86971	validation_1-logloss:0.68525	validation_1-auc:0.70761
# [51]	validation_0-logloss:0.67978	validation_0-auc:0.87181	validation_1-logloss:0.68504	validation_1-auc:0.71015
# [52]	validation_0-logloss:0.67973	validation_0-auc:0.87189	validation_1-logloss:0.68501	validation_1-auc:0.71015
# [53]	validation_0-logloss:0.67941	validation_0-auc:0.87669	validation_1-logloss:0.68481	validation_1-auc:0.71269
# [54]	validation_0-logloss:0.67937	validation_0-auc:0.87668	validation_1-logloss:0.68478	validation_1-auc:0.71269
# [55]	validation_0-logloss:0.67929	validation_0-auc:0.87304	validation_1-logloss:0.68474	validation_1-auc:0.71015
# [56]	validation_0-logloss:0.67900	validation_0-auc:0.87278	validation_1-logloss:0.68458	validation_1-auc:0.71015
# [57]	validation_0-logloss:0.67868	validation_0-auc:0.87719	validation_1-logloss:0.68438	validation_1-auc:0.71415
# [58]	validation_0-logloss:0.67839	validation_0-auc:0.87705	validation_1-logloss:0.68421	validation_1-auc:0.71415
# [59]	validation_0-logloss:0.67834	validation_0-auc:0.87711	validation_1-logloss:0.68418	validation_1-auc:0.71423
# [60]	validation_0-logloss:0.67829	validation_0-auc:0.87712	validation_1-logloss:0.68414	validation_1-auc:0.71462
# [61]	validation_0-logloss:0.67796	validation_0-auc:0.87772	validation_1-logloss:0.68394	validation_1-auc:0.71462
# [62]	validation_0-logloss:0.67792	validation_0-auc:0.87772	validation_1-logloss:0.68392	validation_1-auc:0.71462
# [63]	validation_0-logloss:0.67763	validation_0-auc:0.87741	validation_1-logloss:0.68375	validation_1-auc:0.71423
# [64]	validation_0-logloss:0.67758	validation_0-auc:0.87741	validation_1-logloss:0.68371	validation_1-auc:0.71423
# [65]	validation_0-logloss:0.67726	validation_0-auc:0.87835	validation_1-logloss:0.68351	validation_1-auc:0.71431
# [66]	validation_0-logloss:0.67721	validation_0-auc:0.87834	validation_1-logloss:0.68349	validation_1-auc:0.71431
# [67]	validation_0-logloss:0.67716	validation_0-auc:0.87834	validation_1-logloss:0.68346	validation_1-auc:0.71431
# [68]	validation_0-logloss:0.67710	validation_0-auc:0.87834	validation_1-logloss:0.68342	validation_1-auc:0.71431
# [69]	validation_0-logloss:0.67678	validation_0-auc:0.87847	validation_1-logloss:0.68323	validation_1-auc:0.71477
# [70]	validation_0-logloss:0.67649	validation_0-auc:0.87843	validation_1-logloss:0.68307	validation_1-auc:0.71477
# [71]	validation_0-logloss:0.67645	validation_0-auc:0.87843	validation_1-logloss:0.68304	validation_1-auc:0.71477
# [72]	validation_0-logloss:0.67641	validation_0-auc:0.87844	validation_1-logloss:0.68302	validation_1-auc:0.71477
# [73]	validation_0-logloss:0.67609	validation_0-auc:0.87853	validation_1-logloss:0.68281	validation_1-auc:0.71500
# [74]	validation_0-logloss:0.67605	validation_0-auc:0.87852	validation_1-logloss:0.68279	validation_1-auc:0.71500
# [75]	validation_0-logloss:0.67573	validation_0-auc:0.87932	validation_1-logloss:0.68259	validation_1-auc:0.71400
# [76]	validation_0-logloss:0.67570	validation_0-auc:0.87932	validation_1-logloss:0.68257	validation_1-auc:0.71400
# [77]	validation_0-logloss:0.67566	validation_0-auc:0.87932	validation_1-logloss:0.68255	validation_1-auc:0.71400
# [78]	validation_0-logloss:0.67538	validation_0-auc:0.87922	validation_1-logloss:0.68238	validation_1-auc:0.71446
# [79]	validation_0-logloss:0.67506	validation_0-auc:0.87962	validation_1-logloss:0.68220	validation_1-auc:0.71492
# [80]	validation_0-logloss:0.67474	validation_0-auc:0.88064	validation_1-logloss:0.68198	validation_1-auc:0.71688
# [81]	validation_0-logloss:0.67446	validation_0-auc:0.88019	validation_1-logloss:0.68182	validation_1-auc:0.71619
# [82]	validation_0-logloss:0.67413	validation_0-auc:0.88091	validation_1-logloss:0.68161	validation_1-auc:0.71788
# [83]	validation_0-logloss:0.67385	validation_0-auc:0.88056	validation_1-logloss:0.68144	validation_1-auc:0.71804
# [84]	validation_0-logloss:0.67353	validation_0-auc:0.88095	validation_1-logloss:0.68123	validation_1-auc:0.71858
# [85]	validation_0-logloss:0.67325	validation_0-auc:0.88093	validation_1-logloss:0.68108	validation_1-auc:0.71842
# [86]	validation_0-logloss:0.67322	validation_0-auc:0.88093	validation_1-logloss:0.68106	validation_1-auc:0.71842
# [87]	validation_0-logloss:0.67316	validation_0-auc:0.88092	validation_1-logloss:0.68102	validation_1-auc:0.71842
# [88]	validation_0-logloss:0.67310	validation_0-auc:0.88092	validation_1-logloss:0.68098	validation_1-auc:0.71804
# [89]	validation_0-logloss:0.67278	validation_0-auc:0.88107	validation_1-logloss:0.68078	validation_1-auc:0.71873
# [90]	validation_0-logloss:0.67246	validation_0-auc:0.88184	validation_1-logloss:0.68057	validation_1-auc:0.71996
# [91]	validation_0-logloss:0.67243	validation_0-auc:0.88182	validation_1-logloss:0.68055	validation_1-auc:0.71965
# [92]	validation_0-logloss:0.67238	validation_0-auc:0.88183	validation_1-logloss:0.68052	validation_1-auc:0.71996
# [93]	validation_0-logloss:0.67235	validation_0-auc:0.88183	validation_1-logloss:0.68050	validation_1-auc:0.71996
# [94]	validation_0-logloss:0.67231	validation_0-auc:0.88114	validation_1-logloss:0.68048	validation_1-auc:0.71973
# [95]	validation_0-logloss:0.67202	validation_0-auc:0.88111	validation_1-logloss:0.68030	validation_1-auc:0.71981
# [96]	validation_0-logloss:0.67199	validation_0-auc:0.88111	validation_1-logloss:0.68029	validation_1-auc:0.71988
# [97]	validation_0-logloss:0.67195	validation_0-auc:0.88110	validation_1-logloss:0.68026	validation_1-auc:0.72027
# [98]	validation_0-logloss:0.67163	validation_0-auc:0.88226	validation_1-logloss:0.68006	validation_1-auc:0.72169
# [99]	validation_0-logloss:0.67160	validation_0-auc:0.88228	validation_1-logloss:0.68004	validation_1-auc:0.72185
# [100]	validation_0-logloss:0.67156	validation_0-auc:0.88228	validation_1-logloss:0.68001	validation_1-auc:0.72185
# [101]	validation_0-logloss:0.67125	validation_0-auc:0.88231	validation_1-logloss:0.67981	validation_1-auc:0.72292
# [102]	validation_0-logloss:0.67122	validation_0-auc:0.88247	validation_1-logloss:0.67980	validation_1-auc:0.72431
# [103]	validation_0-logloss:0.67119	validation_0-auc:0.88231	validation_1-logloss:0.67978	validation_1-auc:0.72292
# [104]	validation_0-logloss:0.67118	validation_0-auc:0.88236	validation_1-logloss:0.67977	validation_1-auc:0.72292
# [105]	validation_0-logloss:0.67115	validation_0-auc:0.88236	validation_1-logloss:0.67976	validation_1-auc:0.72277
# [106]	validation_0-logloss:0.67087	validation_0-auc:0.88231	validation_1-logloss:0.67958	validation_1-auc:0.72408
# [107]	validation_0-logloss:0.67055	validation_0-auc:0.88217	validation_1-logloss:0.67938	validation_1-auc:0.72454
# [108]	validation_0-logloss:0.67027	validation_0-auc:0.88325	validation_1-logloss:0.67922	validation_1-auc:0.72511
# [109]	validation_0-logloss:0.67025	validation_0-auc:0.88319	validation_1-logloss:0.67921	validation_1-auc:0.72511
# [110]	validation_0-logloss:0.67023	validation_0-auc:0.88324	validation_1-logloss:0.67919	validation_1-auc:0.72542
# [111]	validation_0-logloss:0.66990	validation_0-auc:0.88359	validation_1-logloss:0.67899	validation_1-auc:0.72519
# [112]	validation_0-logloss:0.66963	validation_0-auc:0.88358	validation_1-logloss:0.67883	validation_1-auc:0.72535
# [113]	validation_0-logloss:0.66960	validation_0-auc:0.88354	validation_1-logloss:0.67881	validation_1-auc:0.72527
# [114]	validation_0-logloss:0.66928	validation_0-auc:0.88356	validation_1-logloss:0.67862	validation_1-auc:0.72542
# [115]	validation_0-logloss:0.66897	validation_0-auc:0.88410	validation_1-logloss:0.67842	validation_1-auc:0.72689
# [116]	validation_0-logloss:0.66895	validation_0-auc:0.88406	validation_1-logloss:0.67841	validation_1-auc:0.72689
# [117]	validation_0-logloss:0.66867	validation_0-auc:0.88404	validation_1-logloss:0.67824	validation_1-auc:0.72542
# [118]	validation_0-logloss:0.66836	validation_0-auc:0.88439	validation_1-logloss:0.67805	validation_1-auc:0.72458
# [119]	validation_0-logloss:0.66833	validation_0-auc:0.88430	validation_1-logloss:0.67803	validation_1-auc:0.72458
# [120]	validation_0-logloss:0.66831	validation_0-auc:0.88430	validation_1-logloss:0.67802	validation_1-auc:0.72458
# [121]	validation_0-logloss:0.66829	validation_0-auc:0.88430	validation_1-logloss:0.67800	validation_1-auc:0.72481
# [122]	validation_0-logloss:0.66800	validation_0-auc:0.88463	validation_1-logloss:0.67783	validation_1-auc:0.72511
# [123]	validation_0-logloss:0.66798	validation_0-auc:0.88463	validation_1-logloss:0.67782	validation_1-auc:0.72511
# [124]	validation_0-logloss:0.66796	validation_0-auc:0.88463	validation_1-logloss:0.67781	validation_1-auc:0.72511
# [125]	validation_0-logloss:0.66764	validation_0-auc:0.88493	validation_1-logloss:0.67761	validation_1-auc:0.72504
# [126]	validation_0-logloss:0.66734	validation_0-auc:0.88453	validation_1-logloss:0.67742	validation_1-auc:0.72458
# [127]	validation_0-logloss:0.66705	validation_0-auc:0.88473	validation_1-logloss:0.67725	validation_1-auc:0.72404
# [128]	validation_0-logloss:0.66703	validation_0-auc:0.88473	validation_1-logloss:0.67723	validation_1-auc:0.72404
# [129]	validation_0-logloss:0.66671	validation_0-auc:0.88473	validation_1-logloss:0.67704	validation_1-auc:0.72450
# [130]	validation_0-logloss:0.66669	validation_0-auc:0.88472	validation_1-logloss:0.67703	validation_1-auc:0.72435
# [131]	validation_0-logloss:0.66642	validation_0-auc:0.88471	validation_1-logloss:0.67687	validation_1-auc:0.72550
# [132]	validation_0-logloss:0.66640	validation_0-auc:0.88471	validation_1-logloss:0.67686	validation_1-auc:0.72550
# [133]	validation_0-logloss:0.66608	validation_0-auc:0.88475	validation_1-logloss:0.67666	validation_1-auc:0.72550
# [134]	validation_0-logloss:0.66605	validation_0-auc:0.88473	validation_1-logloss:0.67664	validation_1-auc:0.72550
# [135]	validation_0-logloss:0.66579	validation_0-auc:0.88471	validation_1-logloss:0.67649	validation_1-auc:0.72558
# [136]	validation_0-logloss:0.66547	validation_0-auc:0.88577	validation_1-logloss:0.67629	validation_1-auc:0.72519
# [137]	validation_0-logloss:0.66517	validation_0-auc:0.88594	validation_1-logloss:0.67610	validation_1-auc:0.72565
# [138]	validation_0-logloss:0.66515	validation_0-auc:0.88593	validation_1-logloss:0.67609	validation_1-auc:0.72565
# [139]	validation_0-logloss:0.66487	validation_0-auc:0.88587	validation_1-logloss:0.67592	validation_1-auc:0.72381
# [140]	validation_0-logloss:0.66455	validation_0-auc:0.88595	validation_1-logloss:0.67572	validation_1-auc:0.72450
# [141]	validation_0-logloss:0.66452	validation_0-auc:0.88595	validation_1-logloss:0.67570	validation_1-auc:0.72450
# [142]	validation_0-logloss:0.66449	validation_0-auc:0.88595	validation_1-logloss:0.67569	validation_1-auc:0.72450
# [143]	validation_0-logloss:0.66447	validation_0-auc:0.88596	validation_1-logloss:0.67567	validation_1-auc:0.72458
# [144]	validation_0-logloss:0.66420	validation_0-auc:0.88599	validation_1-logloss:0.67552	validation_1-auc:0.72381
# [145]	validation_0-logloss:0.66389	validation_0-auc:0.88669	validation_1-logloss:0.67533	validation_1-auc:0.72473
# [146]	validation_0-logloss:0.66387	validation_0-auc:0.88666	validation_1-logloss:0.67531	validation_1-auc:0.72473
# [147]	validation_0-logloss:0.66385	validation_0-auc:0.88666	validation_1-logloss:0.67531	validation_1-auc:0.72473
# [148]	validation_0-logloss:0.66358	validation_0-auc:0.88607	validation_1-logloss:0.67515	validation_1-auc:0.72411
# [149]	validation_0-logloss:0.66328	validation_0-auc:0.88669	validation_1-logloss:0.67496	validation_1-auc:0.72396
# [150]	validation_0-logloss:0.66296	validation_0-auc:0.88730	validation_1-logloss:0.67477	validation_1-auc:0.72396
# [151]	validation_0-logloss:0.66270	validation_0-auc:0.88675	validation_1-logloss:0.67461	validation_1-auc:0.72411
# [152]	validation_0-logloss:0.66268	validation_0-auc:0.88675	validation_1-logloss:0.67460	validation_1-auc:0.72411
# [153]	validation_0-logloss:0.66267	validation_0-auc:0.88675	validation_1-logloss:0.67459	validation_1-auc:0.72411
# [154]	validation_0-logloss:0.66264	validation_0-auc:0.88675	validation_1-logloss:0.67458	validation_1-auc:0.72404
# [155]	validation_0-logloss:0.66261	validation_0-auc:0.88675	validation_1-logloss:0.67456	validation_1-auc:0.72411
# [156]	validation_0-logloss:0.66259	validation_0-auc:0.88675	validation_1-logloss:0.67455	validation_1-auc:0.72411
# [157]	validation_0-logloss:0.66228	validation_0-auc:0.88737	validation_1-logloss:0.67435	validation_1-auc:0.72404
# [158]	validation_0-logloss:0.66226	validation_0-auc:0.88738	validation_1-logloss:0.67434	validation_1-auc:0.72404
# [159]	validation_0-logloss:0.66198	validation_0-auc:0.88739	validation_1-logloss:0.67417	validation_1-auc:0.72335
# [160]	validation_0-logloss:0.66168	validation_0-auc:0.88751	validation_1-logloss:0.67400	validation_1-auc:0.72404
# [161]	validation_0-logloss:0.66167	validation_0-auc:0.88751	validation_1-logloss:0.67399	validation_1-auc:0.72404
# [162]	validation_0-logloss:0.66139	validation_0-auc:0.88787	validation_1-logloss:0.67383	validation_1-auc:0.72327
# [163]	validation_0-logloss:0.66110	validation_0-auc:0.88787	validation_1-logloss:0.67365	validation_1-auc:0.72258
# [164]	validation_0-logloss:0.66108	validation_0-auc:0.88787	validation_1-logloss:0.67364	validation_1-auc:0.72273
# [165]	validation_0-logloss:0.66107	validation_0-auc:0.88787	validation_1-logloss:0.67364	validation_1-auc:0.72265
# [166]	validation_0-logloss:0.66105	validation_0-auc:0.88787	validation_1-logloss:0.67362	validation_1-auc:0.72265
# [167]	validation_0-logloss:0.66077	validation_0-auc:0.88801	validation_1-logloss:0.67346	validation_1-auc:0.72304
# [168]	validation_0-logloss:0.66047	validation_0-auc:0.89551	validation_1-logloss:0.67328	validation_1-auc:0.72523
# [169]	validation_0-logloss:0.66045	validation_0-auc:0.89520	validation_1-logloss:0.67327	validation_1-auc:0.72523
# [170]	validation_0-logloss:0.66015	validation_0-auc:0.89599	validation_1-logloss:0.67309	validation_1-auc:0.72592
# [171]	validation_0-logloss:0.65988	validation_0-auc:0.89565	validation_1-logloss:0.67292	validation_1-auc:0.72546
# [172]	validation_0-logloss:0.65986	validation_0-auc:0.89565	validation_1-logloss:0.67292	validation_1-auc:0.72546
# [173]	validation_0-logloss:0.65958	validation_0-auc:0.89614	validation_1-logloss:0.67277	validation_1-auc:0.72538
# [174]	validation_0-logloss:0.65930	validation_0-auc:0.89608	validation_1-logloss:0.67260	validation_1-auc:0.72792
# [175]	validation_0-logloss:0.65899	validation_0-auc:0.89626	validation_1-logloss:0.67241	validation_1-auc:0.72900
# [176]	validation_0-logloss:0.65873	validation_0-auc:0.89643	validation_1-logloss:0.67224	validation_1-auc:0.73019
# [177]	validation_0-logloss:0.65843	validation_0-auc:0.89738	validation_1-logloss:0.67207	validation_1-auc:0.73127
# [178]	validation_0-logloss:0.65817	validation_0-auc:0.89728	validation_1-logloss:0.67192	validation_1-auc:0.73058
# [179]	validation_0-logloss:0.65816	validation_0-auc:0.89707	validation_1-logloss:0.67191	validation_1-auc:0.73058
# [180]	validation_0-logloss:0.65814	validation_0-auc:0.89726	validation_1-logloss:0.67190	validation_1-auc:0.73081
# [181]	validation_0-logloss:0.65812	validation_0-auc:0.89707	validation_1-logloss:0.67189	validation_1-auc:0.73081
# [182]	validation_0-logloss:0.65782	validation_0-auc:0.89752	validation_1-logloss:0.67171	validation_1-auc:0.73104
# [183]	validation_0-logloss:0.65755	validation_0-auc:0.89778	validation_1-logloss:0.67154	validation_1-auc:0.73119
# [184]	validation_0-logloss:0.65753	validation_0-auc:0.89778	validation_1-logloss:0.67154	validation_1-auc:0.73065
# [185]	validation_0-logloss:0.65751	validation_0-auc:0.89771	validation_1-logloss:0.67152	validation_1-auc:0.73065
# [186]	validation_0-logloss:0.65722	validation_0-auc:0.89788	validation_1-logloss:0.67135	validation_1-auc:0.73158
# [187]	validation_0-logloss:0.65691	validation_0-auc:0.89820	validation_1-logloss:0.67118	validation_1-auc:0.73181
# [188]	validation_0-logloss:0.65665	validation_0-auc:0.89817	validation_1-logloss:0.67101	validation_1-auc:0.73181
# [189]	validation_0-logloss:0.65664	validation_0-auc:0.89817	validation_1-logloss:0.67100	validation_1-auc:0.73181
# [190]	validation_0-logloss:0.65663	validation_0-auc:0.89816	validation_1-logloss:0.67100	validation_1-auc:0.73181
# [191]	validation_0-logloss:0.65633	validation_0-auc:0.89832	validation_1-logloss:0.67080	validation_1-auc:0.73227
# [192]	validation_0-logloss:0.65631	validation_0-auc:0.89833	validation_1-logloss:0.67080	validation_1-auc:0.73227
# [193]	validation_0-logloss:0.65604	validation_0-auc:0.89877	validation_1-logloss:0.67063	validation_1-auc:0.73342
# [194]	validation_0-logloss:0.65576	validation_0-auc:0.89886	validation_1-logloss:0.67048	validation_1-auc:0.73242
# [195]	validation_0-logloss:0.65549	validation_0-auc:0.89896	validation_1-logloss:0.67032	validation_1-auc:0.73342
# [196]	validation_0-logloss:0.65519	validation_0-auc:0.89936	validation_1-logloss:0.67012	validation_1-auc:0.73365
# [197]	validation_0-logloss:0.65492	validation_0-auc:0.89937	validation_1-logloss:0.66996	validation_1-auc:0.73335
# [198]	validation_0-logloss:0.65491	validation_0-auc:0.89937	validation_1-logloss:0.66996	validation_1-auc:0.73335
# [199]	validation_0-logloss:0.65463	validation_0-auc:0.89965	validation_1-logloss:0.66980	validation_1-auc:0.73373
# [200]	validation_0-logloss:0.65436	validation_0-auc:0.89976	validation_1-logloss:0.66964	validation_1-auc:0.73365
# [201]	validation_0-logloss:0.65435	validation_0-auc:0.89973	validation_1-logloss:0.66964	validation_1-auc:0.73365
# [202]	validation_0-logloss:0.65434	validation_0-auc:0.89973	validation_1-logloss:0.66963	validation_1-auc:0.73365
# [203]	validation_0-logloss:0.65404	validation_0-auc:0.90056	validation_1-logloss:0.66946	validation_1-auc:0.73473
# [204]	validation_0-logloss:0.65379	validation_0-auc:0.90035	validation_1-logloss:0.66932	validation_1-auc:0.73450
# [205]	validation_0-logloss:0.65349	validation_0-auc:0.90066	validation_1-logloss:0.66913	validation_1-auc:0.73496
# [206]	validation_0-logloss:0.65323	validation_0-auc:0.90058	validation_1-logloss:0.66896	validation_1-auc:0.73527
# [207]	validation_0-logloss:0.65294	validation_0-auc:0.90069	validation_1-logloss:0.66880	validation_1-auc:0.73458
# [208]	validation_0-logloss:0.65293	validation_0-auc:0.90068	validation_1-logloss:0.66879	validation_1-auc:0.73458
# [209]	validation_0-logloss:0.65263	validation_0-auc:0.90083	validation_1-logloss:0.66861	validation_1-auc:0.73511
# [210]	validation_0-logloss:0.65262	validation_0-auc:0.90080	validation_1-logloss:0.66860	validation_1-auc:0.73511
# [211]	validation_0-logloss:0.65236	validation_0-auc:0.90160	validation_1-logloss:0.66844	validation_1-auc:0.73554
# [212]	validation_0-logloss:0.65234	validation_0-auc:0.90162	validation_1-logloss:0.66843	validation_1-auc:0.73554
# [213]	validation_0-logloss:0.65233	validation_0-auc:0.90162	validation_1-logloss:0.66842	validation_1-auc:0.73554
# [214]	validation_0-logloss:0.65232	validation_0-auc:0.90162	validation_1-logloss:0.66841	validation_1-auc:0.73562
# [215]	validation_0-logloss:0.65202	validation_0-auc:0.90198	validation_1-logloss:0.66824	validation_1-auc:0.73608
# [216]	validation_0-logloss:0.65175	validation_0-auc:0.90369	validation_1-logloss:0.66806	validation_1-auc:0.73646
# [217]	validation_0-logloss:0.65173	validation_0-auc:0.90370	validation_1-logloss:0.66805	validation_1-auc:0.73646
# [218]	validation_0-logloss:0.65146	validation_0-auc:0.90653	validation_1-logloss:0.66793	validation_1-auc:0.73419
# [219]	validation_0-logloss:0.65145	validation_0-auc:0.90652	validation_1-logloss:0.66792	validation_1-auc:0.73427
# [220]	validation_0-logloss:0.65143	validation_0-auc:0.90653	validation_1-logloss:0.66792	validation_1-auc:0.73427
# [221]	validation_0-logloss:0.65142	validation_0-auc:0.90651	validation_1-logloss:0.66790	validation_1-auc:0.73427
# [222]	validation_0-logloss:0.65140	validation_0-auc:0.90650	validation_1-logloss:0.66790	validation_1-auc:0.73427
# [223]	validation_0-logloss:0.65139	validation_0-auc:0.90649	validation_1-logloss:0.66789	validation_1-auc:0.73427
# [224]	validation_0-logloss:0.65109	validation_0-auc:0.90666	validation_1-logloss:0.66770	validation_1-auc:0.73465
# [225]	validation_0-logloss:0.65082	validation_0-auc:0.90698	validation_1-logloss:0.66753	validation_1-auc:0.73465
# [226]	validation_0-logloss:0.65081	validation_0-auc:0.90698	validation_1-logloss:0.66752	validation_1-auc:0.73465
# [227]	validation_0-logloss:0.65055	validation_0-auc:0.90778	validation_1-logloss:0.66741	validation_1-auc:0.73435
# [228]	validation_0-logloss:0.65025	validation_0-auc:0.90829	validation_1-logloss:0.66724	validation_1-auc:0.73350
# [229]	validation_0-logloss:0.64999	validation_0-auc:0.90824	validation_1-logloss:0.66709	validation_1-auc:0.73389
# [230]	validation_0-logloss:0.64998	validation_0-auc:0.90824	validation_1-logloss:0.66709	validation_1-auc:0.73389
# [231]	validation_0-logloss:0.64971	validation_0-auc:0.90922	validation_1-logloss:0.66696	validation_1-auc:0.73235
# [232]	validation_0-logloss:0.64970	validation_0-auc:0.90923	validation_1-logloss:0.66696	validation_1-auc:0.73235
# [233]	validation_0-logloss:0.64969	validation_0-auc:0.90929	validation_1-logloss:0.66695	validation_1-auc:0.73235
# [234]	validation_0-logloss:0.64968	validation_0-auc:0.90927	validation_1-logloss:0.66695	validation_1-auc:0.73235
# [235]	validation_0-logloss:0.64938	validation_0-auc:0.90936	validation_1-logloss:0.66677	validation_1-auc:0.73242
# [236]	validation_0-logloss:0.64937	validation_0-auc:0.90937	validation_1-logloss:0.66676	validation_1-auc:0.73258
# [237]	validation_0-logloss:0.64936	validation_0-auc:0.90938	validation_1-logloss:0.66675	validation_1-auc:0.73258
# [238]	validation_0-logloss:0.64935	validation_0-auc:0.90937	validation_1-logloss:0.66674	validation_1-auc:0.73258
# [239]	validation_0-logloss:0.64934	validation_0-auc:0.90937	validation_1-logloss:0.66674	validation_1-auc:0.73258
# [240]	validation_0-logloss:0.64933	validation_0-auc:0.90936	validation_1-logloss:0.66673	validation_1-auc:0.73258
# [241]	validation_0-logloss:0.64906	validation_0-auc:0.91002	validation_1-logloss:0.66662	validation_1-auc:0.73165
# [242]	validation_0-logloss:0.64904	validation_0-auc:0.91002	validation_1-logloss:0.66661	validation_1-auc:0.73165
# [243]	validation_0-logloss:0.64875	validation_0-auc:0.91028	validation_1-logloss:0.66643	validation_1-auc:0.73281
# [244]	validation_0-logloss:0.64849	validation_0-auc:0.91092	validation_1-logloss:0.66627	validation_1-auc:0.73335
# [245]	validation_0-logloss:0.64848	validation_0-auc:0.91093	validation_1-logloss:0.66626	validation_1-auc:0.73335
# [246]	validation_0-logloss:0.64820	validation_0-auc:0.91088	validation_1-logloss:0.66610	validation_1-auc:0.73319
# [247]	validation_0-logloss:0.64793	validation_0-auc:0.91159	validation_1-logloss:0.66598	validation_1-auc:0.73258
# [248]	validation_0-logloss:0.64764	validation_0-auc:0.91188	validation_1-logloss:0.66583	validation_1-auc:0.73304
# [249]	validation_0-logloss:0.64739	validation_0-auc:0.91182	validation_1-logloss:0.66567	validation_1-auc:0.73273
# [250]	validation_0-logloss:0.64711	validation_0-auc:0.91430	validation_1-logloss:0.66551	validation_1-auc:0.73496
# [251]	validation_0-logloss:0.64684	validation_0-auc:0.91486	validation_1-logloss:0.66539	validation_1-auc:0.73450
# [252]	validation_0-logloss:0.64656	validation_0-auc:0.91633	validation_1-logloss:0.66522	validation_1-auc:0.73519
# [253]	validation_0-logloss:0.64655	validation_0-auc:0.91637	validation_1-logloss:0.66522	validation_1-auc:0.73519
# [254]	validation_0-logloss:0.64626	validation_0-auc:0.91721	validation_1-logloss:0.66508	validation_1-auc:0.73396
# [255]	validation_0-logloss:0.64598	validation_0-auc:0.91768	validation_1-logloss:0.66496	validation_1-auc:0.73404
# [256]	validation_0-logloss:0.64570	validation_0-auc:0.91868	validation_1-logloss:0.66478	validation_1-auc:0.73458
# [257]	validation_0-logloss:0.64569	validation_0-auc:0.91868	validation_1-logloss:0.66478	validation_1-auc:0.73458
# [258]	validation_0-logloss:0.64568	validation_0-auc:0.91869	validation_1-logloss:0.66478	validation_1-auc:0.73458
# [259]	validation_0-logloss:0.64540	validation_0-auc:0.91928	validation_1-logloss:0.66464	validation_1-auc:0.73527
# [260]	validation_0-logloss:0.64539	validation_0-auc:0.91929	validation_1-logloss:0.66464	validation_1-auc:0.73535
# [261]	validation_0-logloss:0.64511	validation_0-auc:0.91989	validation_1-logloss:0.66451	validation_1-auc:0.73589
# [262]	validation_0-logloss:0.64482	validation_0-auc:0.92044	validation_1-logloss:0.66438	validation_1-auc:0.73527
# [263]	validation_0-logloss:0.64482	validation_0-auc:0.92044	validation_1-logloss:0.66438	validation_1-auc:0.73535
# [264]	validation_0-logloss:0.64454	validation_0-auc:0.92139	validation_1-logloss:0.66421	validation_1-auc:0.73673
# [265]	validation_0-logloss:0.64453	validation_0-auc:0.92140	validation_1-logloss:0.66420	validation_1-auc:0.73673
# [266]	validation_0-logloss:0.64425	validation_0-auc:0.92174	validation_1-logloss:0.66408	validation_1-auc:0.73696
# [267]	validation_0-logloss:0.64424	validation_0-auc:0.92174	validation_1-logloss:0.66407	validation_1-auc:0.73689
# [268]	validation_0-logloss:0.64423	validation_0-auc:0.92172	validation_1-logloss:0.66407	validation_1-auc:0.73673
# [269]	validation_0-logloss:0.64395	validation_0-auc:0.92226	validation_1-logloss:0.66395	validation_1-auc:0.73550
# [270]	validation_0-logloss:0.64367	validation_0-auc:0.92305	validation_1-logloss:0.66377	validation_1-auc:0.73711
# [271]	validation_0-logloss:0.64366	validation_0-auc:0.92306	validation_1-logloss:0.66377	validation_1-auc:0.73704
# [272]	validation_0-logloss:0.64338	validation_0-auc:0.92364	validation_1-logloss:0.66365	validation_1-auc:0.73758
# [273]	validation_0-logloss:0.64310	validation_0-auc:0.92443	validation_1-logloss:0.66352	validation_1-auc:0.73611
# [274]	validation_0-logloss:0.64309	validation_0-auc:0.92446	validation_1-logloss:0.66352	validation_1-auc:0.73596
# [275]	validation_0-logloss:0.64282	validation_0-auc:0.92510	validation_1-logloss:0.66335	validation_1-auc:0.73719
# [276]	validation_0-logloss:0.64281	validation_0-auc:0.92509	validation_1-logloss:0.66335	validation_1-auc:0.73711
# [277]	validation_0-logloss:0.64280	validation_0-auc:0.92508	validation_1-logloss:0.66334	validation_1-auc:0.73696
# [278]	validation_0-logloss:0.64279	validation_0-auc:0.92506	validation_1-logloss:0.66334	validation_1-auc:0.73689
# [279]	validation_0-logloss:0.64278	validation_0-auc:0.92507	validation_1-logloss:0.66334	validation_1-auc:0.73689
# [280]	validation_0-logloss:0.64277	validation_0-auc:0.92508	validation_1-logloss:0.66333	validation_1-auc:0.73689
# [281]	validation_0-logloss:0.64276	validation_0-auc:0.92507	validation_1-logloss:0.66333	validation_1-auc:0.73689
# [282]	validation_0-logloss:0.64248	validation_0-auc:0.92549	validation_1-logloss:0.66320	validation_1-auc:0.73681
# [283]	validation_0-logloss:0.64247	validation_0-auc:0.92549	validation_1-logloss:0.66319	validation_1-auc:0.73681
# [284]	validation_0-logloss:0.64219	validation_0-auc:0.92582	validation_1-logloss:0.66308	validation_1-auc:0.73642
# [285]	validation_0-logloss:0.64219	validation_0-auc:0.92586	validation_1-logloss:0.66308	validation_1-auc:0.73642
# [286]	validation_0-logloss:0.64218	validation_0-auc:0.92587	validation_1-logloss:0.66307	validation_1-auc:0.73642
# [287]	validation_0-logloss:0.64217	validation_0-auc:0.92587	validation_1-logloss:0.66307	validation_1-auc:0.73642
# [288]	validation_0-logloss:0.64189	validation_0-auc:0.92597	validation_1-logloss:0.66293	validation_1-auc:0.73604
# [289]	validation_0-logloss:0.64162	validation_0-auc:0.92682	validation_1-logloss:0.66277	validation_1-auc:0.73711
# [290]	validation_0-logloss:0.64161	validation_0-auc:0.92683	validation_1-logloss:0.66276	validation_1-auc:0.73711
# [291]	validation_0-logloss:0.64160	validation_0-auc:0.92683	validation_1-logloss:0.66276	validation_1-auc:0.73711
# [292]	validation_0-logloss:0.64158	validation_0-auc:0.92686	validation_1-logloss:0.66275	validation_1-auc:0.73711
# [293]	validation_0-logloss:0.64131	validation_0-auc:0.92715	validation_1-logloss:0.66263	validation_1-auc:0.73673
# [294]	validation_0-logloss:0.64103	validation_0-auc:0.92742	validation_1-logloss:0.66251	validation_1-auc:0.73619
# [295]	validation_0-logloss:0.64076	validation_0-auc:0.92820	validation_1-logloss:0.66234	validation_1-auc:0.73727
# [296]	validation_0-logloss:0.64048	validation_0-auc:0.92858	validation_1-logloss:0.66222	validation_1-auc:0.73727
# [297]	validation_0-logloss:0.64020	validation_0-auc:0.92891	validation_1-logloss:0.66210	validation_1-auc:0.73781
# [298]	validation_0-logloss:0.64019	validation_0-auc:0.92890	validation_1-logloss:0.66209	validation_1-auc:0.73781
# [299]	validation_0-logloss:0.64019	validation_0-auc:0.92889	validation_1-logloss:0.66209	validation_1-auc:0.73789
# [300]	validation_0-logloss:0.64018	validation_0-auc:0.92887	validation_1-logloss:0.66208	validation_1-auc:0.73789
# [301]	validation_0-logloss:0.64017	validation_0-auc:0.92892	validation_1-logloss:0.66208	validation_1-auc:0.73765
# [302]	validation_0-logloss:0.64016	validation_0-auc:0.92892	validation_1-logloss:0.66207	validation_1-auc:0.73750
# [303]	validation_0-logloss:0.64015	validation_0-auc:0.92896	validation_1-logloss:0.66207	validation_1-auc:0.73750
# [304]	validation_0-logloss:0.64014	validation_0-auc:0.92898	validation_1-logloss:0.66207	validation_1-auc:0.73750
# [305]	validation_0-logloss:0.63986	validation_0-auc:0.92914	validation_1-logloss:0.66195	validation_1-auc:0.73742
# [306]	validation_0-logloss:0.63985	validation_0-auc:0.92914	validation_1-logloss:0.66195	validation_1-auc:0.73750
# [307]	validation_0-logloss:0.63958	validation_0-auc:0.92968	validation_1-logloss:0.66178	validation_1-auc:0.73927
# [308]	validation_0-logloss:0.63931	validation_0-auc:0.93003	validation_1-logloss:0.66166	validation_1-auc:0.73927
# [309]	validation_0-logloss:0.63930	validation_0-auc:0.93004	validation_1-logloss:0.66165	validation_1-auc:0.73927
# [310]	validation_0-logloss:0.63929	validation_0-auc:0.93007	validation_1-logloss:0.66165	validation_1-auc:0.73927
# [311]	validation_0-logloss:0.63901	validation_0-auc:0.93038	validation_1-logloss:0.66153	validation_1-auc:0.74042
# [312]	validation_0-logloss:0.63901	validation_0-auc:0.93039	validation_1-logloss:0.66152	validation_1-auc:0.74035
# [313]	validation_0-logloss:0.63900	validation_0-auc:0.93038	validation_1-logloss:0.66152	validation_1-auc:0.74035
# [314]	validation_0-logloss:0.63899	validation_0-auc:0.93039	validation_1-logloss:0.66151	validation_1-auc:0.74035
# [315]	validation_0-logloss:0.63898	validation_0-auc:0.93039	validation_1-logloss:0.66151	validation_1-auc:0.74042
# [316]	validation_0-logloss:0.63897	validation_0-auc:0.93042	validation_1-logloss:0.66151	validation_1-auc:0.74050
# [317]	validation_0-logloss:0.63870	validation_0-auc:0.93107	validation_1-logloss:0.66134	validation_1-auc:0.74089
# [318]	validation_0-logloss:0.63870	validation_0-auc:0.93108	validation_1-logloss:0.66134	validation_1-auc:0.74096
# [319]	validation_0-logloss:0.63869	validation_0-auc:0.93108	validation_1-logloss:0.66134	validation_1-auc:0.74104
# [320]	validation_0-logloss:0.63841	validation_0-auc:0.93129	validation_1-logloss:0.66122	validation_1-auc:0.74127
# [321]	validation_0-logloss:0.63814	validation_0-auc:0.93161	validation_1-logloss:0.66110	validation_1-auc:0.74119
# [322]	validation_0-logloss:0.63787	validation_0-auc:0.93260	validation_1-logloss:0.66094	validation_1-auc:0.74235
# [323]	validation_0-logloss:0.63786	validation_0-auc:0.93260	validation_1-logloss:0.66094	validation_1-auc:0.74235
# [324]	validation_0-logloss:0.63759	validation_0-auc:0.93265	validation_1-logloss:0.66082	validation_1-auc:0.74281
# [325]	validation_0-logloss:0.63758	validation_0-auc:0.93268	validation_1-logloss:0.66082	validation_1-auc:0.74281
# [326]	validation_0-logloss:0.63757	validation_0-auc:0.93269	validation_1-logloss:0.66081	validation_1-auc:0.74281
# [327]	validation_0-logloss:0.63757	validation_0-auc:0.93272	validation_1-logloss:0.66081	validation_1-auc:0.74281
# [328]	validation_0-logloss:0.63756	validation_0-auc:0.93272	validation_1-logloss:0.66080	validation_1-auc:0.74289
# [329]	validation_0-logloss:0.63755	validation_0-auc:0.93272	validation_1-logloss:0.66080	validation_1-auc:0.74289
# [330]	validation_0-logloss:0.63728	validation_0-auc:0.93287	validation_1-logloss:0.66069	validation_1-auc:0.74258
# [331]	validation_0-logloss:0.63701	validation_0-auc:0.93372	validation_1-logloss:0.66052	validation_1-auc:0.74319
# [332]	validation_0-logloss:0.63700	validation_0-auc:0.93372	validation_1-logloss:0.66052	validation_1-auc:0.74319
# [333]	validation_0-logloss:0.63673	validation_0-auc:0.93377	validation_1-logloss:0.66039	validation_1-auc:0.74342
# [334]	validation_0-logloss:0.63672	validation_0-auc:0.93378	validation_1-logloss:0.66039	validation_1-auc:0.74335
# [335]	validation_0-logloss:0.63671	validation_0-auc:0.93378	validation_1-logloss:0.66039	validation_1-auc:0.74335
# [336]	validation_0-logloss:0.63670	validation_0-auc:0.93376	validation_1-logloss:0.66038	validation_1-auc:0.74319
# [337]	validation_0-logloss:0.63643	validation_0-auc:0.93411	validation_1-logloss:0.66030	validation_1-auc:0.74304
# [338]	validation_0-logloss:0.63643	validation_0-auc:0.93409	validation_1-logloss:0.66030	validation_1-auc:0.74304
# [339]	validation_0-logloss:0.63642	validation_0-auc:0.93409	validation_1-logloss:0.66030	validation_1-auc:0.74304
# [340]	validation_0-logloss:0.63615	validation_0-auc:0.93491	validation_1-logloss:0.66014	validation_1-auc:0.74311
# [341]	validation_0-logloss:0.63588	validation_0-auc:0.93499	validation_1-logloss:0.66002	validation_1-auc:0.74319
# [342]	validation_0-logloss:0.63562	validation_0-auc:0.93532	validation_1-logloss:0.65993	validation_1-auc:0.74342
# [343]	validation_0-logloss:0.63561	validation_0-auc:0.93533	validation_1-logloss:0.65993	validation_1-auc:0.74342
# [344]	validation_0-logloss:0.63559	validation_0-auc:0.93531	validation_1-logloss:0.65992	validation_1-auc:0.74342
# [345]	validation_0-logloss:0.63533	validation_0-auc:0.93585	validation_1-logloss:0.65977	validation_1-auc:0.74342
# [346]	validation_0-logloss:0.63532	validation_0-auc:0.93585	validation_1-logloss:0.65977	validation_1-auc:0.74342
# [347]	validation_0-logloss:0.63531	validation_0-auc:0.93587	validation_1-logloss:0.65976	validation_1-auc:0.74335
# [348]	validation_0-logloss:0.63504	validation_0-auc:0.93601	validation_1-logloss:0.65964	validation_1-auc:0.74335
# [349]	validation_0-logloss:0.63503	validation_0-auc:0.93602	validation_1-logloss:0.65963	validation_1-auc:0.74335
# [350]	validation_0-logloss:0.63503	validation_0-auc:0.93600	validation_1-logloss:0.65963	validation_1-auc:0.74335
# [351]	validation_0-logloss:0.63476	validation_0-auc:0.93651	validation_1-logloss:0.65948	validation_1-auc:0.74411
# [352]	validation_0-logloss:0.63450	validation_0-auc:0.93666	validation_1-logloss:0.65939	validation_1-auc:0.74419
# [353]	validation_0-logloss:0.63423	validation_0-auc:0.93729	validation_1-logloss:0.65924	validation_1-auc:0.74427
# [354]	validation_0-logloss:0.63397	validation_0-auc:0.93758	validation_1-logloss:0.65915	validation_1-auc:0.74411
# [355]	validation_0-logloss:0.63396	validation_0-auc:0.93758	validation_1-logloss:0.65915	validation_1-auc:0.74404
# [356]	validation_0-logloss:0.63395	validation_0-auc:0.93758	validation_1-logloss:0.65915	validation_1-auc:0.74411
# [357]	validation_0-logloss:0.63369	validation_0-auc:0.93819	validation_1-logloss:0.65898	validation_1-auc:0.74489
# [358]	validation_0-logloss:0.63343	validation_0-auc:0.93862	validation_1-logloss:0.65887	validation_1-auc:0.74473
# [359]	validation_0-logloss:0.63342	validation_0-auc:0.93864	validation_1-logloss:0.65887	validation_1-auc:0.74473
# [360]	validation_0-logloss:0.63316	validation_0-auc:0.93867	validation_1-logloss:0.65875	validation_1-auc:0.74481
# [361]	validation_0-logloss:0.63289	validation_0-auc:0.93873	validation_1-logloss:0.65868	validation_1-auc:0.74435
# [362]	validation_0-logloss:0.63263	validation_0-auc:0.93928	validation_1-logloss:0.65852	validation_1-auc:0.74396
# [363]	validation_0-logloss:0.63262	validation_0-auc:0.93928	validation_1-logloss:0.65852	validation_1-auc:0.74396
# [364]	validation_0-logloss:0.63236	validation_0-auc:0.93928	validation_1-logloss:0.65840	validation_1-auc:0.74435
# [365]	validation_0-logloss:0.63235	validation_0-auc:0.93929	validation_1-logloss:0.65840	validation_1-auc:0.74442
# [366]	validation_0-logloss:0.63234	validation_0-auc:0.93929	validation_1-logloss:0.65839	validation_1-auc:0.74442
# [367]	validation_0-logloss:0.63208	validation_0-auc:0.93984	validation_1-logloss:0.65824	validation_1-auc:0.74435
# [368]	validation_0-logloss:0.63182	validation_0-auc:0.93990	validation_1-logloss:0.65817	validation_1-auc:0.74438
# [369]	validation_0-logloss:0.63181	validation_0-auc:0.93990	validation_1-logloss:0.65817	validation_1-auc:0.74438
# [370]	validation_0-logloss:0.63180	validation_0-auc:0.93994	validation_1-logloss:0.65816	validation_1-auc:0.74438
# [371]	validation_0-logloss:0.63154	validation_0-auc:0.94022	validation_1-logloss:0.65800	validation_1-auc:0.74508
# [372]	validation_0-logloss:0.63153	validation_0-auc:0.94023	validation_1-logloss:0.65800	validation_1-auc:0.74508
# [373]	validation_0-logloss:0.63127	validation_0-auc:0.94037	validation_1-logloss:0.65791	validation_1-auc:0.74508
# [374]	validation_0-logloss:0.63102	validation_0-auc:0.94069	validation_1-logloss:0.65780	validation_1-auc:0.74431
# [375]	validation_0-logloss:0.63076	validation_0-auc:0.94124	validation_1-logloss:0.65765	validation_1-auc:0.74500
# [376]	validation_0-logloss:0.63075	validation_0-auc:0.94123	validation_1-logloss:0.65764	validation_1-auc:0.74500
# [377]	validation_0-logloss:0.63074	validation_0-auc:0.94123	validation_1-logloss:0.65764	validation_1-auc:0.74500
# [378]	validation_0-logloss:0.63074	validation_0-auc:0.94124	validation_1-logloss:0.65764	validation_1-auc:0.74500
# [379]	validation_0-logloss:0.63073	validation_0-auc:0.94124	validation_1-logloss:0.65763	validation_1-auc:0.74500
# [380]	validation_0-logloss:0.63047	validation_0-auc:0.94123	validation_1-logloss:0.65753	validation_1-auc:0.74477
# [381]	validation_0-logloss:0.63046	validation_0-auc:0.94123	validation_1-logloss:0.65752	validation_1-auc:0.74492
# [382]	validation_0-logloss:0.63020	validation_0-auc:0.94143	validation_1-logloss:0.65744	validation_1-auc:0.74454
# [383]	validation_0-logloss:0.63019	validation_0-auc:0.94146	validation_1-logloss:0.65743	validation_1-auc:0.74454
# [384]	validation_0-logloss:0.62993	validation_0-auc:0.94199	validation_1-logloss:0.65728	validation_1-auc:0.74454
# [385]	validation_0-logloss:0.62967	validation_0-auc:0.94238	validation_1-logloss:0.65713	validation_1-auc:0.74469
# [386]	validation_0-logloss:0.62940	validation_0-auc:0.94241	validation_1-logloss:0.65699	validation_1-auc:0.74504
# [387]	validation_0-logloss:0.62914	validation_0-auc:0.94247	validation_1-logloss:0.65691	validation_1-auc:0.74496
# [388]	validation_0-logloss:0.62888	validation_0-auc:0.94285	validation_1-logloss:0.65676	validation_1-auc:0.74496
# [389]	validation_0-logloss:0.62863	validation_0-auc:0.94305	validation_1-logloss:0.65665	validation_1-auc:0.74481
# [390]	validation_0-logloss:0.62836	validation_0-auc:0.94321	validation_1-logloss:0.65652	validation_1-auc:0.74481
# [391]	validation_0-logloss:0.62811	validation_0-auc:0.94357	validation_1-logloss:0.65637	validation_1-auc:0.74519
# [392]	validation_0-logloss:0.62810	validation_0-auc:0.94358	validation_1-logloss:0.65637	validation_1-auc:0.74519
# [393]	validation_0-logloss:0.62784	validation_0-auc:0.94379	validation_1-logloss:0.65626	validation_1-auc:0.74511
# [394]	validation_0-logloss:0.62783	validation_0-auc:0.94378	validation_1-logloss:0.65625	validation_1-auc:0.74511
# [395]	validation_0-logloss:0.62782	validation_0-auc:0.94379	validation_1-logloss:0.65625	validation_1-auc:0.74511
# [396]	validation_0-logloss:0.62782	validation_0-auc:0.94380	validation_1-logloss:0.65625	validation_1-auc:0.74511
# [397]	validation_0-logloss:0.62756	validation_0-auc:0.94401	validation_1-logloss:0.65609	validation_1-auc:0.74527
# [398]	validation_0-logloss:0.62728	validation_0-auc:0.94436	validation_1-logloss:0.65592	validation_1-auc:0.74619
# [399]	validation_0-logloss:0.62727	validation_0-auc:0.94435	validation_1-logloss:0.65592	validation_1-auc:0.74619
# [400]	validation_0-logloss:0.62727	validation_0-auc:0.94435	validation_1-logloss:0.65592	validation_1-auc:0.74627
# [401]	validation_0-logloss:0.62726	validation_0-auc:0.94436	validation_1-logloss:0.65592	validation_1-auc:0.74627
# [402]	validation_0-logloss:0.62725	validation_0-auc:0.94436	validation_1-logloss:0.65591	validation_1-auc:0.74619
# [403]	validation_0-logloss:0.62725	validation_0-auc:0.94435	validation_1-logloss:0.65591	validation_1-auc:0.74619
# [404]	validation_0-logloss:0.62699	validation_0-auc:0.94445	validation_1-logloss:0.65581	validation_1-auc:0.74650
# [405]	validation_0-logloss:0.62699	validation_0-auc:0.94446	validation_1-logloss:0.65581	validation_1-auc:0.74650
# [406]	validation_0-logloss:0.62698	validation_0-auc:0.94446	validation_1-logloss:0.65581	validation_1-auc:0.74650
# [407]	validation_0-logloss:0.62698	validation_0-auc:0.94446	validation_1-logloss:0.65581	validation_1-auc:0.74650
# [408]	validation_0-logloss:0.62697	validation_0-auc:0.94445	validation_1-logloss:0.65580	validation_1-auc:0.74650
# [409]	validation_0-logloss:0.62696	validation_0-auc:0.94445	validation_1-logloss:0.65580	validation_1-auc:0.74650
# [410]	validation_0-logloss:0.62671	validation_0-auc:0.94484	validation_1-logloss:0.65565	validation_1-auc:0.74642
# [411]	validation_0-logloss:0.62670	validation_0-auc:0.94483	validation_1-logloss:0.65565	validation_1-auc:0.74650
# [412]	validation_0-logloss:0.62645	validation_0-auc:0.94503	validation_1-logloss:0.65549	validation_1-auc:0.74711
# [413]	validation_0-logloss:0.62644	validation_0-auc:0.94502	validation_1-logloss:0.65549	validation_1-auc:0.74711
# [414]	validation_0-logloss:0.62644	validation_0-auc:0.94501	validation_1-logloss:0.65549	validation_1-auc:0.74711
# [415]	validation_0-logloss:0.62643	validation_0-auc:0.94501	validation_1-logloss:0.65549	validation_1-auc:0.74711
# [416]	validation_0-logloss:0.62615	validation_0-auc:0.94548	validation_1-logloss:0.65534	validation_1-auc:0.74765
# [417]	validation_0-logloss:0.62590	validation_0-auc:0.94558	validation_1-logloss:0.65523	validation_1-auc:0.74727
# [418]	validation_0-logloss:0.62590	validation_0-auc:0.94559	validation_1-logloss:0.65523	validation_1-auc:0.74727
# [419]	validation_0-logloss:0.62564	validation_0-auc:0.94590	validation_1-logloss:0.65508	validation_1-auc:0.74789
# [420]	validation_0-logloss:0.62564	validation_0-auc:0.94590	validation_1-logloss:0.65508	validation_1-auc:0.74789
# [421]	validation_0-logloss:0.62563	validation_0-auc:0.94589	validation_1-logloss:0.65507	validation_1-auc:0.74789
# ...
# [1862]	validation_0-logloss:0.47391	validation_0-auc:0.98595	validation_1-logloss:0.57318	validation_1-auc:0.81408
# [1863]	validation_0-logloss:0.47391	validation_0-auc:0.98595	validation_1-logloss:0.57318	validation_1-auc:0.81408
# [1864]	validation_0-logloss:0.47391	validation_0-auc:0.98595	validation_1-logloss:0.57318	validation_1-auc:0.81408
# [1865]	validation_0-logloss:0.47390	validation_0-auc:0.98595	validation_1-logloss:0.57318	validation_1-auc:0.81408
# [1866]	validation_0-logloss:0.47390	validation_0-auc:0.98595	validation_1-logloss:0.57318	validation_1-auc:0.81408
# [1867]	validation_0-logloss:0.47390	validation_0-auc:0.98595	validation_1-logloss:0.57318	validation_1-auc:0.81408
# [1868]	validation_0-logloss:0.47374	validation_0-auc:0.98599	validation_1-logloss:0.57306	validation_1-auc:0.81439
# [1869]	validation_0-logloss:0.47374	validation_0-auc:0.98599	validation_1-logloss:0.57306	validation_1-auc:0.81439
# [1870]	validation_0-logloss:0.47360	validation_0-auc:0.98599	validation_1-logloss:0.57301	validation_1-auc:0.81439
# [1871]	validation_0-logloss:0.47342	validation_0-auc:0.98602	validation_1-logloss:0.57293	validation_1-auc:0.81461
# [1872]	validation_0-logloss:0.47342	validation_0-auc:0.98602	validation_1-logloss:0.57293	validation_1-auc:0.81461
# [1873]	validation_0-logloss:0.47325	validation_0-auc:0.98602	validation_1-logloss:0.57287	validation_1-auc:0.81446
# [1874]	validation_0-logloss:0.47310	validation_0-auc:0.98605	validation_1-logloss:0.57278	validation_1-auc:0.81439
# [1875]	validation_0-logloss:0.47292	validation_0-auc:0.98608	validation_1-logloss:0.57268	validation_1-auc:0.81439
# [1876]	validation_0-logloss:0.47292	validation_0-auc:0.98608	validation_1-logloss:0.57268	validation_1-auc:0.81439
# [1877]	validation_0-logloss:0.47292	validation_0-auc:0.98608	validation_1-logloss:0.57268	validation_1-auc:0.81439
# [1878]	validation_0-logloss:0.47275	validation_0-auc:0.98613	validation_1-logloss:0.57258	validation_1-auc:0.81454
# [1879]	validation_0-logloss:0.47261	validation_0-auc:0.98611	validation_1-logloss:0.57253	validation_1-auc:0.81454
# [1880]	validation_0-logloss:0.47245	validation_0-auc:0.98609	validation_1-logloss:0.57247	validation_1-auc:0.81454
# [1881]	validation_0-logloss:0.47245	validation_0-auc:0.98609	validation_1-logloss:0.57247	validation_1-auc:0.81454
# [1882]	validation_0-logloss:0.47244	validation_0-auc:0.98609	validation_1-logloss:0.57247	validation_1-auc:0.81454
# [1883]	validation_0-logloss:0.47227	validation_0-auc:0.98611	validation_1-logloss:0.57238	validation_1-auc:0.81439
# [1884]	validation_0-logloss:0.47213	validation_0-auc:0.98612	validation_1-logloss:0.57233	validation_1-auc:0.81461
# [1885]	validation_0-logloss:0.47213	validation_0-auc:0.98612	validation_1-logloss:0.57233	validation_1-auc:0.81461
# [1886]	validation_0-logloss:0.47213	validation_0-auc:0.98612	validation_1-logloss:0.57233	validation_1-auc:0.81461
# [1887]	validation_0-logloss:0.47212	validation_0-auc:0.98612	validation_1-logloss:0.57233	validation_1-auc:0.81461
# [1888]	validation_0-logloss:0.47198	validation_0-auc:0.98619	validation_1-logloss:0.57224	validation_1-auc:0.81469
# [1889]	validation_0-logloss:0.47183	validation_0-auc:0.98623	validation_1-logloss:0.57217	validation_1-auc:0.81485
# [1890]	validation_0-logloss:0.47183	validation_0-auc:0.98623	validation_1-logloss:0.57217	validation_1-auc:0.81485
# [1891]	validation_0-logloss:0.47167	validation_0-auc:0.98625	validation_1-logloss:0.57206	validation_1-auc:0.81492
# [1892]	validation_0-logloss:0.47152	validation_0-auc:0.98629	validation_1-logloss:0.57197	validation_1-auc:0.81492
# [1893]	validation_0-logloss:0.47152	validation_0-auc:0.98629	validation_1-logloss:0.57197	validation_1-auc:0.81492
# [1894]	validation_0-logloss:0.47152	validation_0-auc:0.98629	validation_1-logloss:0.57197	validation_1-auc:0.81492
# [1895]	validation_0-logloss:0.47134	validation_0-auc:0.98631	validation_1-logloss:0.57187	validation_1-auc:0.81515
# [1896]	validation_0-logloss:0.47120	validation_0-auc:0.98636	validation_1-logloss:0.57184	validation_1-auc:0.81492
# [1897]	validation_0-logloss:0.47120	validation_0-auc:0.98636	validation_1-logloss:0.57184	validation_1-auc:0.81492
# [1898]	validation_0-logloss:0.47103	validation_0-auc:0.98638	validation_1-logloss:0.57175	validation_1-auc:0.81508
# [1899]	validation_0-logloss:0.47087	validation_0-auc:0.98634	validation_1-logloss:0.57170	validation_1-auc:0.81500
# [1900]	validation_0-logloss:0.47087	validation_0-auc:0.98634	validation_1-logloss:0.57170	validation_1-auc:0.81500
# [1901]	validation_0-logloss:0.47069	validation_0-auc:0.98639	validation_1-logloss:0.57162	validation_1-auc:0.81515
# [1902]	validation_0-logloss:0.47057	validation_0-auc:0.98639	validation_1-logloss:0.57157	validation_1-auc:0.81500
# [1903]	validation_0-logloss:0.47057	validation_0-auc:0.98639	validation_1-logloss:0.57157	validation_1-auc:0.81500
# [1904]	validation_0-logloss:0.47042	validation_0-auc:0.98643	validation_1-logloss:0.57146	validation_1-auc:0.81508
# [1905]	validation_0-logloss:0.47042	validation_0-auc:0.98643	validation_1-logloss:0.57146	validation_1-auc:0.81508
# [1906]	validation_0-logloss:0.47025	validation_0-auc:0.98647	validation_1-logloss:0.57135	validation_1-auc:0.81554
# [1907]	validation_0-logloss:0.47011	validation_0-auc:0.98647	validation_1-logloss:0.57132	validation_1-auc:0.81539
# [1908]	validation_0-logloss:0.46993	validation_0-auc:0.98652	validation_1-logloss:0.57122	validation_1-auc:0.81554
# [1909]	validation_0-logloss:0.46993	validation_0-auc:0.98652	validation_1-logloss:0.57122	validation_1-auc:0.81554
# [1910]	validation_0-logloss:0.46993	validation_0-auc:0.98652	validation_1-logloss:0.57122	validation_1-auc:0.81554
# [1911]	validation_0-logloss:0.46992	validation_0-auc:0.98652	validation_1-logloss:0.57122	validation_1-auc:0.81554
# [1912]	validation_0-logloss:0.46992	validation_0-auc:0.98652	validation_1-logloss:0.57122	validation_1-auc:0.81554
# [1913]	validation_0-logloss:0.46992	validation_0-auc:0.98652	validation_1-logloss:0.57122	validation_1-auc:0.81554
# [1914]	validation_0-logloss:0.46992	validation_0-auc:0.98652	validation_1-logloss:0.57122	validation_1-auc:0.81554
# [1915]	validation_0-logloss:0.46978	validation_0-auc:0.98655	validation_1-logloss:0.57120	validation_1-auc:0.81546
# [1916]	validation_0-logloss:0.46978	validation_0-auc:0.98655	validation_1-logloss:0.57120	validation_1-auc:0.81546
# [1917]	validation_0-logloss:0.46978	validation_0-auc:0.98655	validation_1-logloss:0.57120	validation_1-auc:0.81546
# [1918]	validation_0-logloss:0.46978	validation_0-auc:0.98655	validation_1-logloss:0.57120	validation_1-auc:0.81546
# [1919]	validation_0-logloss:0.46978	validation_0-auc:0.98655	validation_1-logloss:0.57120	validation_1-auc:0.81546
# [1920]	validation_0-logloss:0.46964	validation_0-auc:0.98655	validation_1-logloss:0.57113	validation_1-auc:0.81546
# [1921]	validation_0-logloss:0.46949	validation_0-auc:0.98660	validation_1-logloss:0.57106	validation_1-auc:0.81531
# [1922]	validation_0-logloss:0.46931	validation_0-auc:0.98664	validation_1-logloss:0.57097	validation_1-auc:0.81554
# [1923]	validation_0-logloss:0.46931	validation_0-auc:0.98664	validation_1-logloss:0.57097	validation_1-auc:0.81554
# [1924]	validation_0-logloss:0.46931	validation_0-auc:0.98664	validation_1-logloss:0.57097	validation_1-auc:0.81554
# [1925]	validation_0-logloss:0.46916	validation_0-auc:0.98662	validation_1-logloss:0.57091	validation_1-auc:0.81561
# [1926]	validation_0-logloss:0.46916	validation_0-auc:0.98662	validation_1-logloss:0.57091	validation_1-auc:0.81561
# [1927]	validation_0-logloss:0.46916	validation_0-auc:0.98662	validation_1-logloss:0.57091	validation_1-auc:0.81561
# [1928]	validation_0-logloss:0.46916	validation_0-auc:0.98662	validation_1-logloss:0.57091	validation_1-auc:0.81561
# [1929]	validation_0-logloss:0.46900	validation_0-auc:0.98667	validation_1-logloss:0.57079	validation_1-auc:0.81577
# [1930]	validation_0-logloss:0.46900	validation_0-auc:0.98667	validation_1-logloss:0.57079	validation_1-auc:0.81577
# [1931]	validation_0-logloss:0.46888	validation_0-auc:0.98668	validation_1-logloss:0.57076	validation_1-auc:0.81577
# [1932]	validation_0-logloss:0.46873	validation_0-auc:0.98673	validation_1-logloss:0.57064	validation_1-auc:0.81600
# [1933]	validation_0-logloss:0.46873	validation_0-auc:0.98673	validation_1-logloss:0.57064	validation_1-auc:0.81600
# [1934]	validation_0-logloss:0.46873	validation_0-auc:0.98673	validation_1-logloss:0.57064	validation_1-auc:0.81600
# [1935]	validation_0-logloss:0.46856	validation_0-auc:0.98674	validation_1-logloss:0.57056	validation_1-auc:0.81615
# [1936]	validation_0-logloss:0.46838	validation_0-auc:0.98677	validation_1-logloss:0.57046	validation_1-auc:0.81623
# [1937]	validation_0-logloss:0.46824	validation_0-auc:0.98679	validation_1-logloss:0.57043	validation_1-auc:0.81623
# [1938]	validation_0-logloss:0.46824	validation_0-auc:0.98679	validation_1-logloss:0.57043	validation_1-auc:0.81623
# [1939]	validation_0-logloss:0.46808	validation_0-auc:0.98676	validation_1-logloss:0.57037	validation_1-auc:0.81631
# [1940]	validation_0-logloss:0.46808	validation_0-auc:0.98676	validation_1-logloss:0.57037	validation_1-auc:0.81631
# [1941]	validation_0-logloss:0.46791	validation_0-auc:0.98676	validation_1-logloss:0.57029	validation_1-auc:0.81646
# [1942]	validation_0-logloss:0.46791	validation_0-auc:0.98676	validation_1-logloss:0.57029	validation_1-auc:0.81646
# [1943]	validation_0-logloss:0.46779	validation_0-auc:0.98677	validation_1-logloss:0.57024	validation_1-auc:0.81639
# [1944]	validation_0-logloss:0.46765	validation_0-auc:0.98680	validation_1-logloss:0.57017	validation_1-auc:0.81623
# [1945]	validation_0-logloss:0.46765	validation_0-auc:0.98680	validation_1-logloss:0.57017	validation_1-auc:0.81623
# [1946]	validation_0-logloss:0.46749	validation_0-auc:0.98684	validation_1-logloss:0.57006	validation_1-auc:0.81654
# [1947]	validation_0-logloss:0.46749	validation_0-auc:0.98684	validation_1-logloss:0.57006	validation_1-auc:0.81654
# [1948]	validation_0-logloss:0.46737	validation_0-auc:0.98686	validation_1-logloss:0.57001	validation_1-auc:0.81646
# [1949]	validation_0-logloss:0.46737	validation_0-auc:0.98686	validation_1-logloss:0.57001	validation_1-auc:0.81646
# [1950]	validation_0-logloss:0.46737	validation_0-auc:0.98686	validation_1-logloss:0.57001	validation_1-auc:0.81642
# [1951]	validation_0-logloss:0.46719	validation_0-auc:0.98684	validation_1-logloss:0.56991	validation_1-auc:0.81654
# [1952]	validation_0-logloss:0.46705	validation_0-auc:0.98685	validation_1-logloss:0.56985	validation_1-auc:0.81646
# [1953]	validation_0-logloss:0.46689	validation_0-auc:0.98689	validation_1-logloss:0.56974	validation_1-auc:0.81646
# [1954]	validation_0-logloss:0.46676	validation_0-auc:0.98692	validation_1-logloss:0.56972	validation_1-auc:0.81639
# [1955]	validation_0-logloss:0.46675	validation_0-auc:0.98692	validation_1-logloss:0.56972	validation_1-auc:0.81639
# [1956]	validation_0-logloss:0.46675	validation_0-auc:0.98692	validation_1-logloss:0.56972	validation_1-auc:0.81639
# [1957]	validation_0-logloss:0.46659	validation_0-auc:0.98692	validation_1-logloss:0.56964	validation_1-auc:0.81669
# [1958]	validation_0-logloss:0.46644	validation_0-auc:0.98696	validation_1-logloss:0.56957	validation_1-auc:0.81669
# [1959]	validation_0-logloss:0.46644	validation_0-auc:0.98696	validation_1-logloss:0.56957	validation_1-auc:0.81669
# [1960]	validation_0-logloss:0.46627	validation_0-auc:0.98694	validation_1-logloss:0.56947	validation_1-auc:0.81715
# [1961]	validation_0-logloss:0.46609	validation_0-auc:0.98694	validation_1-logloss:0.56939	validation_1-auc:0.81715
# [1962]	validation_0-logloss:0.46596	validation_0-auc:0.98699	validation_1-logloss:0.56936	validation_1-auc:0.81715
# [1963]	validation_0-logloss:0.46596	validation_0-auc:0.98699	validation_1-logloss:0.56936	validation_1-auc:0.81715
# [1964]	validation_0-logloss:0.46581	validation_0-auc:0.98701	validation_1-logloss:0.56930	validation_1-auc:0.81700
# [1965]	validation_0-logloss:0.46570	validation_0-auc:0.98701	validation_1-logloss:0.56923	validation_1-auc:0.81685
# [1966]	validation_0-logloss:0.46570	validation_0-auc:0.98701	validation_1-logloss:0.56923	validation_1-auc:0.81685
# [1967]	validation_0-logloss:0.46554	validation_0-auc:0.98704	validation_1-logloss:0.56912	validation_1-auc:0.81739
# [1968]	validation_0-logloss:0.46554	validation_0-auc:0.98704	validation_1-logloss:0.56912	validation_1-auc:0.81739
# [1969]	validation_0-logloss:0.46538	validation_0-auc:0.98706	validation_1-logloss:0.56904	validation_1-auc:0.81754
# [1970]	validation_0-logloss:0.46520	validation_0-auc:0.98709	validation_1-logloss:0.56895	validation_1-auc:0.81761
# [1971]	validation_0-logloss:0.46506	validation_0-auc:0.98709	validation_1-logloss:0.56888	validation_1-auc:0.81746
# [1972]	validation_0-logloss:0.46506	validation_0-auc:0.98709	validation_1-logloss:0.56888	validation_1-auc:0.81746
# [1973]	validation_0-logloss:0.46492	validation_0-auc:0.98712	validation_1-logloss:0.56881	validation_1-auc:0.81739
# [1974]	validation_0-logloss:0.46478	validation_0-auc:0.98716	validation_1-logloss:0.56872	validation_1-auc:0.81723
# [1975]	validation_0-logloss:0.46462	validation_0-auc:0.98717	validation_1-logloss:0.56861	validation_1-auc:0.81754
# [1976]	validation_0-logloss:0.46448	validation_0-auc:0.98719	validation_1-logloss:0.56852	validation_1-auc:0.81777
# [1977]	validation_0-logloss:0.46432	validation_0-auc:0.98718	validation_1-logloss:0.56846	validation_1-auc:0.81777
# [1978]	validation_0-logloss:0.46415	validation_0-auc:0.98721	validation_1-logloss:0.56837	validation_1-auc:0.81777
# [1979]	validation_0-logloss:0.46415	validation_0-auc:0.98721	validation_1-logloss:0.56837	validation_1-auc:0.81777
# [1980]	validation_0-logloss:0.46415	validation_0-auc:0.98721	validation_1-logloss:0.56837	validation_1-auc:0.81777
# [1981]	validation_0-logloss:0.46415	validation_0-auc:0.98721	validation_1-logloss:0.56837	validation_1-auc:0.81777
# [1982]	validation_0-logloss:0.46401	validation_0-auc:0.98720	validation_1-logloss:0.56829	validation_1-auc:0.81785
# [1983]	validation_0-logloss:0.46401	validation_0-auc:0.98720	validation_1-logloss:0.56829	validation_1-auc:0.81785
# [1984]	validation_0-logloss:0.46387	validation_0-auc:0.98720	validation_1-logloss:0.56823	validation_1-auc:0.81777
# [1985]	validation_0-logloss:0.46371	validation_0-auc:0.98724	validation_1-logloss:0.56812	validation_1-auc:0.81808
# [1986]	validation_0-logloss:0.46357	validation_0-auc:0.98728	validation_1-logloss:0.56805	validation_1-auc:0.81777
# [1987]	validation_0-logloss:0.46357	validation_0-auc:0.98728	validation_1-logloss:0.56805	validation_1-auc:0.81777
# [1988]	validation_0-logloss:0.46341	validation_0-auc:0.98729	validation_1-logloss:0.56797	validation_1-auc:0.81777
# [1989]	validation_0-logloss:0.46341	validation_0-auc:0.98729	validation_1-logloss:0.56797	validation_1-auc:0.81777
# [1990]	validation_0-logloss:0.46341	validation_0-auc:0.98729	validation_1-logloss:0.56797	validation_1-auc:0.81777
# [1991]	validation_0-logloss:0.46341	validation_0-auc:0.98729	validation_1-logloss:0.56797	validation_1-auc:0.81777
# [1992]	validation_0-logloss:0.46341	validation_0-auc:0.98729	validation_1-logloss:0.56797	validation_1-auc:0.81777
# [1993]	validation_0-logloss:0.46324	validation_0-auc:0.98729	validation_1-logloss:0.56788	validation_1-auc:0.81823
# [1994]	validation_0-logloss:0.46324	validation_0-auc:0.98729	validation_1-logloss:0.56788	validation_1-auc:0.81823
# [1995]	validation_0-logloss:0.46309	validation_0-auc:0.98732	validation_1-logloss:0.56780	validation_1-auc:0.81808
# [1996]	validation_0-logloss:0.46309	validation_0-auc:0.98732	validation_1-logloss:0.56780	validation_1-auc:0.81808
# [1997]	validation_0-logloss:0.46294	validation_0-auc:0.98731	validation_1-logloss:0.56767	validation_1-auc:0.81823
# [1998]	validation_0-logloss:0.46294	validation_0-auc:0.98731	validation_1-logloss:0.56767	validation_1-auc:0.81823
# [1999]	validation_0-logloss:0.46294	validation_0-auc:0.98731	validation_1-logloss:0.56767	validation_1-auc:0.81823
# Accuracy: 0.734

# %%
# plot learning curves
pyplot.plot(results['validation_0']['auc'], label='train')
pyplot.plot(results['validation_1']['auc'], label='test')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()

# %%
print(classification_report(y_test,model.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.69      0.75      0.72       104
#            2       0.78      0.72      0.75       125
#
#     accuracy                           0.73       229
#    macro avg       0.73      0.73      0.73       229
# weighted avg       0.74      0.73      0.73       229

# %%
print(confusion_matrix(y_test,model.predict(X_test)))
# Out:
# [[78 26]
#  [35 90]]

# %% [markdown]
# # Lazy

# %%
import lazypredict
### importing LazyClassifier for classification problem
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric =None)
### fitting data in LazyClassifier
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
### lets check which model did better on Breast Cancer Dataset
#print(models)
# Out:
# 100%|██████████| 29/29 [00:08<00:00,  3.37it/s]

# %%
predictions
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     0.83               0.82     0.82      0.83
# ExtraTreesClassifier               0.82               0.82     0.82      0.82
# RandomForestClassifier             0.79               0.79     0.79      0.79
# XGBClassifier                      0.79               0.78     0.78      0.78
# LogisticRegression                 0.78               0.78     0.78      0.78
# NuSVC                              0.78               0.78     0.78      0.78
# AdaBoostClassifier                 0.78               0.78     0.78      0.78
# CalibratedClassifierCV             0.77               0.77     0.77      0.77
# BaggingClassifier                  0.76               0.77     0.77      0.76
# LinearSVC                          0.77               0.76     0.76      0.77
# Perceptron                         0.75               0.76     0.76      0.75
# SVC                                0.75               0.75     0.75      0.75
# SGDClassifier                      0.73               0.72     0.72      0.73
# RidgeClassifierCV                  0.71               0.71     0.71      0.71
# QuadraticDiscriminantAnalysis      0.71               0.71     0.71      0.71
# RidgeClassifier                    0.70               0.70     0.70      0.70
# PassiveAggressiveClassifier        0.70               0.69     0.69      0.70
# KNeighborsClassifier               0.69               0.68     0.68      0.69
# LinearDiscriminantAnalysis         0.68               0.68     0.68      0.68
# BernoulliNB                        0.64               0.66     0.66      0.63
# DecisionTreeClassifier             0.66               0.65     0.65      0.66
# GaussianNB                         0.59               0.62     0.62      0.53
# ExtraTreeClassifier                0.62               0.62     0.62      0.62
# NearestCentroid                    0.59               0.62     0.62      0.53
# LabelSpreading                     0.56               0.58     0.58      0.55
# LabelPropagation                   0.56               0.58     0.58      0.55
# DummyClassifier                    0.47               0.46     0.46      0.47
#
#                                Time Taken
# Model
# LGBMClassifier                       1.03
# ExtraTreesClassifier                 0.36
# RandomForestClassifier               0.72
# XGBClassifier                        1.22
# LogisticRegression                   0.12
# NuSVC                                0.34
# AdaBoostClassifier                   0.69
# CalibratedClassifierCV               1.44
# BaggingClassifier                    0.67
# LinearSVC                            0.39
# Perceptron                           0.04
# SVC                                  0.35
# SGDClassifier                        0.06
# RidgeClassifierCV                    0.09
# QuadraticDiscriminantAnalysis        0.08
# RidgeClassifier                      0.05
# PassiveAggressiveClassifier          0.05
# KNeighborsClassifier                 0.12
# LinearDiscriminantAnalysis           0.16
# BernoulliNB                          0.05
# DecisionTreeClassifier               0.14
# GaussianNB                           0.03
# ExtraTreeClassifier                  0.03
# NearestCentroid                      0.04
# LabelSpreading                       0.12
# LabelPropagation                     0.10
# DummyClassifier                      0.03
