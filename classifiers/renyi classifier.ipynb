# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/multiscale_entropy/calculated_entropy/renyi_data.csv',header=None)

# %%
df.shape
# Out:
# (1142, 191)

# %%
import numpy as np
y = df[df.shape[1]-1].values
df = df.dropna(axis=1, how='all')
df=df.replace([np.inf, -np.inf], np.nan)

df=df.T.fillna(df.mean(axis=1)).T

# %%
df.shape
# Out:
# (1142, 191)

# %%
cols_to_scale = list(df.columns)[:-1]
from sklearn.preprocessing import StandardScaler,MinMaxScaler,RobustScaler
scaler = StandardScaler()
df[cols_to_scale] = scaler.fit_transform(df[cols_to_scale])

# %%
X = df.drop([df.shape[1]-1], axis=1)

# %%
from collections import Counter
print(Counter(y))
# Out:
# Counter({2: 626, 1: 516})

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()

logreg.fit(X_train,y_train)
print(logreg.score(X_test,y_test))
from sklearn.metrics import confusion_matrix,classification_report
print(classification_report(y_test,logreg.predict(X_test)))
# Out:
# 0.7510917030567685
#               precision    recall  f1-score   support
#
#            1       0.72      0.75      0.73       104
#            2       0.78      0.75      0.77       125
#
#     accuracy                           0.75       229
#    macro avg       0.75      0.75      0.75       229
# weighted avg       0.75      0.75      0.75       229

# %% [markdown]
# svm

# %%
from sklearn.svm import SVC
svm = SVC(kernel = 'linear')
svm.fit(X_train,y_train)
svm.score(X_test,y_test)
# Out:
# 0.7292576419213974

# %%
print(classification_report(y_test,svm.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.68      0.76      0.72       104
#            2       0.78      0.70      0.74       125
#
#     accuracy                           0.73       229
#    macro avg       0.73      0.73      0.73       229
# weighted avg       0.73      0.73      0.73       229

# %% [markdown]
# # New Section

# %%
'''Set a seed for reproducibility'''
seed = 43

'''Initialize all the regression models object we are interested in.'''
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier,ExtraTreesClassifier,GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

'''We are interested in the following 14 regression models.
All initialized with default parameters except random_state and n_jobs.'''


et = ExtraTreesClassifier(n_jobs = -1, random_state = seed)
ab = AdaBoostClassifier(random_state = seed)
gb = GradientBoostingClassifier(random_state = seed)
xgb = XGBClassifier(random_state = seed, n_jobs = -1)
lgb = LGBMClassifier(random_state = seed, n_jobs = -1)

knn = KNeighborsClassifier(3)
lsvm = SVC(kernel="linear", C=0.025)
rsvm = SVC(kernel="rbf",gamma=2, C=1)
gps = GaussianProcessClassifier(1.0 * RBF(1.0))
dt = DecisionTreeClassifier(max_depth=5)
rf = RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1)
mlp = MLPClassifier(alpha=1, max_iter=1000)
gnb = GaussianNB()
qda = QuadraticDiscriminantAnalysis()

# %%
'''Evaluate models on the holdout set(say on 30%).'''
def train_test_split_score(model):
    from sklearn.metrics import mean_squared_error
    from sklearn.model_selection import train_test_split
    X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size = 0.2, random_state = seed)
    model.fit(X_train, Y_train)
    return model.score(X_test,Y_test)
'''Calculate train_test_split score of differnt models and plot them.'''
models = [et,ab,gb,xgb,lgb,knn,lsvm,rsvm,gps,dt,rf,mlp,gnb,qda]
train_test_split_res = []
for model in models:
    train_test_split_res.append(train_test_split_score(model))

'''Plot data frame of train test rmse'''
train_test_score = pd.DataFrame(data = train_test_split_res, columns = ['Train_Test_SCORE'])
train_test_score.index = ['ET', 'AB', 'GB', 'XGB', 'LGB', 'KNN', 'LSVM', 'RSVM', 'GPS', 'DT', 'RF', 'MLP', 'GNB', 'QDA']
train_test_score = train_test_score.round(5)
train_test_score
# Out:
#       Train_Test_SCORE
# ET                0.69
# AB                0.66
# GB                0.69
# XGB               0.70
# LGB               0.72
# KNN               0.73
# LSVM              0.69
# RSVM              0.55
# GPS               0.73
# DT                0.58
# RF                0.59
# MLP               0.70
# GNB               0.47
# QDA               0.67

# %%
def cross_validate(model):
    from sklearn.model_selection import cross_val_score
    score = cross_val_score(model, X, y, cv = 10, n_jobs = -1, scoring = 'accuracy')
    return score.mean()

'''Calculate cross validation score of differnt models and plot them.'''
models = [et,ab,gb,xgb,lgb,knn,lsvm,rsvm,gps,dt,rf,mlp,gnb,qda]
cross_val_scores = []
for model in models:
    cross_val_scores.append(cross_validate(model))

'''Plot data frame of cross validation scores.'''
x_val_score = pd.DataFrame(data = cross_val_scores, columns = ['Cross Validation Scores (ACC)'])
x_val_score.index = ['ET', 'AB', 'GB', 'XGB', 'LGB', 'KNN', 'LSVM', 'RSVM', 'GPS', 'DT', 'RF', 'MLP', 'GNB', 'QDA']

# %%
x_val_score
# Out:
#       Cross Validation Scores (ACC)
# ET                             0.63
# AB                             0.63
# GB                             0.65
# XGB                            0.64
# LGB                            0.64
# KNN                            0.59
# LSVM                           0.64
# RSVM                           0.55
# GPS                            0.67
# DT                             0.53
# RF                             0.61
# MLP                            0.66
# GNB                            0.46
# QDA                            0.61

# %%
'''Create a function to plot learning curves.'''
import matplotlib.pyplot as plt
import numpy as np

def plot_learning_curve(model):
    from sklearn.model_selection import learning_curve
    
    # df_train_final is training matrix and y_train is target matrix.
    # Create CV training and test scores for various training set sizes
    train_sizes, train_scores, test_scores = learning_curve(model, X, y, 
                                            train_sizes = np.linspace(0.01, 1.0, 20), cv = 10, scoring = 'accuracy', 
                                            n_jobs = -1, random_state = seed)
    
    
    # Create means and standard deviations of training set scores
    train_mean = np.mean(train_scores, axis = 1)
    train_std = np.std(train_scores, axis = 1)

    # Create means and standard deviations of test set scores
    test_mean = np.mean(test_scores, axis = 1)
    test_std = np.std(test_scores, axis = 1)  
    # Draw lines
    plt.plot(train_sizes, train_mean, 'o-', color = 'red',  label = 'Training score')
    plt.plot(train_sizes, test_mean, 'o-', color = 'green', label = 'Cross-validation score')
    
    # Draw bands
    plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, alpha = 0.1, color = 'r') # Alpha controls band transparency.
    plt.fill_between(train_sizes, test_mean - test_std, test_mean + test_std, alpha = 0.1, color = 'g')
    
    
    # Create plot
    font_size = 12
    plt.xlabel('Training Set Size', fontsize = font_size)
    plt.ylabel('Accuracy Score', fontsize = font_size)
    plt.xticks(fontsize = font_size)
    plt.yticks(fontsize = font_size)
    plt.legend(loc = 'best')
    plt.grid()

# %%
'''Now plot learning curves of the optimized models in subplots.
For computational reason, I am omitting XGB, GB, and LGB.'''
plt.figure(figsize = (16,24))
lc_models = [et,ab,gb,xgb,lgb,knn,lsvm,rsvm,gps,dt,rf,mlp,gnb,qda]
lc_labels = ['ET', 'AB', 'GB', 'XGB', 'LGB', 'KNN', 'LSVM', 'RSVM', 'GPS', 'DT', 'RF', 'MLP', 'GNB', 'QDA']

for ax, models, labels in zip (range(1,14), lc_models, lc_labels):
    try:
        plt.subplot(7,2,ax)
        plot_learning_curve(models)
        plt.title(labels, fontsize = 15)
    except:
        pass
plt.suptitle('Learning Curves of Optimized Models', fontsize = 20)
plt.tight_layout(rect = [0, 0.03, 1, 0.97])

# %% [markdown]
# # XGB

# %%
import xgboost as xgb
# read in data
'''
dtrain = xgb.DMatrix(X_train,y_train)
dtest = xgb.DMatrix(X_test,y_test)
evallist = [(dtest, 'eval'), (dtrain, 'train')]
# specify parameters via map
param = {'booster': 'dart',
         'max_depth': 5, 'learning_rate': 0.01,
         'objective': 'binary:logistic',
         'sample_type': 'uniform',
         'normalize_type': 'tree',
         'rate_drop': 0.1,
         'eval_metric':'auc',
         'skip_drop': 0.5}
num_round = 500
bst = xgb.train(param, dtrain, num_round,evallist)
preds = bst.predict(dtest)
'''
# Out:
# "\ndtrain = xgb.DMatrix(X_train,y_train)\ndtest = xgb.DMatrix(X_test,y_test)\nevallist = [(dtest, 'eval'), (dtrain, 'train')]\n# specify parameters via map\nparam = {'booster': 'dart',\n         'max_depth': 5, 'learning_rate': 0.01,\n         'objective': 'binary:logistic',\n         'sample_type': 'uniform',\n         'normalize_type': 'tree',\n         'rate_drop': 0.1,\n         'eval_metric':'auc',\n         'skip_drop': 0.5}\nnum_round = 500\nbst = xgb.train(param, dtrain, num_round,evallist)\npreds = bst.predict(dtest)\n"

# %%
#xgb.plot_importance(bst)

# %%
param = {'booster': 'dart',
         'max_depth': 5,
         'learning_rate': 0.001,
         'objective': 'binary:logistic',
         'sample_type': 'uniform',
         'normalize_type': 'tree',
         'rate_drop': 0.1,
         'skip_drop': 0.5,
         'n_estimators':2000}

# %%
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier
from matplotlib import pyplot
# define the model
model = XGBClassifier(**param)
# define the datasets to evaluate each iteration
evalset = [(X_train, y_train), (X_test,y_test)]
# fit the model
model.fit(X_train, y_train, eval_metric=['logloss','auc'], eval_set=evalset)
# evaluate performance
yhat = model.predict(X_test)
score = accuracy_score(y_test, yhat)
print('Accuracy: %.3f' % score)
# retrieve performance metrics
results = model.evals_result()
# plot learning curves
pyplot.plot(results['validation_0']['logloss'], label='train')
pyplot.plot(results['validation_1']['logloss'], label='test')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# [0]	validation_0-logloss:0.69278	validation_0-auc:0.84809	validation_1-logloss:0.69288	validation_1-auc:0.74800
# [1]	validation_0-logloss:0.69242	validation_0-auc:0.84850	validation_1-logloss:0.69261	validation_1-auc:0.75538
# [2]	validation_0-logloss:0.69206	validation_0-auc:0.85028	validation_1-logloss:0.69234	validation_1-auc:0.75504
# [3]	validation_0-logloss:0.69171	validation_0-auc:0.85005	validation_1-logloss:0.69207	validation_1-auc:0.75465
# [4]	validation_0-logloss:0.69135	validation_0-auc:0.84977	validation_1-logloss:0.69180	validation_1-auc:0.75450
# [5]	validation_0-logloss:0.69099	validation_0-auc:0.84970	validation_1-logloss:0.69153	validation_1-auc:0.75619
# [6]	validation_0-logloss:0.69064	validation_0-auc:0.84804	validation_1-logloss:0.69126	validation_1-auc:0.75419
# [7]	validation_0-logloss:0.69028	validation_0-auc:0.84810	validation_1-logloss:0.69100	validation_1-auc:0.75311
# [8]	validation_0-logloss:0.68993	validation_0-auc:0.84678	validation_1-logloss:0.69073	validation_1-auc:0.75250
# [9]	validation_0-logloss:0.68957	validation_0-auc:0.84683	validation_1-logloss:0.69046	validation_1-auc:0.75250
# [10]	validation_0-logloss:0.68922	validation_0-auc:0.84678	validation_1-logloss:0.69020	validation_1-auc:0.75250
# [11]	validation_0-logloss:0.68887	validation_0-auc:0.84643	validation_1-logloss:0.68994	validation_1-auc:0.75227
# [12]	validation_0-logloss:0.68851	validation_0-auc:0.84654	validation_1-logloss:0.68967	validation_1-auc:0.75127
# [13]	validation_0-logloss:0.68834	validation_0-auc:0.84649	validation_1-logloss:0.68954	validation_1-auc:0.75227
# [14]	validation_0-logloss:0.68816	validation_0-auc:0.84644	validation_1-logloss:0.68941	validation_1-auc:0.75227
# [15]	validation_0-logloss:0.68781	validation_0-auc:0.84706	validation_1-logloss:0.68914	validation_1-auc:0.75177
# [16]	validation_0-logloss:0.68745	validation_0-auc:0.84633	validation_1-logloss:0.68887	validation_1-auc:0.75331
# [17]	validation_0-logloss:0.68710	validation_0-auc:0.84622	validation_1-logloss:0.68861	validation_1-auc:0.75315
# [18]	validation_0-logloss:0.68675	validation_0-auc:0.84629	validation_1-logloss:0.68834	validation_1-auc:0.75400
# [19]	validation_0-logloss:0.68639	validation_0-auc:0.84633	validation_1-logloss:0.68807	validation_1-auc:0.75408
# [20]	validation_0-logloss:0.68605	validation_0-auc:0.84635	validation_1-logloss:0.68781	validation_1-auc:0.75331
# [21]	validation_0-logloss:0.68596	validation_0-auc:0.84633	validation_1-logloss:0.68775	validation_1-auc:0.75408
# [22]	validation_0-logloss:0.68578	validation_0-auc:0.84635	validation_1-logloss:0.68762	validation_1-auc:0.75400
# [23]	validation_0-logloss:0.68544	validation_0-auc:0.84635	validation_1-logloss:0.68736	validation_1-auc:0.75323
# [24]	validation_0-logloss:0.68509	validation_0-auc:0.84635	validation_1-logloss:0.68710	validation_1-auc:0.75331
# [25]	validation_0-logloss:0.68491	validation_0-auc:0.84635	validation_1-logloss:0.68697	validation_1-auc:0.75400
# [26]	validation_0-logloss:0.68456	validation_0-auc:0.84641	validation_1-logloss:0.68670	validation_1-auc:0.75331
# [27]	validation_0-logloss:0.68421	validation_0-auc:0.85581	validation_1-logloss:0.68645	validation_1-auc:0.75904
# [28]	validation_0-logloss:0.68387	validation_0-auc:0.85581	validation_1-logloss:0.68619	validation_1-auc:0.75881
# [29]	validation_0-logloss:0.68369	validation_0-auc:0.85586	validation_1-logloss:0.68606	validation_1-auc:0.75904
# [30]	validation_0-logloss:0.68335	validation_0-auc:0.85579	validation_1-logloss:0.68581	validation_1-auc:0.75904
# [31]	validation_0-logloss:0.68300	validation_0-auc:0.85586	validation_1-logloss:0.68555	validation_1-auc:0.76150
# [32]	validation_0-logloss:0.68266	validation_0-auc:0.85679	validation_1-logloss:0.68531	validation_1-auc:0.75796
# [33]	validation_0-logloss:0.68261	validation_0-auc:0.85679	validation_1-logloss:0.68527	validation_1-auc:0.75796
# [34]	validation_0-logloss:0.68252	validation_0-auc:0.85679	validation_1-logloss:0.68520	validation_1-auc:0.75796
# [35]	validation_0-logloss:0.68243	validation_0-auc:0.85586	validation_1-logloss:0.68514	validation_1-auc:0.76142
# [36]	validation_0-logloss:0.68209	validation_0-auc:0.85714	validation_1-logloss:0.68489	validation_1-auc:0.76342
# [37]	validation_0-logloss:0.68175	validation_0-auc:0.85713	validation_1-logloss:0.68464	validation_1-auc:0.76342
# [38]	validation_0-logloss:0.68140	validation_0-auc:0.85775	validation_1-logloss:0.68439	validation_1-auc:0.76104
# [39]	validation_0-logloss:0.68106	validation_0-auc:0.85773	validation_1-logloss:0.68413	validation_1-auc:0.76111
# [40]	validation_0-logloss:0.68094	validation_0-auc:0.85777	validation_1-logloss:0.68404	validation_1-auc:0.76111
# [41]	validation_0-logloss:0.68061	validation_0-auc:0.85779	validation_1-logloss:0.68381	validation_1-auc:0.76058
# [42]	validation_0-logloss:0.68026	validation_0-auc:0.85783	validation_1-logloss:0.68355	validation_1-auc:0.76065
# [43]	validation_0-logloss:0.67993	validation_0-auc:0.85781	validation_1-logloss:0.68331	validation_1-auc:0.76058
# [44]	validation_0-logloss:0.67958	validation_0-auc:0.85945	validation_1-logloss:0.68305	validation_1-auc:0.76150
# [45]	validation_0-logloss:0.67925	validation_0-auc:0.85947	validation_1-logloss:0.68281	validation_1-auc:0.76158
# [46]	validation_0-logloss:0.67891	validation_0-auc:0.85948	validation_1-logloss:0.68256	validation_1-auc:0.76150
# [47]	validation_0-logloss:0.67887	validation_0-auc:0.85943	validation_1-logloss:0.68253	validation_1-auc:0.76150
# [48]	validation_0-logloss:0.67875	validation_0-auc:0.85946	validation_1-logloss:0.68245	validation_1-auc:0.76150
# [49]	validation_0-logloss:0.67864	validation_0-auc:0.85950	validation_1-logloss:0.68236	validation_1-auc:0.76150
# [50]	validation_0-logloss:0.67860	validation_0-auc:0.85950	validation_1-logloss:0.68233	validation_1-auc:0.76150
# [51]	validation_0-logloss:0.67826	validation_0-auc:0.86738	validation_1-logloss:0.68209	validation_1-auc:0.76904
# [52]	validation_0-logloss:0.67821	validation_0-auc:0.86737	validation_1-logloss:0.68205	validation_1-auc:0.76904
# [53]	validation_0-logloss:0.67787	validation_0-auc:0.86754	validation_1-logloss:0.68180	validation_1-auc:0.76942
# [54]	validation_0-logloss:0.67783	validation_0-auc:0.86754	validation_1-logloss:0.68177	validation_1-auc:0.76942
# [55]	validation_0-logloss:0.67774	validation_0-auc:0.86754	validation_1-logloss:0.68170	validation_1-auc:0.76942
# [56]	validation_0-logloss:0.67741	validation_0-auc:0.86739	validation_1-logloss:0.68147	validation_1-auc:0.76904
# [57]	validation_0-logloss:0.67707	validation_0-auc:0.86747	validation_1-logloss:0.68123	validation_1-auc:0.76935
# [58]	validation_0-logloss:0.67674	validation_0-auc:0.86747	validation_1-logloss:0.68098	validation_1-auc:0.76942
# [59]	validation_0-logloss:0.67668	validation_0-auc:0.86752	validation_1-logloss:0.68094	validation_1-auc:0.76935
# [60]	validation_0-logloss:0.67663	validation_0-auc:0.86749	validation_1-logloss:0.68090	validation_1-auc:0.76935
# [61]	validation_0-logloss:0.67629	validation_0-auc:0.86740	validation_1-logloss:0.68066	validation_1-auc:0.76935
# [62]	validation_0-logloss:0.67625	validation_0-auc:0.86740	validation_1-logloss:0.68063	validation_1-auc:0.76935
# [63]	validation_0-logloss:0.67592	validation_0-auc:0.86744	validation_1-logloss:0.68038	validation_1-auc:0.76935
# [64]	validation_0-logloss:0.67585	validation_0-auc:0.86742	validation_1-logloss:0.68034	validation_1-auc:0.76935
# [65]	validation_0-logloss:0.67552	validation_0-auc:0.86748	validation_1-logloss:0.68009	validation_1-auc:0.76935
# [66]	validation_0-logloss:0.67546	validation_0-auc:0.86748	validation_1-logloss:0.68005	validation_1-auc:0.76935
# [67]	validation_0-logloss:0.67541	validation_0-auc:0.86748	validation_1-logloss:0.68001	validation_1-auc:0.76935
# [68]	validation_0-logloss:0.67534	validation_0-auc:0.86748	validation_1-logloss:0.67996	validation_1-auc:0.76935
# [69]	validation_0-logloss:0.67500	validation_0-auc:0.86740	validation_1-logloss:0.67972	validation_1-auc:0.76896
# [70]	validation_0-logloss:0.67468	validation_0-auc:0.86742	validation_1-logloss:0.67949	validation_1-auc:0.76896
# [71]	validation_0-logloss:0.67462	validation_0-auc:0.86746	validation_1-logloss:0.67945	validation_1-auc:0.76896
# [72]	validation_0-logloss:0.67459	validation_0-auc:0.86746	validation_1-logloss:0.67942	validation_1-auc:0.76896
# [73]	validation_0-logloss:0.67425	validation_0-auc:0.86744	validation_1-logloss:0.67918	validation_1-auc:0.76896
# [74]	validation_0-logloss:0.67420	validation_0-auc:0.86744	validation_1-logloss:0.67914	validation_1-auc:0.76896
# [75]	validation_0-logloss:0.67387	validation_0-auc:0.86744	validation_1-logloss:0.67890	validation_1-auc:0.76896
# [76]	validation_0-logloss:0.67384	validation_0-auc:0.86744	validation_1-logloss:0.67888	validation_1-auc:0.76896
# [77]	validation_0-logloss:0.67379	validation_0-auc:0.86744	validation_1-logloss:0.67885	validation_1-auc:0.76896
# [78]	validation_0-logloss:0.67346	validation_0-auc:0.86744	validation_1-logloss:0.67861	validation_1-auc:0.76896
# [79]	validation_0-logloss:0.67314	validation_0-auc:0.86753	validation_1-logloss:0.67837	validation_1-auc:0.76896
# [80]	validation_0-logloss:0.67281	validation_0-auc:0.86753	validation_1-logloss:0.67813	validation_1-auc:0.76896
# [81]	validation_0-logloss:0.67248	validation_0-auc:0.86787	validation_1-logloss:0.67790	validation_1-auc:0.76896
# [82]	validation_0-logloss:0.67216	validation_0-auc:0.86716	validation_1-logloss:0.67767	validation_1-auc:0.76896
# [83]	validation_0-logloss:0.67183	validation_0-auc:0.86736	validation_1-logloss:0.67743	validation_1-auc:0.76896
# [84]	validation_0-logloss:0.67150	validation_0-auc:0.86905	validation_1-logloss:0.67721	validation_1-auc:0.76877
# [85]	validation_0-logloss:0.67118	validation_0-auc:0.86728	validation_1-logloss:0.67698	validation_1-auc:0.76877
# [86]	validation_0-logloss:0.67115	validation_0-auc:0.86728	validation_1-logloss:0.67696	validation_1-auc:0.76877
# [87]	validation_0-logloss:0.67108	validation_0-auc:0.86728	validation_1-logloss:0.67691	validation_1-auc:0.76877
# [88]	validation_0-logloss:0.67102	validation_0-auc:0.86728	validation_1-logloss:0.67686	validation_1-auc:0.76877
# [89]	validation_0-logloss:0.67068	validation_0-auc:0.87678	validation_1-logloss:0.67662	validation_1-auc:0.77569
# [90]	validation_0-logloss:0.67036	validation_0-auc:0.87479	validation_1-logloss:0.67641	validation_1-auc:0.77523
# [91]	validation_0-logloss:0.67033	validation_0-auc:0.87475	validation_1-logloss:0.67638	validation_1-auc:0.77523
# [92]	validation_0-logloss:0.67028	validation_0-auc:0.87486	validation_1-logloss:0.67634	validation_1-auc:0.77508
# [93]	validation_0-logloss:0.67024	validation_0-auc:0.87629	validation_1-logloss:0.67631	validation_1-auc:0.77523
# [94]	validation_0-logloss:0.67019	validation_0-auc:0.87482	validation_1-logloss:0.67628	validation_1-auc:0.77508
# [95]	validation_0-logloss:0.66985	validation_0-auc:0.87900	validation_1-logloss:0.67604	validation_1-auc:0.77938
# [96]	validation_0-logloss:0.66982	validation_0-auc:0.87900	validation_1-logloss:0.67601	validation_1-auc:0.77938
# [97]	validation_0-logloss:0.66977	validation_0-auc:0.87900	validation_1-logloss:0.67598	validation_1-auc:0.77938
# [98]	validation_0-logloss:0.66946	validation_0-auc:0.87887	validation_1-logloss:0.67576	validation_1-auc:0.77938
# [99]	validation_0-logloss:0.66942	validation_0-auc:0.87890	validation_1-logloss:0.67573	validation_1-auc:0.77938
# [100]	validation_0-logloss:0.66938	validation_0-auc:0.87891	validation_1-logloss:0.67570	validation_1-auc:0.77938
# [101]	validation_0-logloss:0.66904	validation_0-auc:0.87962	validation_1-logloss:0.67546	validation_1-auc:0.78292
# [102]	validation_0-logloss:0.66901	validation_0-auc:0.87960	validation_1-logloss:0.67544	validation_1-auc:0.78292
# [103]	validation_0-logloss:0.66899	validation_0-auc:0.87962	validation_1-logloss:0.67542	validation_1-auc:0.78292
# [104]	validation_0-logloss:0.66897	validation_0-auc:0.87959	validation_1-logloss:0.67541	validation_1-auc:0.78292
# [105]	validation_0-logloss:0.66893	validation_0-auc:0.87962	validation_1-logloss:0.67538	validation_1-auc:0.78292
# [106]	validation_0-logloss:0.66860	validation_0-auc:0.87959	validation_1-logloss:0.67515	validation_1-auc:0.78292
# [107]	validation_0-logloss:0.66828	validation_0-auc:0.87974	validation_1-logloss:0.67493	validation_1-auc:0.78300
# [108]	validation_0-logloss:0.66795	validation_0-auc:0.88026	validation_1-logloss:0.67469	validation_1-auc:0.78308
# [109]	validation_0-logloss:0.66793	validation_0-auc:0.88023	validation_1-logloss:0.67468	validation_1-auc:0.78308
# [110]	validation_0-logloss:0.66791	validation_0-auc:0.88023	validation_1-logloss:0.67466	validation_1-auc:0.78308
# [111]	validation_0-logloss:0.66759	validation_0-auc:0.88016	validation_1-logloss:0.67444	validation_1-auc:0.78323
# [112]	validation_0-logloss:0.66726	validation_0-auc:0.88086	validation_1-logloss:0.67423	validation_1-auc:0.78265
# [113]	validation_0-logloss:0.66723	validation_0-auc:0.88086	validation_1-logloss:0.67420	validation_1-auc:0.78265
# [114]	validation_0-logloss:0.66692	validation_0-auc:0.88114	validation_1-logloss:0.67398	validation_1-auc:0.78281
# [115]	validation_0-logloss:0.66658	validation_0-auc:0.88114	validation_1-logloss:0.67375	validation_1-auc:0.78265
# [116]	validation_0-logloss:0.66656	validation_0-auc:0.88114	validation_1-logloss:0.67373	validation_1-auc:0.78265
# [117]	validation_0-logloss:0.66625	validation_0-auc:0.88099	validation_1-logloss:0.67351	validation_1-auc:0.78242
# [118]	validation_0-logloss:0.66593	validation_0-auc:0.88116	validation_1-logloss:0.67329	validation_1-auc:0.78258
# [119]	validation_0-logloss:0.66590	validation_0-auc:0.88116	validation_1-logloss:0.67328	validation_1-auc:0.78258
# [120]	validation_0-logloss:0.66587	validation_0-auc:0.88116	validation_1-logloss:0.67326	validation_1-auc:0.78258
# [121]	validation_0-logloss:0.66585	validation_0-auc:0.88060	validation_1-logloss:0.67324	validation_1-auc:0.78389
# [122]	validation_0-logloss:0.66552	validation_0-auc:0.88075	validation_1-logloss:0.67302	validation_1-auc:0.78258
# [123]	validation_0-logloss:0.66550	validation_0-auc:0.88075	validation_1-logloss:0.67300	validation_1-auc:0.78258
# [124]	validation_0-logloss:0.66548	validation_0-auc:0.88071	validation_1-logloss:0.67298	validation_1-auc:0.78258
# [125]	validation_0-logloss:0.66517	validation_0-auc:0.88089	validation_1-logloss:0.67277	validation_1-auc:0.78258
# [126]	validation_0-logloss:0.66484	validation_0-auc:0.88114	validation_1-logloss:0.67256	validation_1-auc:0.78258
# [127]	validation_0-logloss:0.66453	validation_0-auc:0.88131	validation_1-logloss:0.67235	validation_1-auc:0.78273
# [128]	validation_0-logloss:0.66450	validation_0-auc:0.88131	validation_1-logloss:0.67233	validation_1-auc:0.78273
# [129]	validation_0-logloss:0.66418	validation_0-auc:0.88126	validation_1-logloss:0.67210	validation_1-auc:0.78289
# [130]	validation_0-logloss:0.66415	validation_0-auc:0.88114	validation_1-logloss:0.67208	validation_1-auc:0.78289
# [131]	validation_0-logloss:0.66385	validation_0-auc:0.88130	validation_1-logloss:0.67187	validation_1-auc:0.78273
# [132]	validation_0-logloss:0.66382	validation_0-auc:0.88130	validation_1-logloss:0.67185	validation_1-auc:0.78273
# [133]	validation_0-logloss:0.66350	validation_0-auc:0.88127	validation_1-logloss:0.67165	validation_1-auc:0.77958
# [134]	validation_0-logloss:0.66347	validation_0-auc:0.88127	validation_1-logloss:0.67163	validation_1-auc:0.77958
# [135]	validation_0-logloss:0.66316	validation_0-auc:0.88128	validation_1-logloss:0.67141	validation_1-auc:0.77973
# [136]	validation_0-logloss:0.66284	validation_0-auc:0.88107	validation_1-logloss:0.67118	validation_1-auc:0.78096
# [137]	validation_0-logloss:0.66252	validation_0-auc:0.88129	validation_1-logloss:0.67096	validation_1-auc:0.78089
# [138]	validation_0-logloss:0.66250	validation_0-auc:0.88131	validation_1-logloss:0.67094	validation_1-auc:0.78358
# [139]	validation_0-logloss:0.66218	validation_0-auc:0.88161	validation_1-logloss:0.67074	validation_1-auc:0.78058
# [140]	validation_0-logloss:0.66187	validation_0-auc:0.88175	validation_1-logloss:0.67052	validation_1-auc:0.78069
# [141]	validation_0-logloss:0.66184	validation_0-auc:0.88172	validation_1-logloss:0.67049	validation_1-auc:0.78069
# [142]	validation_0-logloss:0.66181	validation_0-auc:0.88168	validation_1-logloss:0.67048	validation_1-auc:0.78069
# [143]	validation_0-logloss:0.66177	validation_0-auc:0.88175	validation_1-logloss:0.67046	validation_1-auc:0.78069
# [144]	validation_0-logloss:0.66147	validation_0-auc:0.88176	validation_1-logloss:0.67024	validation_1-auc:0.78038
# [145]	validation_0-logloss:0.66115	validation_0-auc:0.88210	validation_1-logloss:0.67002	validation_1-auc:0.78154
# [146]	validation_0-logloss:0.66113	validation_0-auc:0.88210	validation_1-logloss:0.67001	validation_1-auc:0.78154
# [147]	validation_0-logloss:0.66111	validation_0-auc:0.88210	validation_1-logloss:0.66999	validation_1-auc:0.78154
# [148]	validation_0-logloss:0.66081	validation_0-auc:0.88230	validation_1-logloss:0.66978	validation_1-auc:0.78154
# [149]	validation_0-logloss:0.66049	validation_0-auc:0.88328	validation_1-logloss:0.66958	validation_1-auc:0.78231
# [150]	validation_0-logloss:0.66019	validation_0-auc:0.88339	validation_1-logloss:0.66937	validation_1-auc:0.78215
# [151]	validation_0-logloss:0.65987	validation_0-auc:0.88341	validation_1-logloss:0.66914	validation_1-auc:0.78231
# [152]	validation_0-logloss:0.65985	validation_0-auc:0.88341	validation_1-logloss:0.66912	validation_1-auc:0.78231
# [153]	validation_0-logloss:0.65983	validation_0-auc:0.88341	validation_1-logloss:0.66911	validation_1-auc:0.78231
# [154]	validation_0-logloss:0.65980	validation_0-auc:0.88341	validation_1-logloss:0.66909	validation_1-auc:0.78231
# [155]	validation_0-logloss:0.65977	validation_0-auc:0.88341	validation_1-logloss:0.66907	validation_1-auc:0.78231
# [156]	validation_0-logloss:0.65975	validation_0-auc:0.88341	validation_1-logloss:0.66905	validation_1-auc:0.78231
# [157]	validation_0-logloss:0.65945	validation_0-auc:0.88341	validation_1-logloss:0.66884	validation_1-auc:0.78231
# [158]	validation_0-logloss:0.65942	validation_0-auc:0.88341	validation_1-logloss:0.66882	validation_1-auc:0.78231
# [159]	validation_0-logloss:0.65910	validation_0-auc:0.88743	validation_1-logloss:0.66864	validation_1-auc:0.78108
# [160]	validation_0-logloss:0.65878	validation_0-auc:0.88776	validation_1-logloss:0.66843	validation_1-auc:0.78131
# [161]	validation_0-logloss:0.65877	validation_0-auc:0.88773	validation_1-logloss:0.66842	validation_1-auc:0.78131
# [162]	validation_0-logloss:0.65845	validation_0-auc:0.88813	validation_1-logloss:0.66823	validation_1-auc:0.78146
# [163]	validation_0-logloss:0.65815	validation_0-auc:0.88810	validation_1-logloss:0.66802	validation_1-auc:0.78123
# [164]	validation_0-logloss:0.65813	validation_0-auc:0.88810	validation_1-logloss:0.66801	validation_1-auc:0.78123
# [165]	validation_0-logloss:0.65812	validation_0-auc:0.88808	validation_1-logloss:0.66800	validation_1-auc:0.78123
# [166]	validation_0-logloss:0.65809	validation_0-auc:0.88811	validation_1-logloss:0.66799	validation_1-auc:0.78123
# [167]	validation_0-logloss:0.65777	validation_0-auc:0.88857	validation_1-logloss:0.66780	validation_1-auc:0.78146
# [168]	validation_0-logloss:0.65747	validation_0-auc:0.88861	validation_1-logloss:0.66759	validation_1-auc:0.78115
# [169]	validation_0-logloss:0.65745	validation_0-auc:0.88861	validation_1-logloss:0.66757	validation_1-auc:0.78115
# [170]	validation_0-logloss:0.65713	validation_0-auc:0.88905	validation_1-logloss:0.66738	validation_1-auc:0.78138
# [171]	validation_0-logloss:0.65682	validation_0-auc:0.88935	validation_1-logloss:0.66718	validation_1-auc:0.78146
# [172]	validation_0-logloss:0.65680	validation_0-auc:0.88937	validation_1-logloss:0.66717	validation_1-auc:0.78146
# [173]	validation_0-logloss:0.65649	validation_0-auc:0.88962	validation_1-logloss:0.66699	validation_1-auc:0.78154
# [174]	validation_0-logloss:0.65617	validation_0-auc:0.89045	validation_1-logloss:0.66677	validation_1-auc:0.78169
# [175]	validation_0-logloss:0.65586	validation_0-auc:0.89062	validation_1-logloss:0.66658	validation_1-auc:0.78192
# [176]	validation_0-logloss:0.65554	validation_0-auc:0.89106	validation_1-logloss:0.66637	validation_1-auc:0.78146
# [177]	validation_0-logloss:0.65524	validation_0-auc:0.89121	validation_1-logloss:0.66616	validation_1-auc:0.78108
# [178]	validation_0-logloss:0.65492	validation_0-auc:0.89167	validation_1-logloss:0.66597	validation_1-auc:0.78146
# [179]	validation_0-logloss:0.65491	validation_0-auc:0.89167	validation_1-logloss:0.66597	validation_1-auc:0.78146
# [180]	validation_0-logloss:0.65489	validation_0-auc:0.89165	validation_1-logloss:0.66595	validation_1-auc:0.78146
# [181]	validation_0-logloss:0.65488	validation_0-auc:0.89165	validation_1-logloss:0.66594	validation_1-auc:0.78146
# [182]	validation_0-logloss:0.65456	validation_0-auc:0.89197	validation_1-logloss:0.66573	validation_1-auc:0.78246
# [183]	validation_0-logloss:0.65425	validation_0-auc:0.89221	validation_1-logloss:0.66554	validation_1-auc:0.78292
# [184]	validation_0-logloss:0.65423	validation_0-auc:0.89221	validation_1-logloss:0.66553	validation_1-auc:0.78292
# [185]	validation_0-logloss:0.65420	validation_0-auc:0.89215	validation_1-logloss:0.66551	validation_1-auc:0.78292
# [186]	validation_0-logloss:0.65389	validation_0-auc:0.89259	validation_1-logloss:0.66530	validation_1-auc:0.78285
# [187]	validation_0-logloss:0.65357	validation_0-auc:0.89348	validation_1-logloss:0.66512	validation_1-auc:0.77869
# [188]	validation_0-logloss:0.65326	validation_0-auc:0.89353	validation_1-logloss:0.66490	validation_1-auc:0.77823
# [189]	validation_0-logloss:0.65325	validation_0-auc:0.89353	validation_1-logloss:0.66490	validation_1-auc:0.77823
# [190]	validation_0-logloss:0.65323	validation_0-auc:0.89353	validation_1-logloss:0.66489	validation_1-auc:0.77823
# [191]	validation_0-logloss:0.65293	validation_0-auc:0.89426	validation_1-logloss:0.66470	validation_1-auc:0.78046
# [192]	validation_0-logloss:0.65291	validation_0-auc:0.89426	validation_1-logloss:0.66469	validation_1-auc:0.78046
# [193]	validation_0-logloss:0.65260	validation_0-auc:0.89460	validation_1-logloss:0.66448	validation_1-auc:0.78015
# [194]	validation_0-logloss:0.65228	validation_0-auc:0.89505	validation_1-logloss:0.66429	validation_1-auc:0.78042
# [195]	validation_0-logloss:0.65199	validation_0-auc:0.89461	validation_1-logloss:0.66408	validation_1-auc:0.78042
# [196]	validation_0-logloss:0.65168	validation_0-auc:0.89638	validation_1-logloss:0.66390	validation_1-auc:0.78342
# [197]	validation_0-logloss:0.65136	validation_0-auc:0.89606	validation_1-logloss:0.66369	validation_1-auc:0.78296
# [198]	validation_0-logloss:0.65136	validation_0-auc:0.89606	validation_1-logloss:0.66368	validation_1-auc:0.78296
# [199]	validation_0-logloss:0.65104	validation_0-auc:0.89580	validation_1-logloss:0.66347	validation_1-auc:0.78273
# [200]	validation_0-logloss:0.65073	validation_0-auc:0.89877	validation_1-logloss:0.66326	validation_1-auc:0.78888
# [201]	validation_0-logloss:0.65072	validation_0-auc:0.89877	validation_1-logloss:0.66325	validation_1-auc:0.78888
# [202]	validation_0-logloss:0.65070	validation_0-auc:0.89880	validation_1-logloss:0.66324	validation_1-auc:0.78888
# [203]	validation_0-logloss:0.65039	validation_0-auc:0.89940	validation_1-logloss:0.66305	validation_1-auc:0.78773
# [204]	validation_0-logloss:0.65008	validation_0-auc:0.90007	validation_1-logloss:0.66285	validation_1-auc:0.79012
# [205]	validation_0-logloss:0.64979	validation_0-auc:0.89961	validation_1-logloss:0.66265	validation_1-auc:0.78988
# [206]	validation_0-logloss:0.64948	validation_0-auc:0.89977	validation_1-logloss:0.66244	validation_1-auc:0.78765
# [207]	validation_0-logloss:0.64917	validation_0-auc:0.90028	validation_1-logloss:0.66223	validation_1-auc:0.78796
# [208]	validation_0-logloss:0.64915	validation_0-auc:0.90014	validation_1-logloss:0.66222	validation_1-auc:0.78796
# [209]	validation_0-logloss:0.64884	validation_0-auc:0.90061	validation_1-logloss:0.66202	validation_1-auc:0.78612
# [210]	validation_0-logloss:0.64883	validation_0-auc:0.90042	validation_1-logloss:0.66202	validation_1-auc:0.78612
# [211]	validation_0-logloss:0.64852	validation_0-auc:0.90094	validation_1-logloss:0.66181	validation_1-auc:0.78781
# [212]	validation_0-logloss:0.64851	validation_0-auc:0.90095	validation_1-logloss:0.66180	validation_1-auc:0.78781
# [213]	validation_0-logloss:0.64849	validation_0-auc:0.90092	validation_1-logloss:0.66179	validation_1-auc:0.78781
# [214]	validation_0-logloss:0.64848	validation_0-auc:0.90093	validation_1-logloss:0.66178	validation_1-auc:0.78781
# [215]	validation_0-logloss:0.64817	validation_0-auc:0.90124	validation_1-logloss:0.66158	validation_1-auc:0.78712
# [216]	validation_0-logloss:0.64787	validation_0-auc:0.90141	validation_1-logloss:0.66137	validation_1-auc:0.78850
# [217]	validation_0-logloss:0.64785	validation_0-auc:0.90140	validation_1-logloss:0.66136	validation_1-auc:0.78850
# [218]	validation_0-logloss:0.64754	validation_0-auc:0.90177	validation_1-logloss:0.66115	validation_1-auc:0.78827
# [219]	validation_0-logloss:0.64753	validation_0-auc:0.90178	validation_1-logloss:0.66114	validation_1-auc:0.78827
# [220]	validation_0-logloss:0.64751	validation_0-auc:0.90178	validation_1-logloss:0.66112	validation_1-auc:0.78827
# [221]	validation_0-logloss:0.64749	validation_0-auc:0.90178	validation_1-logloss:0.66111	validation_1-auc:0.78827
# [222]	validation_0-logloss:0.64748	validation_0-auc:0.90177	validation_1-logloss:0.66110	validation_1-auc:0.78827
# [223]	validation_0-logloss:0.64746	validation_0-auc:0.90177	validation_1-logloss:0.66109	validation_1-auc:0.78827
# [224]	validation_0-logloss:0.64716	validation_0-auc:0.90149	validation_1-logloss:0.66092	validation_1-auc:0.78681
# [225]	validation_0-logloss:0.64686	validation_0-auc:0.90164	validation_1-logloss:0.66071	validation_1-auc:0.78681
# [226]	validation_0-logloss:0.64684	validation_0-auc:0.90163	validation_1-logloss:0.66070	validation_1-auc:0.78681
# [227]	validation_0-logloss:0.64654	validation_0-auc:0.90196	validation_1-logloss:0.66050	validation_1-auc:0.78727
# [228]	validation_0-logloss:0.64623	validation_0-auc:0.90207	validation_1-logloss:0.66031	validation_1-auc:0.78819
# [229]	validation_0-logloss:0.64592	validation_0-auc:0.90223	validation_1-logloss:0.66011	validation_1-auc:0.78835
# [230]	validation_0-logloss:0.64591	validation_0-auc:0.90223	validation_1-logloss:0.66010	validation_1-auc:0.78835
# [231]	validation_0-logloss:0.64560	validation_0-auc:0.90213	validation_1-logloss:0.65989	validation_1-auc:0.78742
# [232]	validation_0-logloss:0.64559	validation_0-auc:0.90213	validation_1-logloss:0.65988	validation_1-auc:0.78742
# [233]	validation_0-logloss:0.64558	validation_0-auc:0.90214	validation_1-logloss:0.65987	validation_1-auc:0.78742
# [234]	validation_0-logloss:0.64557	validation_0-auc:0.90214	validation_1-logloss:0.65987	validation_1-auc:0.78742
# [235]	validation_0-logloss:0.64527	validation_0-auc:0.90258	validation_1-logloss:0.65966	validation_1-auc:0.78865
# [236]	validation_0-logloss:0.64525	validation_0-auc:0.90257	validation_1-logloss:0.65965	validation_1-auc:0.78865
# [237]	validation_0-logloss:0.64524	validation_0-auc:0.90258	validation_1-logloss:0.65964	validation_1-auc:0.78865
# [238]	validation_0-logloss:0.64523	validation_0-auc:0.90258	validation_1-logloss:0.65963	validation_1-auc:0.78865
# [239]	validation_0-logloss:0.64522	validation_0-auc:0.90258	validation_1-logloss:0.65962	validation_1-auc:0.78865
# [240]	validation_0-logloss:0.64521	validation_0-auc:0.90258	validation_1-logloss:0.65962	validation_1-auc:0.78881
# [241]	validation_0-logloss:0.64490	validation_0-auc:0.90282	validation_1-logloss:0.65942	validation_1-auc:0.78896
# [242]	validation_0-logloss:0.64489	validation_0-auc:0.90282	validation_1-logloss:0.65941	validation_1-auc:0.78896
# [243]	validation_0-logloss:0.64459	validation_0-auc:0.90300	validation_1-logloss:0.65923	validation_1-auc:0.78888
# [244]	validation_0-logloss:0.64428	validation_0-auc:0.90298	validation_1-logloss:0.65902	validation_1-auc:0.78912
# [245]	validation_0-logloss:0.64427	validation_0-auc:0.90298	validation_1-logloss:0.65902	validation_1-auc:0.78912
# [246]	validation_0-logloss:0.64397	validation_0-auc:0.90327	validation_1-logloss:0.65881	validation_1-auc:0.78819
# [247]	validation_0-logloss:0.64367	validation_0-auc:0.90344	validation_1-logloss:0.65861	validation_1-auc:0.78865
# [248]	validation_0-logloss:0.64336	validation_0-auc:0.90381	validation_1-logloss:0.65842	validation_1-auc:0.78750
# [249]	validation_0-logloss:0.64306	validation_0-auc:0.90398	validation_1-logloss:0.65823	validation_1-auc:0.78742
# [250]	validation_0-logloss:0.64276	validation_0-auc:0.90401	validation_1-logloss:0.65805	validation_1-auc:0.78712
# [251]	validation_0-logloss:0.64246	validation_0-auc:0.90344	validation_1-logloss:0.65785	validation_1-auc:0.78527
# [252]	validation_0-logloss:0.64217	validation_0-auc:0.90351	validation_1-logloss:0.65767	validation_1-auc:0.78535
# [253]	validation_0-logloss:0.64215	validation_0-auc:0.90342	validation_1-logloss:0.65766	validation_1-auc:0.78542
# [254]	validation_0-logloss:0.64187	validation_0-auc:0.90345	validation_1-logloss:0.65747	validation_1-auc:0.78573
# [255]	validation_0-logloss:0.64157	validation_0-auc:0.90393	validation_1-logloss:0.65727	validation_1-auc:0.78519
# [256]	validation_0-logloss:0.64127	validation_0-auc:0.90417	validation_1-logloss:0.65708	validation_1-auc:0.78550
# [257]	validation_0-logloss:0.64126	validation_0-auc:0.90415	validation_1-logloss:0.65708	validation_1-auc:0.78550
# [258]	validation_0-logloss:0.64125	validation_0-auc:0.90415	validation_1-logloss:0.65707	validation_1-auc:0.78550
# [259]	validation_0-logloss:0.64095	validation_0-auc:0.90421	validation_1-logloss:0.65689	validation_1-auc:0.78635
# [260]	validation_0-logloss:0.64094	validation_0-auc:0.90421	validation_1-logloss:0.65688	validation_1-auc:0.78635
# [261]	validation_0-logloss:0.64065	validation_0-auc:0.90425	validation_1-logloss:0.65668	validation_1-auc:0.78635
# [262]	validation_0-logloss:0.64035	validation_0-auc:0.90453	validation_1-logloss:0.65648	validation_1-auc:0.78512
# [263]	validation_0-logloss:0.64034	validation_0-auc:0.90454	validation_1-logloss:0.65648	validation_1-auc:0.78512
# [264]	validation_0-logloss:0.64005	validation_0-auc:0.90491	validation_1-logloss:0.65628	validation_1-auc:0.78550
# [265]	validation_0-logloss:0.64004	validation_0-auc:0.90491	validation_1-logloss:0.65627	validation_1-auc:0.78550
# [266]	validation_0-logloss:0.63974	validation_0-auc:0.90506	validation_1-logloss:0.65608	validation_1-auc:0.78496
# [267]	validation_0-logloss:0.63973	validation_0-auc:0.90506	validation_1-logloss:0.65607	validation_1-auc:0.78496
# [268]	validation_0-logloss:0.63972	validation_0-auc:0.90507	validation_1-logloss:0.65607	validation_1-auc:0.78496
# [269]	validation_0-logloss:0.63942	validation_0-auc:0.90503	validation_1-logloss:0.65587	validation_1-auc:0.78450
# [270]	validation_0-logloss:0.63913	validation_0-auc:0.90505	validation_1-logloss:0.65568	validation_1-auc:0.78489
# [271]	validation_0-logloss:0.63912	validation_0-auc:0.90505	validation_1-logloss:0.65567	validation_1-auc:0.78489
# [272]	validation_0-logloss:0.63882	validation_0-auc:0.90515	validation_1-logloss:0.65549	validation_1-auc:0.78481
# [273]	validation_0-logloss:0.63853	validation_0-auc:0.90553	validation_1-logloss:0.65531	validation_1-auc:0.78442
# [274]	validation_0-logloss:0.63852	validation_0-auc:0.90553	validation_1-logloss:0.65530	validation_1-auc:0.78442
# [275]	validation_0-logloss:0.63823	validation_0-auc:0.90554	validation_1-logloss:0.65509	validation_1-auc:0.78427
# [276]	validation_0-logloss:0.63822	validation_0-auc:0.90553	validation_1-logloss:0.65509	validation_1-auc:0.78427
# [277]	validation_0-logloss:0.63821	validation_0-auc:0.90560	validation_1-logloss:0.65508	validation_1-auc:0.78427
# [278]	validation_0-logloss:0.63820	validation_0-auc:0.90562	validation_1-logloss:0.65507	validation_1-auc:0.78427
# [279]	validation_0-logloss:0.63819	validation_0-auc:0.90562	validation_1-logloss:0.65507	validation_1-auc:0.78427
# [280]	validation_0-logloss:0.63818	validation_0-auc:0.90562	validation_1-logloss:0.65506	validation_1-auc:0.78427
# [281]	validation_0-logloss:0.63817	validation_0-auc:0.90563	validation_1-logloss:0.65505	validation_1-auc:0.78427
# [282]	validation_0-logloss:0.63787	validation_0-auc:0.90573	validation_1-logloss:0.65486	validation_1-auc:0.78435
# [283]	validation_0-logloss:0.63786	validation_0-auc:0.90573	validation_1-logloss:0.65485	validation_1-auc:0.78435
# [284]	validation_0-logloss:0.63757	validation_0-auc:0.90577	validation_1-logloss:0.65465	validation_1-auc:0.78458
# [285]	validation_0-logloss:0.63756	validation_0-auc:0.90577	validation_1-logloss:0.65465	validation_1-auc:0.78458
# [286]	validation_0-logloss:0.63755	validation_0-auc:0.90577	validation_1-logloss:0.65464	validation_1-auc:0.78435
# [287]	validation_0-logloss:0.63754	validation_0-auc:0.90578	validation_1-logloss:0.65463	validation_1-auc:0.78435
# [288]	validation_0-logloss:0.63725	validation_0-auc:0.90577	validation_1-logloss:0.65443	validation_1-auc:0.78473
# [289]	validation_0-logloss:0.63695	validation_0-auc:0.90586	validation_1-logloss:0.65424	validation_1-auc:0.78473
# [290]	validation_0-logloss:0.63695	validation_0-auc:0.90586	validation_1-logloss:0.65424	validation_1-auc:0.78473
# [291]	validation_0-logloss:0.63693	validation_0-auc:0.90585	validation_1-logloss:0.65423	validation_1-auc:0.78481
# [292]	validation_0-logloss:0.63692	validation_0-auc:0.90585	validation_1-logloss:0.65422	validation_1-auc:0.78481
# [293]	validation_0-logloss:0.63663	validation_0-auc:0.90603	validation_1-logloss:0.65405	validation_1-auc:0.78458
# [294]	validation_0-logloss:0.63634	validation_0-auc:0.90603	validation_1-logloss:0.65384	validation_1-auc:0.78450
# [295]	validation_0-logloss:0.63604	validation_0-auc:0.90629	validation_1-logloss:0.65364	validation_1-auc:0.78458
# [296]	validation_0-logloss:0.63575	validation_0-auc:0.90633	validation_1-logloss:0.65346	validation_1-auc:0.78404
# [297]	validation_0-logloss:0.63548	validation_0-auc:0.90634	validation_1-logloss:0.65328	validation_1-auc:0.78458
# [298]	validation_0-logloss:0.63547	validation_0-auc:0.90633	validation_1-logloss:0.65328	validation_1-auc:0.78458
# [299]	validation_0-logloss:0.63546	validation_0-auc:0.90631	validation_1-logloss:0.65327	validation_1-auc:0.78458
# [300]	validation_0-logloss:0.63545	validation_0-auc:0.90631	validation_1-logloss:0.65326	validation_1-auc:0.78458
# [301]	validation_0-logloss:0.63544	validation_0-auc:0.90631	validation_1-logloss:0.65326	validation_1-auc:0.78458
# [302]	validation_0-logloss:0.63543	validation_0-auc:0.90631	validation_1-logloss:0.65325	validation_1-auc:0.78458
# [303]	validation_0-logloss:0.63542	validation_0-auc:0.90631	validation_1-logloss:0.65324	validation_1-auc:0.78458
# [304]	validation_0-logloss:0.63541	validation_0-auc:0.90630	validation_1-logloss:0.65324	validation_1-auc:0.78458
# [305]	validation_0-logloss:0.63512	validation_0-auc:0.90632	validation_1-logloss:0.65304	validation_1-auc:0.78489
# [306]	validation_0-logloss:0.63511	validation_0-auc:0.90632	validation_1-logloss:0.65303	validation_1-auc:0.78489
# [307]	validation_0-logloss:0.63482	validation_0-auc:0.90659	validation_1-logloss:0.65285	validation_1-auc:0.78481
# [308]	validation_0-logloss:0.63453	validation_0-auc:0.90684	validation_1-logloss:0.65266	validation_1-auc:0.78489
# [309]	validation_0-logloss:0.63452	validation_0-auc:0.90684	validation_1-logloss:0.65266	validation_1-auc:0.78489
# [310]	validation_0-logloss:0.63451	validation_0-auc:0.90684	validation_1-logloss:0.65265	validation_1-auc:0.78489
# [311]	validation_0-logloss:0.63422	validation_0-auc:0.90664	validation_1-logloss:0.65245	validation_1-auc:0.78412
# [312]	validation_0-logloss:0.63421	validation_0-auc:0.90664	validation_1-logloss:0.65244	validation_1-auc:0.78412
# [313]	validation_0-logloss:0.63421	validation_0-auc:0.90664	validation_1-logloss:0.65244	validation_1-auc:0.78412
# [314]	validation_0-logloss:0.63420	validation_0-auc:0.90664	validation_1-logloss:0.65243	validation_1-auc:0.78412
# [315]	validation_0-logloss:0.63419	validation_0-auc:0.90664	validation_1-logloss:0.65243	validation_1-auc:0.78412
# [316]	validation_0-logloss:0.63418	validation_0-auc:0.90664	validation_1-logloss:0.65242	validation_1-auc:0.78412
# [317]	validation_0-logloss:0.63389	validation_0-auc:0.90679	validation_1-logloss:0.65223	validation_1-auc:0.78481
# [318]	validation_0-logloss:0.63388	validation_0-auc:0.90679	validation_1-logloss:0.65222	validation_1-auc:0.78481
# [319]	validation_0-logloss:0.63387	validation_0-auc:0.90679	validation_1-logloss:0.65222	validation_1-auc:0.78481
# [320]	validation_0-logloss:0.63359	validation_0-auc:0.90701	validation_1-logloss:0.65206	validation_1-auc:0.78442
# [321]	validation_0-logloss:0.63330	validation_0-auc:0.90699	validation_1-logloss:0.65186	validation_1-auc:0.78473
# [322]	validation_0-logloss:0.63301	validation_0-auc:0.90708	validation_1-logloss:0.65168	validation_1-auc:0.78473
# [323]	validation_0-logloss:0.63301	validation_0-auc:0.90708	validation_1-logloss:0.65167	validation_1-auc:0.78473
# [324]	validation_0-logloss:0.63272	validation_0-auc:0.90753	validation_1-logloss:0.65148	validation_1-auc:0.78527
# [325]	validation_0-logloss:0.63271	validation_0-auc:0.90753	validation_1-logloss:0.65147	validation_1-auc:0.78527
# [326]	validation_0-logloss:0.63270	validation_0-auc:0.90753	validation_1-logloss:0.65146	validation_1-auc:0.78527
# [327]	validation_0-logloss:0.63269	validation_0-auc:0.90753	validation_1-logloss:0.65146	validation_1-auc:0.78527
# [328]	validation_0-logloss:0.63268	validation_0-auc:0.90753	validation_1-logloss:0.65145	validation_1-auc:0.78527
# [329]	validation_0-logloss:0.63267	validation_0-auc:0.90723	validation_1-logloss:0.65145	validation_1-auc:0.78473
# [330]	validation_0-logloss:0.63238	validation_0-auc:0.90772	validation_1-logloss:0.65125	validation_1-auc:0.78581
# [331]	validation_0-logloss:0.63211	validation_0-auc:0.90783	validation_1-logloss:0.65108	validation_1-auc:0.78573
# [332]	validation_0-logloss:0.63210	validation_0-auc:0.90783	validation_1-logloss:0.65108	validation_1-auc:0.78573
# [333]	validation_0-logloss:0.63181	validation_0-auc:0.90782	validation_1-logloss:0.65089	validation_1-auc:0.78565
# [334]	validation_0-logloss:0.63180	validation_0-auc:0.90782	validation_1-logloss:0.65089	validation_1-auc:0.78565
# [335]	validation_0-logloss:0.63179	validation_0-auc:0.90782	validation_1-logloss:0.65088	validation_1-auc:0.78565
# [336]	validation_0-logloss:0.63178	validation_0-auc:0.90782	validation_1-logloss:0.65088	validation_1-auc:0.78565
# [337]	validation_0-logloss:0.63150	validation_0-auc:0.90802	validation_1-logloss:0.65068	validation_1-auc:0.78550
# [338]	validation_0-logloss:0.63149	validation_0-auc:0.90801	validation_1-logloss:0.65068	validation_1-auc:0.78550
# [339]	validation_0-logloss:0.63148	validation_0-auc:0.90802	validation_1-logloss:0.65068	validation_1-auc:0.78550
# [340]	validation_0-logloss:0.63120	validation_0-auc:0.90831	validation_1-logloss:0.65049	validation_1-auc:0.78658
# [341]	validation_0-logloss:0.63091	validation_0-auc:0.90835	validation_1-logloss:0.65031	validation_1-auc:0.78665
# [342]	validation_0-logloss:0.63062	validation_0-auc:0.90838	validation_1-logloss:0.65012	validation_1-auc:0.78673
# [343]	validation_0-logloss:0.63062	validation_0-auc:0.90838	validation_1-logloss:0.65012	validation_1-auc:0.78673
# [344]	validation_0-logloss:0.63060	validation_0-auc:0.90839	validation_1-logloss:0.65011	validation_1-auc:0.78673
# [345]	validation_0-logloss:0.63032	validation_0-auc:0.90842	validation_1-logloss:0.64992	validation_1-auc:0.78681
# [346]	validation_0-logloss:0.63031	validation_0-auc:0.90841	validation_1-logloss:0.64992	validation_1-auc:0.78681
# [347]	validation_0-logloss:0.63030	validation_0-auc:0.90841	validation_1-logloss:0.64991	validation_1-auc:0.78681
# [348]	validation_0-logloss:0.63001	validation_0-auc:0.90838	validation_1-logloss:0.64973	validation_1-auc:0.78696
# [349]	validation_0-logloss:0.63001	validation_0-auc:0.90838	validation_1-logloss:0.64972	validation_1-auc:0.78696
# [350]	validation_0-logloss:0.63000	validation_0-auc:0.90838	validation_1-logloss:0.64972	validation_1-auc:0.78696
# [351]	validation_0-logloss:0.62972	validation_0-auc:0.90835	validation_1-logloss:0.64954	validation_1-auc:0.78712
# [352]	validation_0-logloss:0.62946	validation_0-auc:0.90839	validation_1-logloss:0.64938	validation_1-auc:0.78704
# [353]	validation_0-logloss:0.62918	validation_0-auc:0.90852	validation_1-logloss:0.64919	validation_1-auc:0.78704
# [354]	validation_0-logloss:0.62889	validation_0-auc:0.90858	validation_1-logloss:0.64901	validation_1-auc:0.78704
# [355]	validation_0-logloss:0.62889	validation_0-auc:0.90858	validation_1-logloss:0.64901	validation_1-auc:0.78704
# [356]	validation_0-logloss:0.62888	validation_0-auc:0.90844	validation_1-logloss:0.64900	validation_1-auc:0.78665
# [357]	validation_0-logloss:0.62860	validation_0-auc:0.90853	validation_1-logloss:0.64882	validation_1-auc:0.78704
# [358]	validation_0-logloss:0.62832	validation_0-auc:0.90862	validation_1-logloss:0.64863	validation_1-auc:0.78704
# [359]	validation_0-logloss:0.62831	validation_0-auc:0.90862	validation_1-logloss:0.64863	validation_1-auc:0.78704
# [360]	validation_0-logloss:0.62803	validation_0-auc:0.90863	validation_1-logloss:0.64847	validation_1-auc:0.78712
# [361]	validation_0-logloss:0.62775	validation_0-auc:0.90870	validation_1-logloss:0.64828	validation_1-auc:0.78735
# [362]	validation_0-logloss:0.62747	validation_0-auc:0.90883	validation_1-logloss:0.64809	validation_1-auc:0.78712
# [363]	validation_0-logloss:0.62746	validation_0-auc:0.90883	validation_1-logloss:0.64809	validation_1-auc:0.78712
# [364]	validation_0-logloss:0.62718	validation_0-auc:0.90885	validation_1-logloss:0.64792	validation_1-auc:0.78735
# [365]	validation_0-logloss:0.62718	validation_0-auc:0.90886	validation_1-logloss:0.64791	validation_1-auc:0.78735
# [366]	validation_0-logloss:0.62717	validation_0-auc:0.90885	validation_1-logloss:0.64791	validation_1-auc:0.78719
# [367]	validation_0-logloss:0.62689	validation_0-auc:0.90909	validation_1-logloss:0.64772	validation_1-auc:0.78758
# [368]	validation_0-logloss:0.62661	validation_0-auc:0.90903	validation_1-logloss:0.64753	validation_1-auc:0.78696
# [369]	validation_0-logloss:0.62660	validation_0-auc:0.90902	validation_1-logloss:0.64753	validation_1-auc:0.78712
# [370]	validation_0-logloss:0.62660	validation_0-auc:0.90901	validation_1-logloss:0.64752	validation_1-auc:0.78704
# [371]	validation_0-logloss:0.62632	validation_0-auc:0.90922	validation_1-logloss:0.64736	validation_1-auc:0.78765
# [372]	validation_0-logloss:0.62631	validation_0-auc:0.90922	validation_1-logloss:0.64735	validation_1-auc:0.78765
# [373]	validation_0-logloss:0.62604	validation_0-auc:0.90941	validation_1-logloss:0.64717	validation_1-auc:0.78781
# [374]	validation_0-logloss:0.62577	validation_0-auc:0.90941	validation_1-logloss:0.64701	validation_1-auc:0.78812
# [375]	validation_0-logloss:0.62549	validation_0-auc:0.90945	validation_1-logloss:0.64682	validation_1-auc:0.78858
# [376]	validation_0-logloss:0.62548	validation_0-auc:0.90945	validation_1-logloss:0.64682	validation_1-auc:0.78858
# [377]	validation_0-logloss:0.62547	validation_0-auc:0.90945	validation_1-logloss:0.64681	validation_1-auc:0.78858
# [378]	validation_0-logloss:0.62546	validation_0-auc:0.90946	validation_1-logloss:0.64681	validation_1-auc:0.78858
# [379]	validation_0-logloss:0.62546	validation_0-auc:0.90946	validation_1-logloss:0.64681	validation_1-auc:0.78858
# [380]	validation_0-logloss:0.62518	validation_0-auc:0.90939	validation_1-logloss:0.64662	validation_1-auc:0.78858
# [381]	validation_0-logloss:0.62518	validation_0-auc:0.90939	validation_1-logloss:0.64662	validation_1-auc:0.78858
# [382]	validation_0-logloss:0.62491	validation_0-auc:0.90941	validation_1-logloss:0.64645	validation_1-auc:0.78850
# [383]	validation_0-logloss:0.62489	validation_0-auc:0.90941	validation_1-logloss:0.64644	validation_1-auc:0.78850
# [384]	validation_0-logloss:0.62461	validation_0-auc:0.90951	validation_1-logloss:0.64627	validation_1-auc:0.78865
# [385]	validation_0-logloss:0.62435	validation_0-auc:0.90965	validation_1-logloss:0.64610	validation_1-auc:0.78865
# [386]	validation_0-logloss:0.62408	validation_0-auc:0.90965	validation_1-logloss:0.64590	validation_1-auc:0.78912
# [387]	validation_0-logloss:0.62380	validation_0-auc:0.90956	validation_1-logloss:0.64573	validation_1-auc:0.78881
# [388]	validation_0-logloss:0.62352	validation_0-auc:0.90980	validation_1-logloss:0.64556	validation_1-auc:0.78935
# [389]	validation_0-logloss:0.62326	validation_0-auc:0.90964	validation_1-logloss:0.64540	validation_1-auc:0.78912
# [390]	validation_0-logloss:0.62299	validation_0-auc:0.90985	validation_1-logloss:0.64524	validation_1-auc:0.78950
# [391]	validation_0-logloss:0.62272	validation_0-auc:0.91220	validation_1-logloss:0.64511	validation_1-auc:0.79069
# [392]	validation_0-logloss:0.62271	validation_0-auc:0.91222	validation_1-logloss:0.64511	validation_1-auc:0.79069
# [393]	validation_0-logloss:0.62244	validation_0-auc:0.91245	validation_1-logloss:0.64497	validation_1-auc:0.79131
# [394]	validation_0-logloss:0.62243	validation_0-auc:0.91245	validation_1-logloss:0.64497	validation_1-auc:0.79123
# [395]	validation_0-logloss:0.62243	validation_0-auc:0.91244	validation_1-logloss:0.64497	validation_1-auc:0.79123
# [396]	validation_0-logloss:0.62242	validation_0-auc:0.91244	validation_1-logloss:0.64496	validation_1-auc:0.79123
# [397]	validation_0-logloss:0.62215	validation_0-auc:0.91249	validation_1-logloss:0.64479	validation_1-auc:0.79131
# [398]	validation_0-logloss:0.62188	validation_0-auc:0.91256	validation_1-logloss:0.64463	validation_1-auc:0.79077
# [399]	validation_0-logloss:0.62187	validation_0-auc:0.91256	validation_1-logloss:0.64462	validation_1-auc:0.79077
# [400]	validation_0-logloss:0.62186	validation_0-auc:0.91256	validation_1-logloss:0.64462	validation_1-auc:0.79077
# [401]	validation_0-logloss:0.62186	validation_0-auc:0.91256	validation_1-logloss:0.64461	validation_1-auc:0.79077
# [402]	validation_0-logloss:0.62185	validation_0-auc:0.91256	validation_1-logloss:0.64461	validation_1-auc:0.79077
# [403]	validation_0-logloss:0.62184	validation_0-auc:0.91256	validation_1-logloss:0.64460	validation_1-auc:0.79077
# [404]	validation_0-logloss:0.62158	validation_0-auc:0.91318	validation_1-logloss:0.64446	validation_1-auc:0.79173
# [405]	validation_0-logloss:0.62157	validation_0-auc:0.91318	validation_1-logloss:0.64446	validation_1-auc:0.79173
# [406]	validation_0-logloss:0.62157	validation_0-auc:0.91318	validation_1-logloss:0.64446	validation_1-auc:0.79173
# [407]	validation_0-logloss:0.62156	validation_0-auc:0.91318	validation_1-logloss:0.64445	validation_1-auc:0.79173
# [408]	validation_0-logloss:0.62155	validation_0-auc:0.91318	validation_1-logloss:0.64445	validation_1-auc:0.79173
# [409]	validation_0-logloss:0.62155	validation_0-auc:0.91317	validation_1-logloss:0.64445	validation_1-auc:0.79181
# [410]	validation_0-logloss:0.62128	validation_0-auc:0.91363	validation_1-logloss:0.64431	validation_1-auc:0.79181
# [411]	validation_0-logloss:0.62127	validation_0-auc:0.91363	validation_1-logloss:0.64431	validation_1-auc:0.79181
# [412]	validation_0-logloss:0.62101	validation_0-auc:0.91373	validation_1-logloss:0.64416	validation_1-auc:0.79227
# [413]	validation_0-logloss:0.62100	validation_0-auc:0.91373	validation_1-logloss:0.64416	validation_1-auc:0.79227
# [414]	validation_0-logloss:0.62099	validation_0-auc:0.91373	validation_1-logloss:0.64415	validation_1-auc:0.79227
# [415]	validation_0-logloss:0.62099	validation_0-auc:0.91373	validation_1-logloss:0.64415	validation_1-auc:0.79227
# [416]	validation_0-logloss:0.62072	validation_0-auc:0.91393	validation_1-logloss:0.64401	validation_1-auc:0.79242
# [417]	validation_0-logloss:0.62045	validation_0-auc:0.91400	validation_1-logloss:0.64384	validation_1-auc:0.79219
# [418]	validation_0-logloss:0.62045	validation_0-auc:0.91400	validation_1-logloss:0.64384	validation_1-auc:0.79219
# [419]	validation_0-logloss:0.62018	validation_0-auc:0.91439	validation_1-logloss:0.64370	validation_1-auc:0.79204
# [420]	validation_0-logloss:0.62018	validation_0-auc:0.91439	validation_1-logloss:0.64370	validation_1-auc:0.79204
# [421]	validation_0-logloss:0.62017	validation_0-auc:0.91439	validation_1-logloss:0.64370	validation_1-auc:0.79204
# ...
# [1862]	validation_0-logloss:0.46641	validation_0-auc:0.97783	validation_1-logloss:0.56565	validation_1-auc:0.81877
# [1863]	validation_0-logloss:0.46641	validation_0-auc:0.97783	validation_1-logloss:0.56565	validation_1-auc:0.81885
# [1864]	validation_0-logloss:0.46640	validation_0-auc:0.97783	validation_1-logloss:0.56565	validation_1-auc:0.81885
# [1865]	validation_0-logloss:0.46640	validation_0-auc:0.97783	validation_1-logloss:0.56565	validation_1-auc:0.81885
# [1866]	validation_0-logloss:0.46640	validation_0-auc:0.97783	validation_1-logloss:0.56565	validation_1-auc:0.81885
# [1867]	validation_0-logloss:0.46640	validation_0-auc:0.97783	validation_1-logloss:0.56565	validation_1-auc:0.81885
# [1868]	validation_0-logloss:0.46619	validation_0-auc:0.97792	validation_1-logloss:0.56557	validation_1-auc:0.81908
# [1869]	validation_0-logloss:0.46619	validation_0-auc:0.97792	validation_1-logloss:0.56557	validation_1-auc:0.81908
# [1870]	validation_0-logloss:0.46604	validation_0-auc:0.97793	validation_1-logloss:0.56551	validation_1-auc:0.81900
# [1871]	validation_0-logloss:0.46583	validation_0-auc:0.97802	validation_1-logloss:0.56539	validation_1-auc:0.81900
# [1872]	validation_0-logloss:0.46583	validation_0-auc:0.97802	validation_1-logloss:0.56539	validation_1-auc:0.81900
# [1873]	validation_0-logloss:0.46568	validation_0-auc:0.97803	validation_1-logloss:0.56536	validation_1-auc:0.81892
# [1874]	validation_0-logloss:0.46546	validation_0-auc:0.97811	validation_1-logloss:0.56523	validation_1-auc:0.81931
# [1875]	validation_0-logloss:0.46534	validation_0-auc:0.97811	validation_1-logloss:0.56518	validation_1-auc:0.81946
# [1876]	validation_0-logloss:0.46534	validation_0-auc:0.97811	validation_1-logloss:0.56518	validation_1-auc:0.81946
# [1877]	validation_0-logloss:0.46534	validation_0-auc:0.97811	validation_1-logloss:0.56518	validation_1-auc:0.81946
# [1878]	validation_0-logloss:0.46520	validation_0-auc:0.97813	validation_1-logloss:0.56513	validation_1-auc:0.81931
# [1879]	validation_0-logloss:0.46499	validation_0-auc:0.97821	validation_1-logloss:0.56505	validation_1-auc:0.81961
# [1880]	validation_0-logloss:0.46487	validation_0-auc:0.97824	validation_1-logloss:0.56500	validation_1-auc:0.81969
# [1881]	validation_0-logloss:0.46486	validation_0-auc:0.97824	validation_1-logloss:0.56500	validation_1-auc:0.81969
# [1882]	validation_0-logloss:0.46486	validation_0-auc:0.97824	validation_1-logloss:0.56500	validation_1-auc:0.81969
# [1883]	validation_0-logloss:0.46465	validation_0-auc:0.97829	validation_1-logloss:0.56491	validation_1-auc:0.81992
# [1884]	validation_0-logloss:0.46452	validation_0-auc:0.97833	validation_1-logloss:0.56486	validation_1-auc:0.81977
# [1885]	validation_0-logloss:0.46452	validation_0-auc:0.97833	validation_1-logloss:0.56486	validation_1-auc:0.81977
# [1886]	validation_0-logloss:0.46452	validation_0-auc:0.97832	validation_1-logloss:0.56486	validation_1-auc:0.81977
# [1887]	validation_0-logloss:0.46452	validation_0-auc:0.97832	validation_1-logloss:0.56486	validation_1-auc:0.81977
# [1888]	validation_0-logloss:0.46430	validation_0-auc:0.97840	validation_1-logloss:0.56474	validation_1-auc:0.81985
# [1889]	validation_0-logloss:0.46418	validation_0-auc:0.97840	validation_1-logloss:0.56469	validation_1-auc:0.81946
# [1890]	validation_0-logloss:0.46418	validation_0-auc:0.97840	validation_1-logloss:0.56469	validation_1-auc:0.81946
# [1891]	validation_0-logloss:0.46397	validation_0-auc:0.97851	validation_1-logloss:0.56461	validation_1-auc:0.81992
# [1892]	validation_0-logloss:0.46383	validation_0-auc:0.97852	validation_1-logloss:0.56455	validation_1-auc:0.81985
# [1893]	validation_0-logloss:0.46383	validation_0-auc:0.97852	validation_1-logloss:0.56455	validation_1-auc:0.81985
# [1894]	validation_0-logloss:0.46383	validation_0-auc:0.97852	validation_1-logloss:0.56455	validation_1-auc:0.81985
# [1895]	validation_0-logloss:0.46362	validation_0-auc:0.97860	validation_1-logloss:0.56443	validation_1-auc:0.82023
# [1896]	validation_0-logloss:0.46350	validation_0-auc:0.97862	validation_1-logloss:0.56439	validation_1-auc:0.82000
# [1897]	validation_0-logloss:0.46350	validation_0-auc:0.97862	validation_1-logloss:0.56439	validation_1-auc:0.82000
# [1898]	validation_0-logloss:0.46329	validation_0-auc:0.97870	validation_1-logloss:0.56430	validation_1-auc:0.82023
# [1899]	validation_0-logloss:0.46315	validation_0-auc:0.97873	validation_1-logloss:0.56425	validation_1-auc:0.81977
# [1900]	validation_0-logloss:0.46315	validation_0-auc:0.97873	validation_1-logloss:0.56425	validation_1-auc:0.81977
# [1901]	validation_0-logloss:0.46303	validation_0-auc:0.97874	validation_1-logloss:0.56421	validation_1-auc:0.81985
# [1902]	validation_0-logloss:0.46282	validation_0-auc:0.97885	validation_1-logloss:0.56409	validation_1-auc:0.82015
# [1903]	validation_0-logloss:0.46282	validation_0-auc:0.97885	validation_1-logloss:0.56409	validation_1-auc:0.82015
# [1904]	validation_0-logloss:0.46268	validation_0-auc:0.97889	validation_1-logloss:0.56404	validation_1-auc:0.81969
# [1905]	validation_0-logloss:0.46267	validation_0-auc:0.97889	validation_1-logloss:0.56404	validation_1-auc:0.81969
# [1906]	validation_0-logloss:0.46246	validation_0-auc:0.97893	validation_1-logloss:0.56396	validation_1-auc:0.81969
# [1907]	validation_0-logloss:0.46235	validation_0-auc:0.97895	validation_1-logloss:0.56391	validation_1-auc:0.81969
# [1908]	validation_0-logloss:0.46214	validation_0-auc:0.97906	validation_1-logloss:0.56380	validation_1-auc:0.81969
# [1909]	validation_0-logloss:0.46213	validation_0-auc:0.97906	validation_1-logloss:0.56380	validation_1-auc:0.81969
# [1910]	validation_0-logloss:0.46213	validation_0-auc:0.97906	validation_1-logloss:0.56380	validation_1-auc:0.81969
# [1911]	validation_0-logloss:0.46213	validation_0-auc:0.97906	validation_1-logloss:0.56380	validation_1-auc:0.81969
# [1912]	validation_0-logloss:0.46213	validation_0-auc:0.97906	validation_1-logloss:0.56380	validation_1-auc:0.81969
# [1913]	validation_0-logloss:0.46213	validation_0-auc:0.97906	validation_1-logloss:0.56380	validation_1-auc:0.81969
# [1914]	validation_0-logloss:0.46213	validation_0-auc:0.97906	validation_1-logloss:0.56380	validation_1-auc:0.81969
# [1915]	validation_0-logloss:0.46201	validation_0-auc:0.97909	validation_1-logloss:0.56374	validation_1-auc:0.81969
# [1916]	validation_0-logloss:0.46201	validation_0-auc:0.97909	validation_1-logloss:0.56374	validation_1-auc:0.81969
# [1917]	validation_0-logloss:0.46201	validation_0-auc:0.97910	validation_1-logloss:0.56374	validation_1-auc:0.81969
# [1918]	validation_0-logloss:0.46201	validation_0-auc:0.97910	validation_1-logloss:0.56374	validation_1-auc:0.81969
# [1919]	validation_0-logloss:0.46201	validation_0-auc:0.97910	validation_1-logloss:0.56374	validation_1-auc:0.81969
# [1920]	validation_0-logloss:0.46180	validation_0-auc:0.97915	validation_1-logloss:0.56366	validation_1-auc:0.81977
# [1921]	validation_0-logloss:0.46167	validation_0-auc:0.97916	validation_1-logloss:0.56361	validation_1-auc:0.81985
# [1922]	validation_0-logloss:0.46146	validation_0-auc:0.97924	validation_1-logloss:0.56349	validation_1-auc:0.81977
# [1923]	validation_0-logloss:0.46145	validation_0-auc:0.97924	validation_1-logloss:0.56349	validation_1-auc:0.81977
# [1924]	validation_0-logloss:0.46145	validation_0-auc:0.97924	validation_1-logloss:0.56349	validation_1-auc:0.81977
# [1925]	validation_0-logloss:0.46134	validation_0-auc:0.97927	validation_1-logloss:0.56345	validation_1-auc:0.81969
# [1926]	validation_0-logloss:0.46134	validation_0-auc:0.97927	validation_1-logloss:0.56345	validation_1-auc:0.81969
# [1927]	validation_0-logloss:0.46134	validation_0-auc:0.97927	validation_1-logloss:0.56345	validation_1-auc:0.81969
# [1928]	validation_0-logloss:0.46134	validation_0-auc:0.97927	validation_1-logloss:0.56345	validation_1-auc:0.81969
# [1929]	validation_0-logloss:0.46113	validation_0-auc:0.97932	validation_1-logloss:0.56337	validation_1-auc:0.81969
# [1930]	validation_0-logloss:0.46113	validation_0-auc:0.97932	validation_1-logloss:0.56337	validation_1-auc:0.81969
# [1931]	validation_0-logloss:0.46101	validation_0-auc:0.97937	validation_1-logloss:0.56332	validation_1-auc:0.81969
# [1932]	validation_0-logloss:0.46088	validation_0-auc:0.97939	validation_1-logloss:0.56327	validation_1-auc:0.81969
# [1933]	validation_0-logloss:0.46088	validation_0-auc:0.97939	validation_1-logloss:0.56327	validation_1-auc:0.81969
# [1934]	validation_0-logloss:0.46088	validation_0-auc:0.97939	validation_1-logloss:0.56327	validation_1-auc:0.81969
# [1935]	validation_0-logloss:0.46067	validation_0-auc:0.97947	validation_1-logloss:0.56319	validation_1-auc:0.81992
# [1936]	validation_0-logloss:0.46054	validation_0-auc:0.97950	validation_1-logloss:0.56314	validation_1-auc:0.81969
# [1937]	validation_0-logloss:0.46032	validation_0-auc:0.97955	validation_1-logloss:0.56302	validation_1-auc:0.81992
# [1938]	validation_0-logloss:0.46032	validation_0-auc:0.97955	validation_1-logloss:0.56302	validation_1-auc:0.81992
# [1939]	validation_0-logloss:0.46021	validation_0-auc:0.97959	validation_1-logloss:0.56298	validation_1-auc:0.81969
# [1940]	validation_0-logloss:0.46021	validation_0-auc:0.97959	validation_1-logloss:0.56298	validation_1-auc:0.81969
# [1941]	validation_0-logloss:0.46000	validation_0-auc:0.97965	validation_1-logloss:0.56290	validation_1-auc:0.82000
# [1942]	validation_0-logloss:0.46000	validation_0-auc:0.97965	validation_1-logloss:0.56290	validation_1-auc:0.82000
# [1943]	validation_0-logloss:0.45986	validation_0-auc:0.97967	validation_1-logloss:0.56285	validation_1-auc:0.82023
# [1944]	validation_0-logloss:0.45965	validation_0-auc:0.97975	validation_1-logloss:0.56273	validation_1-auc:0.82008
# [1945]	validation_0-logloss:0.45965	validation_0-auc:0.97975	validation_1-logloss:0.56273	validation_1-auc:0.82008
# [1946]	validation_0-logloss:0.45954	validation_0-auc:0.97976	validation_1-logloss:0.56269	validation_1-auc:0.82023
# [1947]	validation_0-logloss:0.45953	validation_0-auc:0.97976	validation_1-logloss:0.56269	validation_1-auc:0.82023
# [1948]	validation_0-logloss:0.45933	validation_0-auc:0.97980	validation_1-logloss:0.56261	validation_1-auc:0.82039
# [1949]	validation_0-logloss:0.45933	validation_0-auc:0.97980	validation_1-logloss:0.56261	validation_1-auc:0.82039
# [1950]	validation_0-logloss:0.45933	validation_0-auc:0.97980	validation_1-logloss:0.56261	validation_1-auc:0.82039
# [1951]	validation_0-logloss:0.45921	validation_0-auc:0.97981	validation_1-logloss:0.56257	validation_1-auc:0.82031
# [1952]	validation_0-logloss:0.45908	validation_0-auc:0.97984	validation_1-logloss:0.56252	validation_1-auc:0.82031
# [1953]	validation_0-logloss:0.45887	validation_0-auc:0.97991	validation_1-logloss:0.56240	validation_1-auc:0.82039
# [1954]	validation_0-logloss:0.45876	validation_0-auc:0.97995	validation_1-logloss:0.56235	validation_1-auc:0.82031
# [1955]	validation_0-logloss:0.45875	validation_0-auc:0.97995	validation_1-logloss:0.56235	validation_1-auc:0.82031
# [1956]	validation_0-logloss:0.45875	validation_0-auc:0.97995	validation_1-logloss:0.56235	validation_1-auc:0.82031
# [1957]	validation_0-logloss:0.45855	validation_0-auc:0.98006	validation_1-logloss:0.56228	validation_1-auc:0.82054
# [1958]	validation_0-logloss:0.45843	validation_0-auc:0.98011	validation_1-logloss:0.56225	validation_1-auc:0.82069
# [1959]	validation_0-logloss:0.45843	validation_0-auc:0.98011	validation_1-logloss:0.56225	validation_1-auc:0.82069
# [1960]	validation_0-logloss:0.45822	validation_0-auc:0.98016	validation_1-logloss:0.56213	validation_1-auc:0.82077
# [1961]	validation_0-logloss:0.45809	validation_0-auc:0.98020	validation_1-logloss:0.56208	validation_1-auc:0.82069
# [1962]	validation_0-logloss:0.45788	validation_0-auc:0.98025	validation_1-logloss:0.56201	validation_1-auc:0.82092
# [1963]	validation_0-logloss:0.45788	validation_0-auc:0.98025	validation_1-logloss:0.56201	validation_1-auc:0.82092
# [1964]	validation_0-logloss:0.45776	validation_0-auc:0.98025	validation_1-logloss:0.56199	validation_1-auc:0.82077
# [1965]	validation_0-logloss:0.45764	validation_0-auc:0.98025	validation_1-logloss:0.56193	validation_1-auc:0.82069
# [1966]	validation_0-logloss:0.45764	validation_0-auc:0.98025	validation_1-logloss:0.56193	validation_1-auc:0.82069
# [1967]	validation_0-logloss:0.45743	validation_0-auc:0.98035	validation_1-logloss:0.56182	validation_1-auc:0.82092
# [1968]	validation_0-logloss:0.45743	validation_0-auc:0.98035	validation_1-logloss:0.56182	validation_1-auc:0.82092
# [1969]	validation_0-logloss:0.45731	validation_0-auc:0.98035	validation_1-logloss:0.56178	validation_1-auc:0.82077
# [1970]	validation_0-logloss:0.45711	validation_0-auc:0.98042	validation_1-logloss:0.56171	validation_1-auc:0.82085
# [1971]	validation_0-logloss:0.45697	validation_0-auc:0.98040	validation_1-logloss:0.56165	validation_1-auc:0.82092
# [1972]	validation_0-logloss:0.45697	validation_0-auc:0.98040	validation_1-logloss:0.56165	validation_1-auc:0.82092
# [1973]	validation_0-logloss:0.45676	validation_0-auc:0.98042	validation_1-logloss:0.56153	validation_1-auc:0.82085
# [1974]	validation_0-logloss:0.45665	validation_0-auc:0.98046	validation_1-logloss:0.56151	validation_1-auc:0.82077
# [1975]	validation_0-logloss:0.45644	validation_0-auc:0.98049	validation_1-logloss:0.56144	validation_1-auc:0.82069
# [1976]	validation_0-logloss:0.45631	validation_0-auc:0.98052	validation_1-logloss:0.56139	validation_1-auc:0.82085
# [1977]	validation_0-logloss:0.45610	validation_0-auc:0.98058	validation_1-logloss:0.56127	validation_1-auc:0.82077
# [1978]	validation_0-logloss:0.45599	validation_0-auc:0.98059	validation_1-logloss:0.56125	validation_1-auc:0.82061
# [1979]	validation_0-logloss:0.45599	validation_0-auc:0.98059	validation_1-logloss:0.56125	validation_1-auc:0.82061
# [1980]	validation_0-logloss:0.45599	validation_0-auc:0.98059	validation_1-logloss:0.56125	validation_1-auc:0.82061
# [1981]	validation_0-logloss:0.45599	validation_0-auc:0.98059	validation_1-logloss:0.56125	validation_1-auc:0.82061
# [1982]	validation_0-logloss:0.45587	validation_0-auc:0.98064	validation_1-logloss:0.56122	validation_1-auc:0.82039
# [1983]	validation_0-logloss:0.45587	validation_0-auc:0.98064	validation_1-logloss:0.56122	validation_1-auc:0.82039
# [1984]	validation_0-logloss:0.45566	validation_0-auc:0.98070	validation_1-logloss:0.56110	validation_1-auc:0.82039
# [1985]	validation_0-logloss:0.45553	validation_0-auc:0.98071	validation_1-logloss:0.56106	validation_1-auc:0.82031
# [1986]	validation_0-logloss:0.45532	validation_0-auc:0.98076	validation_1-logloss:0.56098	validation_1-auc:0.82046
# [1987]	validation_0-logloss:0.45532	validation_0-auc:0.98077	validation_1-logloss:0.56098	validation_1-auc:0.82046
# [1988]	validation_0-logloss:0.45521	validation_0-auc:0.98080	validation_1-logloss:0.56096	validation_1-auc:0.82031
# [1989]	validation_0-logloss:0.45521	validation_0-auc:0.98080	validation_1-logloss:0.56096	validation_1-auc:0.82031
# [1990]	validation_0-logloss:0.45521	validation_0-auc:0.98080	validation_1-logloss:0.56096	validation_1-auc:0.82031
# [1991]	validation_0-logloss:0.45521	validation_0-auc:0.98080	validation_1-logloss:0.56096	validation_1-auc:0.82031
# [1992]	validation_0-logloss:0.45521	validation_0-auc:0.98080	validation_1-logloss:0.56096	validation_1-auc:0.82031
# [1993]	validation_0-logloss:0.45500	validation_0-auc:0.98084	validation_1-logloss:0.56085	validation_1-auc:0.82054
# [1994]	validation_0-logloss:0.45500	validation_0-auc:0.98084	validation_1-logloss:0.56085	validation_1-auc:0.82054
# [1995]	validation_0-logloss:0.45489	validation_0-auc:0.98089	validation_1-logloss:0.56082	validation_1-auc:0.82039
# [1996]	validation_0-logloss:0.45489	validation_0-auc:0.98089	validation_1-logloss:0.56082	validation_1-auc:0.82039
# [1997]	validation_0-logloss:0.45469	validation_0-auc:0.98095	validation_1-logloss:0.56071	validation_1-auc:0.82077
# [1998]	validation_0-logloss:0.45469	validation_0-auc:0.98095	validation_1-logloss:0.56071	validation_1-auc:0.82077
# [1999]	validation_0-logloss:0.45468	validation_0-auc:0.98095	validation_1-logloss:0.56071	validation_1-auc:0.82077
# Accuracy: 0.738

# %%
# plot learning curves
pyplot.plot(results['validation_0']['auc'], label='train')
pyplot.plot(results['validation_1']['auc'], label='test')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()

# %%
print(classification_report(y_test,model.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.71      0.71      0.71       104
#            2       0.76      0.76      0.76       125
#
#     accuracy                           0.74       229
#    macro avg       0.74      0.74      0.74       229
# weighted avg       0.74      0.74      0.74       229

# %%
print(confusion_matrix(y_test,model.predict(X_test)))
# Out:
# [[74 30]
#  [30 95]]

# %% [markdown]
# # Lazy prediction

# %%
#!pip install lazypredict

# %%
import lazypredict
### importing LazyClassifier for classification problem
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric = None)
### fitting data in LazyClassifier
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
### lets check which model did better on Breast Cancer Dataset
print(models)
# Out:
# 100%|██████████| 29/29 [00:12<00:00,  2.38it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# NuSVC                              0.79               0.79     0.79      0.79
# XGBClassifier                      0.79               0.79     0.79      0.79
# RandomForestClassifier             0.78               0.78     0.78      0.78
# RidgeClassifierCV                  0.77               0.77     0.77      0.77
# RidgeClassifier                    0.76               0.76     0.76      0.76
# ExtraTreesClassifier               0.76               0.76     0.76      0.76
# LinearDiscriminantAnalysis         0.76               0.76     0.76      0.76
# CalibratedClassifierCV             0.76               0.75     0.75      0.76
# LogisticRegression                 0.75               0.75     0.75      0.75
# LinearSVC                          0.75               0.75     0.75      0.75
# LGBMClassifier                     0.75               0.75     0.75      0.75
# SVC                                0.72               0.72     0.72      0.72
# BaggingClassifier                  0.72               0.72     0.72      0.72
# SGDClassifier                      0.71               0.71     0.71      0.71
# AdaBoostClassifier                 0.70               0.70     0.70      0.70
# KNeighborsClassifier               0.71               0.70     0.70      0.71
# PassiveAggressiveClassifier        0.68               0.68     0.68      0.68
# LabelSpreading                     0.67               0.67     0.67      0.67
# LabelPropagation                   0.67               0.67     0.67      0.67
# QuadraticDiscriminantAnalysis      0.68               0.67     0.67      0.67
# Perceptron                         0.65               0.65     0.65      0.65
# DecisionTreeClassifier             0.63               0.63     0.63      0.63
# NearestCentroid                    0.59               0.61     0.61      0.59
# ExtraTreeClassifier                0.60               0.59     0.59      0.60
# BernoulliNB                        0.56               0.57     0.57      0.56
# GaussianNB                         0.45               0.49     0.49      0.36
# DummyClassifier                    0.47               0.46     0.46      0.47
#
#                                Time Taken
# Model
# NuSVC                                0.33
# XGBClassifier                        1.72
# RandomForestClassifier               0.95
# RidgeClassifierCV                    0.10
# RidgeClassifier                      0.05
# ExtraTreesClassifier                 0.32
# LinearDiscriminantAnalysis           0.13
# CalibratedClassifierCV               1.61
# LogisticRegression                   0.12
# LinearSVC                            0.44
# LGBMClassifier                       2.92
# SVC                                  0.33
# BaggingClassifier                    0.91
# SGDClassifier                        0.06
# AdaBoostClassifier                   1.12
# KNeighborsClassifier                 0.13
# PassiveAggressiveClassifier          0.05
# LabelSpreading                       0.16
# LabelPropagation                     0.11
# QuadraticDiscriminantAnalysis        0.10
# Perceptron                           0.05
# DecisionTreeClassifier               0.20
# NearestCentroid                      0.05
# ExtraTreeClassifier                  0.03
# BernoulliNB                          0.04
# GaussianNB                           0.03
# DummyClassifier                      0.03
